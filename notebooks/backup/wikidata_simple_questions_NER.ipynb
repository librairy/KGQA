# %% [markdown]
# # Named Entity Recognition based on Language Models, PoS tagging and Subwords

# %%
# %%capture
# !pip install --upgrade pip
# !pip install flair

# %%
# PoS tagger

from flair.data import Sentence
from flair.models import SequenceTagger
tagger = SequenceTagger.load("flair/pos-english")
# Out:
# Downloading:   0%|          | 0.00/249M [00:00<?, ?B/s]
# 2022-04-19 10:43:34,467 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# 2022-04-19 10:43:35,010 SequenceTagger predicts: Dictionary with 53 tags: <unk>, O, UH, ,, VBD, PRP, VB, PRP$, NN, RB, ., DT, JJ, VBP, VBG, IN, CD, NNS, NNP, WRB, VBZ, WDT, CC, TO, MD, VBN, WP, :, RP, EX, JJR, FW, XX, HYPH, POS, RBR, JJS, PDT, NNPS, RBS, AFX, WP$, -LRB-, -RRB-, ``, '', LS, $, SYM, ADD

# %%
# NER model

from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER-uncased")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER-uncased")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
# Out:
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]

# %%
def get_pos_entities(text,category):
    # make example sentence
    sentence = Sentence(text)

    # predict NER tags
    tagger.predict(sentence)

    # print sentence
    #print(sentence)
    # iterate over entities and print
    entities = []
    current_entity = ""
    for t in sentence.tokens:
        for label in t.annotation_layers.keys():
            text = t.text
            label = t.get_labels(label)[0].value   
            if (label == category):
                if (current_entity == ""):
                    current_entity += text
                else:
                    current_entity += " " + text
            elif len(current_entity) > 0:
                entities.append(current_entity)
                current_entity = ""
          
    if (len(current_entity)>0):
        entities.append(current_entity)
    return entities

r = get_pos_entities("who's a kung fu star from hong kong","NN")
print(r)
# Out:
# ['kung fu star']

# %%
def get_entities(text):
    entities = []
    entity = ""
    index = -1
    offset = -1
    for token in nlp(text):
        if (index == -1):
            index = token['index']
            offset = token['start']
        word = token['word']
        if (word[0] == '#'):
            word = token['word'].replace("#","")
            
        if (token['start']== offset):
            entity += word
        elif (token['index']-index < 2):
            entity += " " + word
        else:
            entities.append(entity)
            entity = word
        index = token['index']
        offset = token['end']
        
    if (len(entity) > 0):    
        entities.append(entity)
    if (len(entities) == 0):
        cardinal_entities =  get_pos_entities(text,"CD")
        if (len(cardinal_entities)>0):
            return cardinal_entities
        noun_entities =  get_pos_entities(text,"NN")
        if (len(noun_entities)>0):
            return noun_entities
        
    return entities

r = get_entities("which city did carl-alfred schumacher die")
print(r)
# Out:
# ['carl-alfred schumacher']

# %% [markdown]
# # Wikidata Entity Linking based on MediaWiki API
#
# The MediaWiki Action API is a web service that allows access to some wiki-features like authentication, page operations, and search. It can provide meta information about the wiki and the logged-in user.
#
# action=wbsearchentities
#
# Searches for entities using labels and aliases.
#
# Returns a label and description for the entity in the user language if possible. Returns details of the matched term. The matched term text is also present in the aliases key if different from the display label.

# %%
import requests
def get_wikidata_candidates(label):
    candidates = []
    if (label==""):
        return candidates
    # type: One of the following values: form, form, item, lexeme, property, sense, sense
    query_path = "https://www.wikidata.org/w/api.php?action=wbsearchentities&search=QUERY_TEXT&language=en&limit=10&type=item&format=json"
    r = requests.get(query_path.replace("QUERY_TEXT",label))
    
    for answer in r.json()['search']:
        candidate = {
            'label': answer['display']['label']['value'],
            'id':answer['id']
#            'description' : answer['display']['description']
        }
        candidates.append(candidate)
    return candidates

r = get_wikidata_candidates("Berlín")
print(r)
# Out:
# [{'label': 'Berlin', 'id': 'Q64'}, {'label': 'Berlin', 'id': 'Q821244'}, {'label': 'Berlin', 'id': 'Q614184'}, {'label': 'Berlín', 'id': 'Q582242'}, {'label': '1936 Summer Olympics', 'id': 'Q8150'}, {'label': 'Berlín', 'id': 'Q821971'}, {'label': 'Berlín', 'id': 'Q62270519'}, {'label': 'Technical University of Berlin', 'id': 'Q51985'}, {'label': 'Mitte', 'id': 'Q163966'}, {'label': 'Berlín', 'id': 'Q20274855'}]

# %% [markdown]
# ### DBpedia Entity Linking based on DBpedia Lookup service
#
# The DBpedia Lookup is an entity retrieval service for Linked Data. It provides a straightforward solution for the frequent use case of resolving keywords and natural language to related resource identifiers in the DBpedia knowledge graph. Related means that either the label or abstract of a resource matches, or an anchor text that was frequently used in Wikipedia to refer to a specific resource matches (e.g. the resource http://dbpedia.org/resource/United_States can be looked up by the string “USA”).
#
# So whether you need an auto-complete service for your RDF application, Linked Data enhancements for your CSV tables or simply a way to retrieve specific DBpedia identifiers – the DBpedia Lookup is for you!
#
# As a part of the DBpedia Technology Stack the DBpedia Lookup can be deployed conveniently via Docker and works well with DBpedia Databus Collections. The DBpedia Lookup uses an Apache Lucene Index for resource indexing and retrieval and provides a web interface for querying.

# %%
import requests
def get_dbpedia_candidates(label):
    candidates = []
    if (label==""):
        return candidates
    # type: One of the following values: form, form, item, lexeme, property, sense, sense
    query_path = "http://lookup.dbpedia.org/api/search?query=QUERY_TEXT&maxResults=10&type=class&format=json"
    r = requests.get(query_path.replace("QUERY_TEXT",label))
    for answer in r.json()['docs']:
      if ('label' in answer) and ('resource' in answer):
        candidate = {
            'label': answer['label'][0].replace("<B>","").replace("</B>",""),
            'id':answer['resource'][0].split("http://dbpedia.org/resource/")[1]
#            'description' : answer['display']['description']
        }
        candidates.append(candidate)
    return candidates

r = get_dbpedia_candidates("Berlín")
print(r)
# Out:
# [{'label': 'Berlin', 'id': 'Berlin'}, {'label': 'Bergen', 'id': 'Bergen'}, {'label': 'Tennis Borussia Berlin', 'id': 'Tennis_Borussia_Berlin'}, {'label': '1. FC Union Berlin', 'id': '1._FC_Union_Berlin'}, {'label': 'West Berlin', 'id': 'West_Berlin'}, {'label': 'East Berlin', 'id': 'East_Berlin'}, {'label': 'Berlín, Usulután', 'id': 'Berlín,_Usulután'}, {'label': 'Humboldt University of Berlin', 'id': 'Humboldt_University_of_Berlin'}, {'label': 'Hertha BSC', 'id': 'Hertha_BSC'}, {'label': 'Carlos Berlín Montero', 'id': 'Carlos_Berlín_Montero'}]

# %% [markdown]
# # Wikidata Simple-Question with Answers
#
# We only consider questions with a single answer (i.e. predicate = 'P').

# %%
import pandas as pd
df = pd.read_csv('wsq-labels.csv', index_col=0)
df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question      subject_label  \
# 0                        Where did roger marquis die      Roger Marquis
# 1          what was the cause of death of yves klein         Yves Klein
# 2              What position does carlos gomez play?       Carlos Gómez
# 3               how does engelbert zaschka identify   Engelbert Zaschka
# 4  what position does pee wee reese play in baseball      Pee Wee Reese
#
#                         predicate_label           object_label
# 0                        place of death                Holyoke
# 1                        cause of death  myocardial infarction
# 2  position played on team / speciality         center fielder
# 3                         sex or gender                   male
# 4  position played on team / speciality              shortstop

# %% [markdown]
# ## NER Task

# %%
# initialize entities column
entities = []

# %%
index = 0
rows = df.to_numpy().tolist()
for row in rows[index:]:
    question = row[3] #question
    print(index,":",question)
    question_entities = get_entities(question)
    entities.append(question_entities)
    index += 1
print(len(entities),"questions analyzed!")

# %%
df['entity']=entities
df.to_csv('wsq-entities.csv')
df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question      subject_label  \
# 0                        Where did roger marquis die      Roger Marquis
# 1          what was the cause of death of yves klein         Yves Klein
# 2              What position does carlos gomez play?       Carlos Gómez
# 3               how does engelbert zaschka identify   Engelbert Zaschka
# 4  what position does pee wee reese play in baseball      Pee Wee Reese
#
#                         predicate_label           object_label  \
# 0                        place of death                Holyoke
# 1                        cause of death  myocardial infarction
# 2  position played on team / speciality         center fielder
# 3                         sex or gender                   male
# 4  position played on team / speciality              shortstop
#
#                 entity
# 0      [roger marquis]
# 1         [yves klein]
# 2       [carlos gomez]
# 3  [engelbert zaschka]
# 4      [pee wee reese]

# %% [markdown]
# ## Entity Linking Task

# %% [markdown]
# ### Wikidata Entity Linking

# %%
# initialize wikidata entities column
wikidata_items = []

# %%
index = 0
rows = df.to_numpy().tolist()
for row in rows[index:]:
    items = []
    q_entities = row[7] #entity
    print(index,":",q_entities)
    for entity in q_entities:
      for item in get_wikidata_candidates(entity):
          items.append(item['id'])
    wikidata_items.append(items)    
    index += 1
print(len(wikidata_items),"questions analyzed!")

# %%
df['wiki_items']=wikidata_items
df.to_csv('wsq-wikidata.csv')
df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question      subject_label  \
# 0                        Where did roger marquis die      Roger Marquis
# 1          what was the cause of death of yves klein         Yves Klein
# 2              What position does carlos gomez play?       Carlos Gómez
# 3               how does engelbert zaschka identify   Engelbert Zaschka
# 4  what position does pee wee reese play in baseball      Pee Wee Reese
#
#                         predicate_label           object_label  \
# 0                        place of death                Holyoke
# 1                        cause of death  myocardial infarction
# 2  position played on team / speciality         center fielder
# 3                         sex or gender                   male
# 4  position played on team / speciality              shortstop
#
#                 entity                                         wiki_items
# 0      [roger marquis]                               [Q7358592, Q7358590]
# 1         [yves klein]  [Q154335, Q98233558, Q8062325, Q92397997, Q806...
# 2       [carlos gomez]  [Q949506, Q203210, Q51944192, Q2747238, Q50421...
# 3  [engelbert zaschka]                                           [Q62498]
# 4      [pee wee reese]                                          [Q182485]

# %% [markdown]
# ### DBpedia Entity Linking

# %%
# initialize dbpedia entities column
dbpedia_items = []

# %%
index = 0
for row in rows[index:]:
    items = []
    q_entities = row[7] #entity
    print(index,":",q_entities)
    for entity in q_entities:
      for item in get_dbpedia_candidates(entity):
          items.append(item['id'])    
    dbpedia_items.append(items)
    index += 1
print(len(dbpedia_items),"questions analyzed!")
# Out:
# 0 : ['roger marquis']
# 1 : ['yves klein']
# 2 : ['carlos gomez']
# 3 : ['engelbert zaschka']
# 4 : ['pee wee reese']
# 5 : ['swiss']
# 6 : ['padraic mcguinness']
# 7 : ['sam edwards']
# 8 : ['italianate']
# 9 : ['neo contra']
# 10 : ['angie estes']
# 11 : ['jose francisco torres']
# 12 : ['warsaw']
# 13 : ['jakarta']
# 14 : ['prague']
# 15 : ['guy pnini']
# 16 : ['scott grimes']
# 17 : ['sidewalks entertainment']
# 18 : ['tour perret']
# 19 : ['guy clark']
# 20 : ['australian', 'roll']
# 21 : ['dysona']
# 22 : ['robo v']
# 23 : ['example', 'romance film']
# 24 : ['shigeyasu suzuki']
# 25 : ['yonatan rozen']
# 26 : ['indian', 'fazil']
# 27 : ['paolo de la haza']
# 28 : ['daniela cristofori']
# 29 : ['country', 'delivery']
# 30 : ['crixas do tocantins']
# 31 : ['ian iqbal rashid']
# 32 : ['monango']
# 33 : ['who', 'rca records']
# 34 : ['artist', 'love']
# 35 : ['gampelay', 'allegiance']
# 36 : ['raghuvinte swantham raziya']
# 37 : ['which films', 'leonid gaidai']
# 38 : ['j. a. folger']
# 39 : ['shinji mori']
# 40 : ['msui', 'john pizzarelli']
# 41 : ['pandarus']
# 42 : ['trond egil soltvedt']
# 43 : ['super mario bros. 2']
# 44 : ['anthony perkins']
# 45 : ['schuylkill']
# 46 : ['bin laden', 'america']
# 47 : ['model', 'car accident']
# 48 : ['brian dowling']
# 49 : ['catania']
# 50 : ['carrasco']
# 51 : ['julio medem']
# 52 : ['walter muller']
# 53 : ['fable']
# 54 : ['chris gwynn']
# 55 : ['enrico medioli']
# 56 : ['film', 'film']
# 57 : ['jack warner', 'american']
# 58 : ['superdrag']
# 59 : ['island of disco']
# 60 : ['buckley']
# 61 : ['warner music group']
# 62 : ['dracula', 'brianza']
# 63 : ['mark kramer']
# 64 : ['janet gaynor']
# 65 : ['fred hawkins']
# 66 : ['soundwave']
# 67 : ['song', 'summer', 'romance novel', 'drama']
# 68 : ['mohinder suresh']
# 69 : ['lenny']
# 70 : ['jordon dizon']
# 71 : ['jethro tull']
# 72 : ['example', 'video game']
# 73 : ['thomas whitham']
# 74 : ['gary paulsen']
# 75 : ['werner m. moser']
# 76 : ['the fish child']
# 77 : ['goltzius', 'the pelican company']
# 78 : ['football player']
# 79 : ["smokin' aces 2", "assasins' ball"]
# 80 : ['med']
# 81 : ['carol kicinski']
# 82 : ['hans dally']
# 83 : ['ken mcgoogan']
# 84 : ['sort', 'film', 'combat report']
# 85 : ['tenchu: wrath of heaven']
# 86 : ['michael visaroff']
# 87 : ['ace of base']
# 88 : ['cleopatra']
# 89 : ['nordenskiold']
# 90 : ['what', 'cube']
# 91 : ['villa deste']
# 92 : ['starkenburg']
# 93 : ['santa ana']
# 94 : ['carry on cruising']
# 95 : ['enno lerian']
# 96 : ['woody meets davy crewcut']
# 97 : ['bill wyman']
# 98 : ['jirina bohdalova']
# 99 : ['action film']
# 100 : ['cornwall bridge']
# 101 : ['aleksei kravchenko']
# 102 : ['language', 'act']
# 103 : ['yen']
# 104 : ['warner bros. records']
# 105 : ['person', 'politician', 'profession']
# 106 : ['drama film']
# 107 : ['rob renes']
# 108 : ['aldebaran']
# 109 : ['the congress']
# 110 : ['la boheme']
# 111 : ['name', 'folk rock album']
# 112 : ['kiss kiss']
# 113 : ['wife']
# 114 : ['skyclans destiny']
# 115 : ['ryuichi sakamoto']
# 116 : ['chicago']
# 117 : ['paul reubens']
# 118 : ['tourist film']
# 119 : ['epitaph records']
# 120 : ['caraboo']
# 121 : []
# 122 : ['kappa draconis']
# 123 : ['amy sherman-palladino']
# 124 : ['berlin']
# 125 : ['gameplay mode']
# 126 : ['darling lili']
# 127 : ['c. jack ellis']
# 128 : ['country', 'treaty']
# 129 : ['johnny russell']
# 130 : ['country', 'place']
# 131 : ['godzilla']
# 132 : ['vic frazier']
# 133 : ['sjafruddin prawiranegara']
# 134 : ['grete sultan']
# 135 : ['strega']
# 136 : ['georgia gibbs']
# 137 : ['cassiesteele']
# 138 : ['abduction', 'whom']
# 139 : ["what's a movie", 'stuart ford']
# 140 : ['roger molliens']
# 141 : ['bernthøler']
# 142 : ['hinze dam']
# 143 : ['hank cochran']
# 144 : ['eberhard kinzel']
# 145 : ['monogram pictures']
# 146 : ['leo bertos']
# 147 : ['grindhouse']
# 148 : ['country', 'way']
# 149 : ['hawkman']
# 150 : ['laura kirkpatrick']
# 151 : ['sanjog', 'bani sangini']
# 152 : ['growlanser iv', 'wayfarer of the time']
# 153 : ['monkey ball', 'banana blitz']
# 154 : ['the inner circle']
# 155 : ['rob margolies']
# 156 : ['piano player']
# 157 : ['life on a stick']
# 158 : ['language', 'harbour drift']
# 159 : ['eva isaksen']
# 160 : ["roc'n rope"]
# 161 : ['joseph-ferdinand daniel']
# 162 : ['drums of tahiti']
# 163 : ['philippe delorme']
# 164 : ['101180', '1998 sh9']
# 165 : ['gail harris']
# 166 : ['anatoliy matkevych']
# 167 : ['bernie graham']
# 168 : ['harry werner storz']
# 169 : ['jerry wald']
# 170 : ['ancient evil: scream of the mummy']
# 171 : ['empire earth']
# 172 : ['east peoria', 'illinois']
# 173 : ['fu', 'hong kong']
# 174 : ['silhouette mirage']
# 175 : ['european']
# 176 : ['canadian', 'william southam']
# 177 : ['vladimir baksheyev']
# 178 : ['paul phoenix']
# 179 : ['ray lewis']
# 180 : ['pati par']
# 181 : ['dj nelson']
# 182 : ['moon', 'georg ohm']
# 183 : ["what's a eurodance", 'ian van dahl']
# 184 : ['harvey lowe']
# 185 : ['lego', 'knights kingdom']
# 186 : ['dominican republic']
# 187 : ['english']
# 188 : ['alain sutter']
# 189 : ['language', 'road house']
# 190 : ['lee ho-jin']
# 191 : ['georg baselt']
# 192 : ['henry nielsen']
# 193 : ['the salamander']
# 194 : ['glikson']
# 195 : ['dave henderson']
# 196 : ['birth of a golem']
# 197 : ['carl-alfred schumacher']
# 198 : ['ezekiel f. chambers']
# 199 : ['magnant']
# 200 : ['chungking express']
# 201 : ['gail davis']
# 202 : ['stylistics']
# 203 : ['gwalior']
# 204 : ['carolin fink']
# 205 : ['thomas ostros']
# 206 : ['porsuk']
# 207 : ['example', 'video game']
# 208 : ['christy carlson romano']
# 209 : ['case', 'spell dump']
# 210 : ['phil manzanera']
# 211 : ['john f. mulholland, jr']
# 212 : ['iphiklos']
# 213 : ['the last good time']
# 214 : ['spanish']
# 215 : ['plotzensee']
# 216 : ['prince arthur', 'connaught']
# 217 : ['england', 'rik mayall']
# 218 : ['jack carter']
# 219 : ['earth']
# 220 : ['louise latimer']
# 221 : ['harold gore']
# 222 : ['man made']
# 223 : ['michael jackson', 'number ones']
# 224 : ['james c. dobbin']
# 225 : ['early music']
# 226 : ['ladykillers']
# 227 : ['ricardo delgado']
# 228 : ['a time to love', 'a time to die']
# 229 : ['constantinos mina']
# 230 : ['tom']
# 231 : ['battle for the sun']
# 232 : ['pierre samuel du pont de nemours']
# 233 : ['kind', 'music', 'work']
# 234 : ['archie maclaren']
# 235 : ['yuriy furta']
# 236 : ['italian', 'gaeta']
# 237 : ['karsten smith']
# 238 : ['ville vanni']
# 239 : ['name', 'game']
# 240 : ['gintama: the movie']
# 241 : ['kalyug']
# 242 : ['artist', 'album']
# 243 : ['italian']
# 244 : ['game', 'platform game']
# 245 : ['brazil']
# 246 : ['valencian community']
# 247 : ['mike altieri']
# 248 : ['netflix', 'three came home']
# 249 : ['yvonne ryding']
# 250 : ['supercalifragilis', 'oc']
# 251 : ['europe', 'barbara hicks']
# 252 : ['tillie k. fowler']
# 253 : ['italian']
# 254 : ['christoph grimm']
# 255 : ['anthony barry']
# 256 : ['otto nagel']
# 257 : ['columbia records']
# 258 : ['ellice']
# 259 : ['horst heldt']
# 260 : ['irish film board']
# 261 : ['alfredo zacarias']
# 262 : ['european']
# 263 : ['science fantasy']
# 264 : ['drum kit']
# 265 : ['milan vilotic']
# 266 : ['joseph satoshi fukahori']
# 267 : ['carlo ponti']
# 268 : ['joseph moxon']
# 269 : ['ram lakhan']
# 270 : ['european', 'henryk borowski']
# 271 : ["somethin' slick!"]
# 272 : ['walt disney pictures']
# 273 : ['corn']
# 274 : ['alex north']
# 275 : ['yoon bomi']
# 276 : ['name', 'football player', 'forward']
# 277 : ['golden fortress']
# 278 : ['sims 3', 'world adventures']
# 279 : ['hms e56']
# 280 : ['a. r. murugadoss']
# 281 : ['houston cougars']
# 282 : ['sjors en sjimmie en de gorilla']
# 283 : ['bob kane']
# 284 : ['mariella farre']
# 285 : ['glenn robinson iii']
# 286 : ['charles strouse']
# 287 : ['eduard boltrushevich']
# 288 : ['bonnie and clyde']
# 289 : ['mike']
# 290 : ['donaldhowk']
# 291 : ['haim amsalem']
# 292 : ['francis i', 'france']
# 293 : ['frøken kirkemus']
# 294 : ['james brown']
# 295 : ['deliver']
# 296 : ['roberto benigni']
# 297 : ['christopher mcquarrie']
# 298 : ['screenwriter']
# 299 : ['occupation', 'mutlu']
# 300 : ['antonio pagudo']
# 301 : ['love hurts']
# 302 : ['richard haldane', 'haldanes']
# 303 : ['nefertari']
# 304 : ['san giovanni bianco']
# 305 : ['the climax']
# 306 : ['film director']
# 307 : ['elisabeth nunziato']
# 308 : ['brian jones']
# 309 : ['matanuska', 'susitna']
# 310 : ['1952']
# 311 : ['world war', 'gerald robert osullivan']
# 312 : ['would joey']
# 313 : ['garfield']
# 314 : ['tracey ullman']
# 315 : ['kind', 'film', 'actress']
# 316 : ['henry gellibrand']
# 317 : ['christian gartner']
# 318 : ['john reynolds gardiner']
# 319 : ['lopburi']
# 320 : ['batman']
# 321 : ['germany']
# 322 : ['new wave']
# 323 : ['willies blues']
# 324 : ['kati kovacs']
# 325 : ['australian']
# 326 : ['mexico city']
# 327 : ['trent reznor']
# 328 : ['poochini']
# 329 : ['alpinia']
# 330 : ['tommy breen']
# 331 : ['style']
# 332 : ['bernadette strachan', 'europe']
# 333 : ['fort bend', 'texas']
# 334 : ['rock artist']
# 335 : ['howard storm']
# 336 : ['asphyxia']
# 337 : ['denmark']
# 338 : ['texarkana']
# 339 : ['asko sarkola']
# 340 : ['reno kiilerich']
# 341 : ['madita']
# 342 : ['john farnham']
# 343 : ['saving private ryan']
# 344 : ['marcos tebar']
# 345 : ['leonard proxauf']
# 346 : ['omaha road', '15']
# 347 : ['kahuna']
# 348 : ['william hamley']
# 349 : ['gender']
# 350 : ['trenton']
# 351 : ['ac']
# 352 : ['klaus-degenhard schmidt']
# 353 : ['david wiesner']
# 354 : ['gene taylor']
# 355 : ['pauline vanier']
# 356 : ['mukoma ngugi']
# 357 : ['hakaru hashimoto']
# 358 : ['movie', 'nothing']
# 359 : ['jonathan davis']
# 360 : ['ikaze']
# 361 : ['wild', 'club']
# 362 : ['so', 'love']
# 363 : ['orpheus', 'mgm records', 'capital records']
# 364 : ['shan serafin']
# 365 : ['title', 'film', 'horror movie']
# 366 : ['karin svensson smith']
# 367 : ['aep paphos f.c.']
# 368 : ['leonard b. stern']
# 369 : ['kim hyeung-bum']
# 370 : ['paul newlan']
# 371 : ['pete briggs']
# 372 : ['robert smith']
# 373 : ['juan pablo garat']
# 374 : ['devon', 'hannah cowley']
# 375 : ['gex: enter the gecko']
# 376 : ['rossy']
# 377 : ['tartina city']
# 378 : ['genre', 'music', 'album', 'dream']
# 379 : ['afonso alvares']
# 380 : ['ricochet']
# 381 : ['leo erdody']
# 382 : ['jorge i. dominguez']
# 383 : ['terminal city ricochet']
# 384 : ['rancho chico']
# 385 : ['cai chusheng']
# 386 : ['lucas demare']
# 387 : ['sydney']
# 388 : ['jay robinson']
# 389 : ['skopje']
# 390 : ['stockholm']
# 391 : ['k', 'rajagopal']
# 392 : ['everly brothers', 'country']
# 393 : ['paul donnelly']
# 394 : ['someone', 'cancer']
# 395 : ['kind', 'movie', 'corn']
# 396 : ['captain america']
# 397 : ['country', 'origin', 'tv show']
# 398 : ['mylo xyloto']
# 399 : ['floyd bannister']
# 400 : ['hans gunther van allen']
# 401 : ['sachche ka bol', 'bala']
# 402 : ['truth', 'language']
# 403 : ['wokingham']
# 404 : ['daniel sickles']
# 405 : ['the end of eternity']
# 406 : ['4689']
# 407 : ['streets']
# 408 : ['patsy rowlands']
# 409 : ['intersexion']
# 410 : ['pitcher', 'baseball']
# 411 : ['jabari asim']
# 412 : ['of forgotten men']
# 413 : ['helsinki']
# 414 : ['dutch', 'amsterdam']
# 415 : ['name', 'rock performer']
# 416 : ['silvio schroter']
# 417 : ['delly ranx']
# 418 : ['martin wagner']
# 419 : ['oldham athletic a.f.c']
# 420 : ['rhythm and blues']
# 421 : ['duke esper']
# 422 : ['france', 'daniel singer']
# 423 : ['mervat tallawy']
# 424 : ['country', 'playground']
# 425 : ['rendsburg']
# 426 : ['anime speed']
# 427 : ['call of duty: black ops ii']
# 428 : ['play']
# 429 : ['blazblue: calamity trigger']
# 430 : ['rip!']
# 431 : ['california', 'benji schwimmer']
# 432 : ['jocelyne lagarde']
# 433 : ['aleksei kostenko']
# 434 : ['william dominic austin']
# 435 : ['157753']
# 436 : ['george karl']
# 437 : ['tel aviv']
# 438 : ['a propos de nice']
# 439 : ['charles', 'prince of wales']
# 440 : ['woman', 'actress']
# 441 : ['game', 'single-player mode']
# 442 : ['charlie mason']
# 443 : ['bomberman touch 2', 'volcano party']
# 444 : ['masse broberg']
# 445 : ['dudley foster']
# 446 : ['frank oz']
# 447 : ['kinya aikawa']
# 448 : ['gerardus vossius']
# 449 : ['claudiano alves dos santos']
# 450 : ['weston']
# 451 : ['language', 'spike']
# 452 : ['pato branco']
# 453 : ['nicholas miccarelli iii']
# 454 : ['atv offroad fury 3']
# 455 : ['patsy tebeau']
# 456 : ['sheila larken']
# 457 : ['julio salvador']
# 458 : ['joao miguel']
# 459 : ['death', 'infarction']
# 460 : ['george ardisson']
# 461 : ['ron mcgovney']
# 462 : ['piano']
# 463 : ['paul shipton']
# 464 : ['canada']
# 465 : ['alemayo kebede']
# 466 : ['rockford']
# 467 : ['robert whitaker']
# 468 : ['tetsujin nijuhachi-go', 'hakuchu no zangetsu']
# 469 : ['gory guerrero']
# 470 : ['irina shayk']
# 471 : ['bushman']
# 472 : ['leone giraldoni']
# 473 : ['jenna lee']
# 474 : ['paul levain']
# 475 : ['brian molko']
# 476 : ['paris', 'texas']
# 477 : ['spike', 'buffy the vampire slayer']
# 478 : ['jeff manship']
# 479 : ['nikolai ostrovsky']
# 480 : ['vellinakshatram']
# 481 : ['country']
# 482 : ['the hunter']
# 483 : ['viswanatha nayakudu']
# 484 : ['george welch']
# 485 : ['tony castillo']
# 486 : ['jahangir']
# 487 : ['woodsboro']
# 488 : ['ruy guerra']
# 489 : ['emphysema']
# 490 : ['pat dillard']
# 491 : ['time']
# 492 : ['nicolas provost']
# 493 : ['america', 'pete candoli']
# 494 : ['what', 'russian', "d'artagnan", 'moscow']
# 495 : ['reginald mountain']
# 496 : ['stanley kubrick']
# 497 : ["alice's restaurant"]
# 498 : ['madame']
# 499 : ['walter bowman']
# 500 : ['bunker hill bunny']
# 501 : ['tom uren']
# 502 : ['4733']
# 503 : ['omoni oboli']
# 504 : ['rennes']
# 505 : ['4974']
# 506 : ['devin bronson']
# 507 : ['enrique amorim']
# 508 : ['nancy']
# 509 : ['platinum collection']
# 510 : ['greville janner', 'janner', 'braunstone']
# 511 : ['name', 'action-adventure game']
# 512 : ['sima yi']
# 513 : ['lion of the moguls']
# 514 : ['brazil', 'marcus viana']
# 515 : ['rock music artist']
# 516 : ['eric johnson']
# 517 : ['nascar']
# 518 : ['james foster']
# 519 : ['language', 'film foundry town']
# 520 : ['olga desmond']
# 521 : ['ludwig wittgenstein']
# 522 : ['stanislav kostov']
# 523 : ['bandai']
# 524 : ['fred quimby']
# 525 : ['apollo 13']
# 526 : ['constance towers']
# 527 : ['lodz']
# 528 : ['butterscotch']
# 529 : ['riccardo primo']
# 530 : ['bitterblue']
# 531 : ['aa']
# 532 : ['codemasters']
# 533 : ['acclaim entertainment']
# 534 : ['villa!']
# 535 : ['uep systems']
# 536 : ['ghassan tueni']
# 537 : ['mahendranath gupta']
# 538 : ['azerbaijan']
# 539 : ['voice actor']
# 540 : ['airbourne']
# 541 : ['big dream']
# 542 : ['louis agassiz shaw', 'jr']
# 543 : ['john heitinga']
# 544 : ['john evan thomas']
# 545 : ['sound', 'thunder', 'type', 'music']
# 546 : ['boyd irwin']
# 547 : ['siouxsie sioux']
# 548 : ['damon knight']
# 549 : ['african american']
# 550 : ['ralph fox']
# 551 : ['believe you me']
# 552 : ['pirates of the caribbean']
# 553 : ['ron canada']
# 554 : ['mashed']
# 555 : ['country', 'lamb']
# 556 : ['kosova airlines']
# 557 : ['thea foss']
# 558 : ['person', 'profession model', 'person']
# 559 : ['mazu daoyi']
# 560 : ['hungary', 'bela barsy']
# 561 : ['mezcala']
# 562 : ['copenhagen']
# 563 : ['tom urbani']
# 564 : ['darashaw nosherwan wadia']
# 565 : ['sort', 'music', 'recitation']
# 566 : ['vahan gevorgyan']
# 567 : ['andy todd']
# 568 : ['jane swisshelm']
# 569 : ['movie', 'documentary film']
# 570 : ['magic waltz']
# 571 : ['john b. haskin']
# 572 : ['american', 'world war ii']
# 573 : ['european', 'matteo momente']
# 574 : ['sybil']
# 575 : ['karl burdach']
# 576 : ['bill, the galactic hero']
# 577 : ['rollergirls']
# 578 : ['artist', 'album truth']
# 579 : ['adrien robinson']
# 580 : ['lysander spooner']
# 581 : ['doug west']
# 582 : ['jack cooley']
# 583 : ['jurriaan andriessen']
# 584 : ['dmw greer']
# 585 : ['black rock']
# 586 : ['philadelphia']
# 587 : ['lavern baker']
# 588 : ['transformers 2']
# 589 : ['chaikin']
# 590 : ['european']
# 591 : ['astra super stars']
# 592 : ['west coast', 'richard a. jones']
# 593 : ['parijat']
# 594 : ['woman of rome']
# 595 : ['michael kenworthy']
# 596 : ['marek koterski']
# 597 : ["chappelle's"]
# 598 : ['yeo hyo-jin']
# 599 : ['katie cassidy']
# 600 : ['brothers in arms ds']
# 601 : ['huy']
# 602 : ['george c. baker']
# 603 : ['arthur hallam']
# 604 : ['new wave']
# 605 : ['joseph taylor robinson']
# 606 : ['william henry allen']
# 607 : ['name', 'forward', 'football']
# 608 : ['melchior berri']
# 609 : ['toronto']
# 610 : ['johan inger']
# 611 : ['salem', 'tamil nadu']
# 612 : ['susan owens']
# 613 : ['example', 'game']
# 614 : ['lawless']
# 615 : ['max alexander']
# 616 : ['swedish', 'gerard de geer']
# 617 : ['master blasters']
# 618 : ['corpus christi']
# 619 : ['neil hamilton fairley']
# 620 : ['nightmare city']
# 621 : ['the scalphunters']
# 622 : ['rochdale']
# 623 : ['lynette boggs']
# 624 : ['the natural order']
# 625 : ['sun']
# 626 : ['halifax']
# 627 : ['baltasar de la cueva', 'castellar']
# 628 : ['georges doriot']
# 629 : ['aneek dhar']
# 630 : ['isle of wight']
# 631 : ['ralf jager']
# 632 : ['wilhelm beck']
# 633 : ['michael staniforth', 'united kingdom', 'united states']
# 634 : ['westminster abbey']
# 635 : ['xiu xiu']
# 636 : ['hal roach']
# 637 : ['hwang byung-ju']
# 638 : ['lou perryman']
# 639 : ['palm springs follies']
# 640 : ['bobby durham']
# 641 : ['film', 'comedy']
# 642 : ['movie']
# 643 : ['lars eriksson']
# 644 : ['birmingham']
# 645 : ['david vanian']
# 646 : ['east', 'paris theodore']
# 647 : ['gerardo esquivel']
# 648 : ['agnieszka holland']
# 649 : ['delicious vinyl']
# 650 : ['victor victoria']
# 651 : ['live from across the pond']
# 652 : ['name']
# 653 : ['american']
# 654 : ['linda ronstadt']
# 655 : ['who', 'material world']
# 656 : ['musician', 'film']
# 657 : ['djoumin sangare']
# 658 : ['lucy russell']
# 659 : ['name', 'action film']
# 660 : ['p.a.r', 'c', 'e']
# 661 : ['chance and']
# 662 : ['mosfilm']
# 663 : ['artist', 'pop music']
# 664 : ['switchblade symphony']
# 665 : ['character']
# 666 : ['saigon']
# 667 : ['yuriko yamamoto']
# 668 : ['xavier montsalvatge']
# 669 : ['you aint woman enough']
# 670 : ['artist', 'album']
# 671 : ['kristinrose']
# 672 : ['voice actor']
# 673 : ['ronnie milsap']
# 674 : ['bartolome blanche']
# 675 : ['matt lindstrom']
# 676 : ['edmund grierson']
# 677 : ['glove']
# 678 : ['micah lawrence']
# 679 : ['buch in de bajes']
# 680 : ['attack of the killer tomatoes']
# 681 : ['pavel badea']
# 682 : ['campo de ourique']
# 683 : ['marsalis standard', 'who']
# 684 : ['nicholas crafts']
# 685 : ['tim burton']
# 686 : ['ed alonzo']
# 687 : ['russ meyer']
# 688 : ['carlos', 'bourbon-two sicilies']
# 689 : ['bheja fry']
# 690 : ['frederick benteen']
# 691 : ['beloved']
# 692 : ['shimla']
# 693 : ['album', 'rock']
# 694 : ['lillian evanti']
# 695 : ['la commare secca']
# 696 : ['cino da pistoia']
# 697 : ['steve helstrip']
# 698 : ['yes, madam']
# 699 : ['romance novel']
# 700 : ['temple grandin']
# 701 : ['buron']
# 702 : ['altshause']
# 703 : ['emilio comte']
# 704 : ['catfish keith']
# 705 : ['the angry river']
# 706 : ['international superstar soccer']
# 707 : ['yevgeni tarasov']
# 708 : ['jett jackson']
# 709 : ['matthew karatz']
# 710 : ['renu saluja']
# 711 : ['country']
# 712 : ['overkill']
# 713 : ['us', 'leo nocentelli']
# 714 : ['mc breed']
# 715 : ['martin gabel']
# 716 : ['derek rutherford']
# 717 : ['defender', 'football']
# 718 : ['foo fighters']
# 719 : ['mortimer folchart']
# 720 : ['taxi']
# 721 : ['red angel']
# 722 : ['shehnai']
# 723 : ['film', 'genre', 'film']
# 724 : ['alien']
# 725 : ['paul alexandrovich', 'russia']
# 726 : ['irish', 'london']
# 727 : ['garrett hedlund']
# 728 : ['camelia jordana']
# 729 : ['antwerp']
# 730 : ['progressive rock']
# 731 : ['home for christmas']
# 732 : ['paul delay']
# 733 : ['giovanni tuccari']
# 734 : ['mary lou fallis']
# 735 : ['theodore j. pahle']
# 736 : ['road']
# 737 : ['kind', 'tv show', 'rerun show']
# 738 : ['film']
# 739 : ['german canadian']
# 740 : ['david dunn']
# 741 : ['hungarian']
# 742 : ['artist']
# 743 : ['state of the union']
# 744 : ['dar williams']
# 745 : ['palermo']
# 746 : ['what', '20th century fox']
# 747 : ['moira lynd']
# 748 : ['name', 'player']
# 749 : ['afranio']
# 750 : ['valeri petrov']
# 751 : ['type', 'music']
# 752 : ['rolf henne']
# 753 : ['film', 'film']
# 754 : ['eva marcille']
# 755 : ['dark man']
# 756 : ['mary ann sieghart']
# 757 : ['dozer']
# 758 : ['dick clement']
# 759 : ['neon genesis evangelion', 'iron maiden']
# 760 : ['jan mark']
# 761 : ['nu metal']
# 762 : ['margaret way']
# 763 : ['nefertiti']
# 764 : ['roger corman']
# 765 : ['orange county']
# 766 : ['movie', 'horror']
# 767 : ['michael nyman']
# 768 : ['hamzabari']
# 769 : ['urs buhler']
# 770 : ['walk hard', 'dewey cox']
# 771 : ['jayceon terrell taylor']
# 772 : ['mississippi', 'nathaniel h. harris']
# 773 : ['raphael martinho']
# 774 : ['sharpe']
# 775 : ['cecil b. demille']
# 776 : ['frances marion']
# 777 : ['country', 'trust']
# 778 : ['shooter game']
# 779 : ['nik abdul aziz nik mat']
# 780 : ['sandefjord']
# 781 : ['kind', 'movie', 'love', 'courage']
# 782 : ['chin-hui tsao']
# 783 : ['edward', 'portugal']
# 784 : ['arthur teele']
# 785 : ['oscar peterson', 'jerome kern songbook']
# 786 : ['david kulcsar']
# 787 : ['yarra river']
# 788 : ['nidwalden']
# 789 : ['richmond bridge', 'london']
# 790 : ['jim huber']
# 791 : ['drive a crooked road']
# 792 : ['language', 'film', 'love', 'war']
# 793 : ['tvxq']
# 794 : ['david livingston']
# 795 : ['harley sanford jones']
# 796 : ['type', 'music genre']
# 797 : ['adrian mcpherson']
# 798 : ['kavi']
# 799 : ['country']
# 800 : ['dana stevens']
# 801 : ['russian', 'prince paul', 'yugoslavia']
# 802 : ['vidyasagar']
# 803 : ['max joseph von pettenkofer']
# 804 : ['jazz musician']
# 805 : ['ready to run']
# 806 : ['alicia aller']
# 807 : ['melbourne']
# 808 : ['yanina zhejmo']
# 809 : ['shimako iwai']
# 810 : ['luther gulick']
# 811 : ['kewanee', 'illinois']
# 812 : ['humayra abedin']
# 813 : ['ogedays']
# 814 : ['jim flynn']
# 815 : ['martin abena']
# 816 : ['joe burns', 'american']
# 817 : ['david brazier']
# 818 : ['country', 'devil', 'daniel webster']
# 819 : ['force']
# 820 : ['music artist']
# 821 : ['osamu tezuka']
# 822 : ['stefan logi magnusson']
# 823 : ['arenac']
# 824 : ['10603', '1996 uf4']
# 825 : ['michigan']
# 826 : ['lloyd bacon']
# 827 : ['su tong']
# 828 : ['ten']
# 829 : ['edwin r. murray']
# 830 : ['andrew scheinman']
# 831 : ['gap inc']
# 832 : ['nolan baumgartner']
# 833 : ['leslie thompkins']
# 834 : ['dallas roberts']
# 835 : ['name', 'person', 'architect']
# 836 : ['jesse wharton']
# 837 : ['frederick j. karch']
# 838 : ['fauziah latiff']
# 839 : ['ken hughes']
# 840 : ['strafford']
# 841 : ['lamar thomas']
# 842 : ['chris hussey']
# 843 : ['william j. obrien']
# 844 : ['sp']
# 845 : ['hands up']
# 846 : ['merry christmas, mr. lawrence']
# 847 : ['paul ekins']
# 848 : ['hamish bond']
# 849 : ['billy walton']
# 850 : ['production company']
# 851 : ['liverpool']
# 852 : ['gender']
# 853 : ['dan gerrity']
# 854 : ['mervyn leroy']
# 855 : ['french', 'lille']
# 856 : ['christofnor']
# 857 : ['monastery', 'sendomir']
# 858 : ['cordelia chase']
# 859 : ['gaby dunn']
# 860 : ['lars krogh gerson']
# 861 : ['dahmer vs. gacy']
# 862 : ['hed pe']
# 863 : ['language', 'gift']
# 864 : ['netflix']
# 865 : ['bugs henderson']
# 866 : ['faithless']
# 867 : ['bradley pierce']
# 868 : ['twilight']
# 869 : ['minnesota', 'catharine mackinnon']
# 870 : ['all about eve']
# 871 : ['erwin planck']
# 872 : ['gy waldron']
# 873 : ['alexander hamilton']
# 874 : ['the stratton story']
# 875 : ['david grisman']
# 876 : ['nsw']
# 877 : ['man', 'position defender', 'soccer']
# 878 : ['gaza city']
# 879 : ['small graces']
# 880 : ['cowgate']
# 881 : ['edward a. devore, jr']
# 882 : ['walter gerth']
# 883 : ['doomtree']
# 884 : ['harold hardman']
# 885 : ['the tourist']
# 886 : ['denis shcherbak']
# 887 : ['ido mosseri']
# 888 : ['ghulam azam']
# 889 : ['hooshang amirahmadi']
# 890 : ['john william finn']
# 891 : ['straight shooter']
# 892 : ['jonathan smith']
# 893 : ['amazing grace']
# 894 : ['gianna dangelo']
# 895 : ['pete seeger']
# 896 : ['summer glau']
# 897 : ['the champ']
# 898 : ['country', 'origin']
# 899 : ['presque isle']
# 900 : ['jose luis grant']
# 901 : ['artist', 'album']
# 902 : ["what's", 'banpresto']
# 903 : ['football forward']
# 904 : ['yusuke kawakita']
# 905 : ['david quinn']
# 906 : ['country', 'transplant movie produce']
# 907 : ['street fighter']
# 908 : ['type', 'film']
# 909 : ['country music']
# 910 : ['ferdinand columbus']
# 911 : ['maarty leunen']
# 912 : ['paul brooks']
# 913 : ['jasper']
# 914 : ['arab']
# 915 : ['amazonas']
# 916 : ['langston hughes']
# 917 : ['ivan okhlobystin']
# 918 : ['tamara rhodes']
# 919 : ['let it shine']
# 920 : ['francisco tarrega']
# 921 : ['abdollah nouri']
# 922 : ['language']
# 923 : ['howie dorough']
# 924 : ['orest miller']
# 925 : ['game']
# 926 : ['butcher']
# 927 : ['abraham haskel taub']
# 928 : ['example', 'action role-playing game']
# 929 : ['berry kroeger']
# 930 : ['thiruppu munai']
# 931 : ['tomas mac giolla']
# 932 : ['rudy arias']
# 933 : ['the papercut chronicles']
# 934 : ['john corrill']
# 935 : ['cuckfield']
# 936 : ['corrado mantoni']
# 937 : ['american', 'chicago']
# 938 : ['poland', 'marian lalewicz']
# 939 : ['robert lawrence leopold']
# 940 : ['joey osbourne']
# 941 : ['german']
# 942 : ['souli']
# 943 : ['type', 'gameplay mode', 'maelstrom']
# 944 : ['ashmore', 'cartier islands']
# 945 : ['robert mckinley']
# 946 : ['player', 'goalkeeper', 'football']
# 947 : ['strangers']
# 948 : ['borko milenkovic']
# 949 : ['kelly slater']
# 950 : ['prabhu']
# 951 : ['walter hampden', 'united states', 'canada']
# 952 : ['power rangers dino thunder', 'american']
# 953 : ['cook county', 'illinois']
# 954 : ['bonnie hollingsworth']
# 955 : ['tower of london']
# 956 : ['chikara sakaguchi']
# 957 : ['jerametrius butler']
# 958 : ['hamburg']
# 959 : ['dice raw']
# 960 : ['jerry zirsanga']
# 961 : ['las colonias']
# 962 : ['robert bennett']
# 963 : ['disneys', 'revenge']
# 964 : ['georgi yumatov']
# 965 : ['asian', 'my beloved']
# 966 : ['john e. smith']
# 967 : ['london']
# 968 : ['warbringer']
# 969 : ['alexandre bilodeau', 'which gender']
# 970 : ['madeleine martin']
# 971 : ['shaikh ayaz']
# 972 : ['nick lowe']
# 973 : ['portrait of sinatra']
# 974 : ['haven']
# 975 : []
# 976 : ['ian dobson']
# 977 : ['rayver cruz']
# 978 : ['country', 'origin', 'darling']
# 979 : ['williamsburg']
# 980 : ['he']
# 981 : ['leslie s. hiscott']
# 982 : ['fatty']
# 983 : ['the twilight zone']
# 984 : ['heat']
# 985 : ['joe satriani']
# 986 : ['alec james']
# 987 : ['lynwood']
# 988 : ['mexico']
# 989 : ['abandoned garden']
# 990 : ['first on the moon']
# 991 : ['joy sengupta']
# 992 : ['lew wallace']
# 993 : ['name', 'story']
# 994 : ['byron haskin']
# 995 : ['sarvakalashala']
# 996 : ['beverly bivens']
# 997 : ['hans-joachim ressel']
# 998 : ['fredericksburg', 'virginia']
# 999 : ['fiction', 'game', 'single-player']
# 1000 : ['niki de saint phalle']
# 1001 : ['teddy']
# 1002 : ['richard burns']
# 1003 : ['michael lewis']
# 1004 : ['queensland']
# 1005 : ['james v. hartinger']
# 1006 : ['name', 'game']
# 1007 : ['revenge of the pink panther']
# 1008 : ['andrew johnson']
# 1009 : ['folly']
# 1010 : ['ani']
# 1011 : ['name', 'politician']
# 1012 : ['series', 'fear', 'episode']
# 1013 : ['jerome woods']
# 1014 : ['artist', 'album']
# 1015 : ['nilton']
# 1016 : ['hammerfest']
# 1017 : ['simonne monet', 'chartrand']
# 1018 : ['i think i love my wife']
# 1019 : ['helen taft manning']
# 1020 : ['andromeda']
# 1021 : ['new westminster']
# 1022 : ['pieraldo ferrante']
# 1023 : ['winter', 'quin']
# 1024 : ['rome']
# 1025 : ['mike stark']
# 1026 : ['brayan pena']
# 1027 : ['emo']
# 1028 : ['hephaisto']
# 1029 : ['name', 'city', 'mountain time zone']
# 1030 : ['hrazdan']
# 1031 : ['lambros lambrou']
# 1032 : ['politician']
# 1033 : ['modernism']
# 1034 : ['camilla von hollay']
# 1035 : ['monte collins']
# 1036 : ['tyler green']
# 1037 : ['kind', 'game', 'food']
# 1038 : ['canadian', 'howard cable']
# 1039 : ['disciple']
# 1040 : ['nigel slater']
# 1041 : ['spinnerette']
# 1042 : ['yonkers']
# 1043 : ['el rio de luz']
# 1044 : ['antwerp']
# 1045 : ['goalkeeper', 'football']
# 1046 : ['ncaa']
# 1047 : ['the man outside']
# 1048 : ['carnatic']
# 1049 : ['kseniya rappoport']
# 1050 : ['sean dundee']
# 1051 : ['thomas day']
# 1052 : ['pat roach']
# 1053 : ['geneva']
# 1054 : ['john b. calhoun']
# 1055 : ['barbara mularczyk']
# 1056 : ['moscow', 'hudson']
# 1057 : ['joe kracher']
# 1058 : ['george gilbert scott']
# 1059 : ['who', 'halloween resurrection']
# 1060 : ['fanni gyarmati']
# 1061 : ['morten rasmussen']
# 1062 : ['carl weingarten']
# 1063 : ['audrey williams']
# 1064 : ['j']
# 1065 : ['temmink: the ultimate fight']
# 1066 : ['der']
# 1067 : ['italy']
# 1068 : ['pashtoons social democratic party']
# 1069 : ['genre', 'music', 'trumpet']
# 1070 : ['csx a', 'line']
# 1071 : ['katerini']
# 1072 : ['trans canada highway']
# 1073 : ['spongebob']
# 1074 : ['game', 'multiplayer']
# 1075 : ['luan garcia teixeira']
# 1076 : ['the orb']
# 1077 : ['porochista khakpour']
# 1078 : ['til schweiger']
# 1079 : ['what', 'maula', 'masood azhar']
# 1080 : ['john brahm']
# 1081 : ['amina figarova']
# 1082 : ['andrew ellis']
# 1083 : ['someone', 'attention deficit hyperactivity disorder']
# 1084 : ['john campbell']
# 1085 : ['album', 'artist']
# 1086 : ['60']
# 1087 : ['lynyrd skynyrd']
# 1088 : ['west', 'bolt birch']
# 1089 : ['8']
# 1090 : ['returns']
# 1091 : ['hermann von mallinckrodt']
# 1092 : ['netflix', 'tale of two sisters']
# 1093 : ['drogo', 'champagne']
# 1094 : ['gothic']
# 1095 : ['bruce ricker']
# 1096 : ['leigh anne tuohy']
# 1097 : ['xiao shan', 'china', 'hong kong']
# 1098 : ['robert gadocha']
# 1099 : ['paul a. winn']
# 1100 : ['sort', 'film', 'bread']
# 1101 : ['genesis', 'revelation']
# 1102 : ['ronnie foster']
# 1103 : ['gracie allen']
# 1104 : ['benedetto gennari ii']
# 1105 : ['vagif mustafazade']
# 1106 : ['timothy fok']
# 1107 : ['new york city', 'william morgan shuster']
# 1108 : ['tom flores']
# 1109 : ['netflix', 'bobby']
# 1110 : ['max graham']
# 1111 : ['betty luster']
# 1112 : ['john ake']
# 1113 : ['germany', 'iranian']
# 1114 : ['asteroid belt', 'sun']
# 1115 : ['artist', 'guitar']
# 1116 : ['drama film']
# 1117 : ['johann von vasary']
# 1118 : ['maja ostaszewska']
# 1119 : ['jean jacques clark']
# 1120 : ['raffaele di mario']
# 1121 : ['william gillette']
# 1122 : ['kyle drabek']
# 1123 : ['country']
# 1124 : ['country', 'film panic']
# 1125 : ['home']
# 1126 : ['united states', 'roderick wetherill']
# 1127 : ['greatest kiss']
# 1128 : ['claudia lonow']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-85b5b029018f> in <module>()
#       5     print(index,":",q_entities)
#       6     for entity in q_entities:
# ----> 7       for item in get_dbpedia_candidates(entity):
#       8           items.append(item['id'])
#       9     dbpedia_items.append(items)
#
# <ipython-input-72-84443e88a5ca> in get_dbpedia_candidates(label)
#       6     # type: One of the following values: form, form, item, lexeme, property, sense, sense
#       7     query_path = "http://lookup.dbpedia.org/api/search?query=QUERY_TEXT&maxResults=10&type=class&format=json"
# ----> 8     r = requests.get(query_path.replace("QUERY_TEXT",label))
#       9     for answer in r.json()['docs']:
#      10       if ('label' in answer) and ('resource' in answer):
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     665             # Redirect resolving generator.
#     666             gen = self.resolve_redirects(r, request, **kwargs)
# --> 667             history = [resp for resp in gen]
#     668         else:
#     669             history = []
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in <listcomp>(.0)
#     665             # Redirect resolving generator.
#     666             gen = self.resolve_redirects(r, request, **kwargs)
# --> 667             history = [resp for resp in gen]
#     668         else:
#     669             history = []
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     243                     proxies=proxies,
#     244                     allow_redirects=False,
# --> 245                     **adapter_kwargs
#     246                 )
#     247
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     decode_content=False,
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#     452
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df['dbpedia_items']=dbpedia_items
df.to_csv('wsq-dbpedia.csv')
df.head()

# %% [markdown]
# # Evaluation

# %%
# %%capture
# !pip install unidecode

# %%
def evaluate_labels(true_list,pred_list):
  index = 0
  tp, tn, fp, fn = 0, 0, 0, 0
  empty_values = 0
  for l1 in true_list:
    predicted_values = pred_list[index]
    if (len(predicted_values) == 0):
      empty_values += 1
    elif (l1[0] not in predicted_values):
      fn += 1
    else:  
      for l2 in predicted_values:
        if (l2 in l1):
          tp += 1
        else:
          fp += 1
    index += 1
    if (index % 1000 == 0):
      print(index)
  print("Total:",index)
  print("Empty Values:",empty_values)
  print("TruePositives:",tp,"TrueNegatives:",tn,"FalsePositives:",fp,"FalseNegatives:",fn)
  precision = tp / (fp + tp)
  print("Precission:",precision)
  recall = tp / (fn + tp)
  print("Recall:",recall)
  f1 = 2 * ((precision*recall)/(precision+recall))
  print("F1:",f1)

# %%
my_df = df[df.predicate.str.contains('P',case=False)]
my_df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question      subject_label  \
# 0                        Where did roger marquis die      Roger Marquis
# 1          what was the cause of death of yves klein         Yves Klein
# 2              What position does carlos gomez play?       Carlos Gómez
# 3               how does engelbert zaschka identify   Engelbert Zaschka
# 4  what position does pee wee reese play in baseball      Pee Wee Reese
#
#                         predicate_label           object_label  \
# 0                        place of death                Holyoke
# 1                        cause of death  myocardial infarction
# 2  position played on team / speciality         center fielder
# 3                         sex or gender                   male
# 4  position played on team / speciality              shortstop
#
#                 entity                                         wiki_items
# 0      [roger marquis]                               [Q7358592, Q7358590]
# 1         [yves klein]  [Q154335, Q98233558, Q8062325, Q92397997, Q806...
# 2       [carlos gomez]  [Q949506, Q203210, Q51944192, Q2747238, Q50421...
# 3  [engelbert zaschka]                                           [Q62498]
# 4      [pee wee reese]                                          [Q182485]

# %%
# NER Performance
import unidecode
y_true = [[unidecode.unidecode(i).lower().replace(" ","_")] for i in my_df['subject_label']]
y_pred = []
for entities in my_df['entity']:
  norm_entities = []
  for entity in entities:
    norm_entities.append(unidecode.unidecode(entity).lower().replace(" ","_"))
  y_pred.append(norm_entities)
evaluate_labels(y_true,y_pred)
# Out:
# 1000
# 2000
# 3000
# 4000
# Total: 4296
# Empty Values: 6
# TruePositives: 3043 TrueNegatives: 0 FalsePositives: 266 FalseNegatives: 1248
# Precission: 0.919613176186159
# Recall: 0.7091587042647401
# F1: 0.8007894736842105

# %%
# Wikidata Entity Linking Performance
y_true = [[i] for i in my_df['subject']]
y_pred = my_df['wiki_items'].tolist()
evaluate_labels(y_true,y_pred)
# Out:
# 1000
# 2000
# 3000
# 4000
# Total: 4296
# Empty Values: 110
# TruePositives: 3382 TrueNegatives: 0 FalsePositives: 12089 FalseNegatives: 815
# Precission: 0.21860254670027793
# Recall: 0.8058136764355492
# F1: 0.3439088875330486
