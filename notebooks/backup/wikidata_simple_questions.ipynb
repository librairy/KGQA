# %%
# %%capture
# !pip3 install sparqlwrapper

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/askplatypus/wikidata-simplequestions/master/annotated_wd_data_test_answerable.txt', sep="\t", index_col=False, header=None, names=['subject','predicate','object','question'])
df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question
# 0                        Where did roger marquis die
# 1          what was the cause of death of yves klein
# 2              What position does carlos gomez play?
# 3               how does engelbert zaschka identify
# 4  what position does pee wee reese play in baseball

# %%
import time
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

cache = {}
def get_wikidata_label(entity):
    if (entity in cache):
      print("use of cache!")
      return cache[entity]
    query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
        PREFIX wd: <http://www.wikidata.org/entity/> 
        SELECT  *
        WHERE {
            wd:ENTITY rdfs:label ?label .
            FILTER (langMatches( lang(?label), "EN" ) )
          } 
        LIMIT 1
        """
    query_text = query.replace('ENTITY',entity)
    sparql.setQuery(query_text)
    result = ""
    while (result == ""):
      try:
          ret = sparql.queryAndConvert()
          if (len(ret["results"]["bindings"]) == 0):
            result = "-"
          for r in ret["results"]["bindings"]:
              result = r['label']['value']
      except Exception as e:
          print("Error on wikidata query:",e)
          print("Waiting for 5.0 seconds..")
          time.sleep(5.0)
    cache[entity] = result
    return result

# %%
object_labels = []
subject_labels = []
predicate_labels = []

# %%
rows = df.to_numpy().tolist()
index = 0
for row in rows[index:]:
    print(index,":",row)
    subject_labels.append(get_wikidata_label(row[0])) #subject
    predicate_labels.append(get_wikidata_label(row[1].replace("R","P"))) #predicate
    object_labels.append(get_wikidata_label(row[2])) #object
    if (index % 100 == 0 ):
        print("Labels Identified:",index,"Cache Size:",len(cache))
    index += 1
print(len(object_labels),"labels retrieved!")
# Out:
# Streaming output truncated to the last 5000 lines.
# 3741 : ['Q2266283', 'P364', 'Q1860', 'what language was the angel wore red in?']
# use of cache!
# use of cache!
# use of cache!
# 3742 : ['Q5487599', 'R40', 'Q207544', 'Who was a parent of frank joslyn baum']
# use of cache!
# 3743 : ['Q35149', 'R138', 'Q1272', 'What has been named after wilhelm röntgen']
# use of cache!
# 3744 : ['Q4004117', 'P495', 'Q38', 'what country did the film ripped off take place in']
# use of cache!
# use of cache!
# 3745 : ['Q1173086', 'P136', 'Q203720', 'what type of music does dave alvin play']
# use of cache!
# 3746 : ['Q2614390', 'P31', 'Q3863', 'what type of celestial object is 20879 chengyuhsuan']
# use of cache!
# use of cache!
# 3747 : ['Q731169', 'P136', 'Q208189', 'What genre is theocracy in?']
# use of cache!
# 3748 : ['Q6607', 'R1303', 'Q11792043', 'Who played the guitar?']
# use of cache!
# use of cache!
# 3749 : ['Q10465267', 'P136', 'Q1800833', 'new york doll is considered what type of motion picture?']
# use of cache!
# 3750 : ['Q3607332', 'P27', 'Q17', "what is akihiko ishizumi's nationality?"]
# use of cache!
# use of cache!
# 3751 : ['Q3719665', 'P495', 'Q30', 'what country is he-man & she-ra: a christmas special from']
# use of cache!
# use of cache!
# 3752 : ['Q934639', 'P21', 'Q6581072', "What is zsuzsanna rácz's gender"]
# use of cache!
# use of cache!
# 3753 : ['Q2565992', 'P175', 'Q207706', 'Who is the artist of the ultimate collection album?']
# use of cache!
# 3754 : ['Q798811', 'P495', 'Q145', 'what country is the film underworld filmed in?']
# use of cache!
# use of cache!
# 3755 : ['Q1095411', 'P20', 'Q372454', 'where did clarence emir allen die']
# use of cache!
# 3756 : ['Q11229509', 'P175', 'Q269532', 'love is the message is an album by what singer?']
# use of cache!
# 3757 : ['Q7934973', 'P136', 'Q270948', 'what type of game is virtual hiryū no ken?']
# use of cache!
# use of cache!
# 3758 : ['Q7638765', 'P113', 'Q6587859', 'Name an airport in which sunair operates.']
# use of cache!
# 3759 : ['Q2252587', 'P364', 'Q1860', 'what language is spoken in the film kansas raiders?']
# use of cache!
# use of cache!
# 3760 : ['Q7988400', 'P175', 'Q321806', 'What artist produced the album Western Underground?']
# use of cache!
# 3761 : ['Q17485583', 'P413', 'Q280658', 'What position did park sung-jin play']
# use of cache!
# use of cache!
# 3762 : ['Q437', 'R19', 'Q553524', 'Who was born in ljubljana?']
# use of cache!
# use of cache!
# 3763 : ['Q7717328', 'P175', 'Q560153', 'what artist is featured on the best of ub40, volume 1']
# use of cache!
# 3764 : ['Q3731502', 'P27', 'Q30', 'where is eric louzil from']
# use of cache!
# use of cache!
# 3765 : ['Q1944630', 'P21', 'Q6581072', 'What is the gender of monika gabriel?']
# use of cache!
# use of cache!
# 3766 : ['Q47048', 'R19', 'Q649776', 'Name someone who was born in oulu']
# use of cache!
# 3767 : ['Q4718915', 'P19', 'Q340', 'where was the birthplace of alexander gaden']
# use of cache!
# use of cache!
# 3768 : ['Q1304731', 'P495', 'Q29', 'Where was who can kill a child? filmed?']
# use of cache!
# use of cache!
# 3769 : ['Q336286', 'R413', 'Q6739967', 'Who was a retired football defender player?']
# use of cache!
# use of cache!
# 3770 : ['Q2164731', 'P509', 'Q12152', "what illness caused isaac witkin's death"]
# use of cache!
# use of cache!
# 3771 : ['Q4057980', 'P413', 'Q336286', 'whats adriano spadoto position']
# use of cache!
# use of cache!
# 3772 : ['Q4465', 'R162', 'Q3567456', "what's a lesser known film that peter jackson produced"]
# use of cache!
# 3773 : ['Q2464153', 'P20', 'Q9949', 'Where did heintje davids die']
# use of cache!
# 3774 : ['Q3414816', 'P495', 'Q38', 'what country released like two crocodiles']
# use of cache!
# use of cache!
# 3775 : ['Q56149', 'P138', 'Q23', 'What was washington county named after']
# use of cache!
# 3776 : ['Q17345033', 'P21', 'Q6581072', "What is arja pessa's gender"]
# use of cache!
# use of cache!
# 3777 : ['Q738152', 'P364', 'Q1860', 'What language is the green hornet in?']
# use of cache!
# use of cache!
# 3778 : ['Q3044376', 'P27', 'Q30', 'Which country is cydney bernard from?']
# use of cache!
# use of cache!
# 3779 : ['Q14712693', 'P149', 'Q1513688', 'What is the architectural style of lee-fendall house?']
# use of cache!
# 3780 : ['Q5214843', 'P27', 'Q30', 'What nationality is dana stone']
# use of cache!
# use of cache!
# 3781 : ['Q2079498', 'P178', 'Q1049502', 'who is the developer of the computer videogame binary land']
# use of cache!
# use of cache!
# 3782 : ['Q1574428', 'P19', 'Q174', 'Where in Brazil was alexandre luiz fernandes born?']
# use of cache!
# use of cache!
# 3783 : ['Q5972292', 'P27', 'Q30', 'which country is john mahaffey from']
# use of cache!
# use of cache!
# 3784 : ['Q1400', 'P17', 'Q30', 'where is pennsylvania situated']
# use of cache!
# use of cache!
# use of cache!
# 3785 : ['Q451216', 'P19', 'Q23661', 'Where was jessica napier born?']
# use of cache!
# use of cache!
# 3786 : ['Q188473', 'R136', 'Q16174790', 'what movie is action film']
# use of cache!
# use of cache!
# 3787 : ['Q3520173', 'P136', 'Q645928', 'what is the genre of the film the butler']
# use of cache!
# use of cache!
# 3788 : ['Q4316334', 'P495', 'Q145', 'What is the country of origin of the tv show, the tenant of wildfell hall?']
# use of cache!
# use of cache!
# 3789 : ['Q6115807', 'P27', 'Q30', 'Which country does jack williams claim nationality from? ']
# use of cache!
# use of cache!
# 3790 : ['Q1163515', 'P86', 'Q296876', 'Who composed the composition islands in the stream?']
# use of cache!
# 3791 : ['Q15527274', 'P21', 'Q6581097', 'john binder identifies with what gender?']
# use of cache!
# use of cache!
# 3792 : ['Q336286', 'R413', 'Q4750948', 'who plays defender?']
# use of cache!
# use of cache!
# 3793 : ['Q318953', 'R1431', 'Q2613318', 'Name a film that jim davis produced.']
# use of cache!
# 3794 : ['Q4957770', 'R123', 'Q3189957', 'what was a game published by brash entertainment']
# use of cache!
# 3795 : ['Q463983', 'R175', 'Q7624477', 'what album is by the artist tanya tucker?']
# use of cache!
# 3796 : ['Q69597', 'P20', 'Q159', 'Where did werner mummert die']
# use of cache!
# use of cache!
# 3797 : ['Q1139473', 'P136', 'Q83440', 'what kind of music is personal file?']
# use of cache!
# use of cache!
# 3798 : ['Q4817465', 'P27', 'Q30', 'which country is kay lahusen from']
# use of cache!
# use of cache!
# 3799 : ['Q188874', 'R509', 'Q2052905', 'who died from colorectal cancer']
# use of cache!
# 3800 : ['Q365407', 'P21', 'Q6581097', 'What gender is adolph j. sabath']
# use of cache!
# use of cache!
# Labels Identified: 3800 Cache Size: 4998
# 3801 : ['Q47164', 'R19', 'Q2675693', 'which american film producer is from  santa monica, california']
# use of cache!
# use of cache!
# 3802 : ['Q781201', 'P136', 'Q187760', 'what kind of music does austra make?']
# use of cache!
# use of cache!
# 3803 : ['Q3195227', 'P264', 'Q216364', 'What label is kennyandchante on?']
# use of cache!
# use of cache!
# 3804 : ['Q235858', 'R136', 'Q7739383', 'Which quartet is known for traditional music?']
# use of cache!
# 3805 : ['Q202600', 'P20', 'Q3708823', 'where in new york did richard kiley died in?']
# use of cache!
# 3806 : ['Q46333', 'R607', 'Q381823', 'who was involved in the long march']
# use of cache!
# 3807 : ['Q83270', 'R136', 'Q4354943', 'who is a hard rock artist']
# use of cache!
# use of cache!
# 3808 : ['Q708689', 'P27', 'Q15180', 'Where is vladimir vasyutin originally from?']
# use of cache!
# use of cache!
# 3809 : ['Q7317647', 'P509', 'Q12192', 'what was the cause of death of reuven frank']
# use of cache!
# use of cache!
# 3810 : ['Q421707', 'P509', 'Q181257', 'What caused the death of jerry orbach?']
# use of cache!
# use of cache!
# 3811 : ['Q16727649', 'P21', 'Q6581072', 'What is the gender of carolyn a. brent?']
# use of cache!
# use of cache!
# 3812 : ['Q187351', 'P123', 'Q1229035', 'who published split second: velocity']
# use of cache!
# 3813 : ['Q1753433', 'P495', 'Q30', 'what country was the patriot filmed in']
# use of cache!
# use of cache!
# 3814 : ['Q7147854', 'P21', 'Q6581097', 'which male is patrick wintour']
# use of cache!
# use of cache!
# 3815 : ['Q7130156', 'P27', 'Q229', 'where is panayiotis panayiotou from ']
# use of cache!
# use of cache!
# 3816 : ['Q7294641', 'R40', 'Q354783', "who are ras baraka's parents?"]
# use of cache!
# 3817 : ['Q3100078', 'R40', 'Q1054305', "Who was imagawa ujizane's parent?"]
# use of cache!
# 3818 : ['Q226730', 'R136', 'Q10301844', 'Name a silent film.']
# use of cache!
# use of cache!
# 3819 : ['Q13422452', 'P404', 'Q208850', 'what is the gameplay mode of the elder scrolls v: skyrim – hearthfire?']
# use of cache!
# use of cache!
# 3820 : ['Q5965748', 'P272', 'Q168383', "Which company produced i'll be yours"]
# use of cache!
# 3821 : ['Q367715', 'P175', 'Q299138', 'who is the artist of man on the moon: the end of day']
# use of cache!
# 3822 : ['Q33999', 'R106', 'Q3840262', 'Name an actor. ']
# use of cache!
# use of cache!
# 3823 : ['Q83440', 'R136', 'Q7882371', 'what is a country album?']
# use of cache!
# use of cache!
# 3824 : ['Q6376828', 'P364', 'Q1860', 'What language was the drama kathleen mavourneen filmed in?']
# use of cache!
# use of cache!
# 3825 : ['Q7735439', 'P136', 'Q7749', 'what genre is the fully down']
# use of cache!
# use of cache!
# 3826 : ['Q1331748', 'P196', 'Q2179', 'where in the solar system is (8228) 1996 yb2']
# use of cache!
# use of cache!
# 3827 : ['Q3815292', 'P19', 'Q202828', 'where was basketball player kim hughes born?']
# use of cache!
# 3828 : ['Q12126240', 'P58', 'Q2898736', 'who wrote the story for the movie money for speed']
# use of cache!
# 3829 : ['Q5262955', 'P21', 'Q6581097', 'is derrell mitchell male or female']
# use of cache!
# use of cache!
# 3830 : ['Q8076835', 'P21', 'Q6581097', "what is angel fleitas's gender?"]
# use of cache!
# use of cache!
# 3831 : ['Q11770700', 'P19', 'Q3141', 'where was martin pakula born ']
# use of cache!
# use of cache!
# 3832 : ['Q4837108', 'P495', 'Q668', 'which country was baadbaan filmed in']
# use of cache!
# use of cache!
# 3833 : ['Q7749', 'R136', 'Q3966165', 'name a famous rock and roll  album in 2003']
# use of cache!
# use of cache!
# 3834 : ['Q3523437', 'P57', 'Q1861005', 'Who directed the movie the world is rich']
# use of cache!
# 3835 : ['Q916349', 'P17', 'Q155', 'what country does the guaporé river run through?']
# use of cache!
# use of cache!
# 3836 : ['Q15039830', 'P495', 'Q408', 'what is the country of origin of burden']
# use of cache!
# use of cache!
# 3837 : ['Q2421682', 'P86', 'Q2049494', 'what music came from the film thoda pyaar thoda magic?']
# use of cache!
# 3838 : ['Q7577021', 'P136', 'Q200092', 'What is the genre of the film spider forest?']
# use of cache!
# use of cache!
# 3839 : ['Q1367166', 'R175', 'Q4690790', 'What is one of the albums marion brown recorded?']
# use of cache!
# 3840 : ['Q1297', 'R19', 'Q18638555', 'who was born in chicago?']
# use of cache!
# use of cache!
# 3841 : ['Q4647672', 'P27', 'Q30', 'what is the nationality of a.d. miles?']
# use of cache!
# use of cache!
# 3842 : ['Q4090181', 'P19', 'Q172', 'where was milan božić born']
# use of cache!
# use of cache!
# 3843 : ['Q332169', 'P27', 'Q30', 'which nationalisty is troy brown']
# use of cache!
# use of cache!
# 3844 : ['Q216924', 'P20', 'Q172', 'where was the death place of glenn gould']
# use of cache!
# use of cache!
# 3845 : ['Q40898', 'R19', 'Q164405', 'Who was born in nancy?']
# use of cache!
# 3846 : ['Q5077792', 'P21', 'Q6581097', "What is charles frank's gender"]
# use of cache!
# use of cache!
# 3847 : ['Q451676', 'P20', 'Q484678', 'where did robert lawson vaught pass away?']
# use of cache!
# 3848 : ['Q7488688', 'P106', 'Q482980', "What is shankar dayal singh's profession?"]
# use of cache!
# 3849 : ['Q463343', 'P19', 'Q502710', 'where was bernhard stavenhagen born ']
# use of cache!
# 3850 : ['Q3956295', 'P19', 'Q490', 'what is the place of birth of sergio spina']
# use of cache!
# use of cache!
# 3851 : ['Q1641156', 'P136', 'Q645928', 'what type of film is george wallace']
# use of cache!
# use of cache!
# 3852 : ['Q16482238', 'P495', 'Q96', 'What was the country of origin for the film bedtime fairy tales for crocodiles?']
# use of cache!
# use of cache!
# 3853 : ['Q5338522', 'P19', 'Q3410', 'Where was edith craig born?']
# use of cache!
# 3854 : ['Q6425037', 'P136', 'Q20502', 'what kind of music is on the koda kumi remix album']
# use of cache!
# use of cache!
# 3855 : ['Q5307222', 'P19', 'Q491128', 'Where did drew macias die']
# use of cache!
# 3856 : ['Q2368037', 'P162', 'Q51492', 'who produced the film  broadway bill']
# use of cache!
# 3857 : ['Q259961', 'P27', 'Q145', "what is tim yeo's nationality?"]
# use of cache!
# use of cache!
# 3858 : ['Q219526', 'P131', 'Q61148', 'which county is fayetteville located in?']
# use of cache!
# 3859 : ['Q18153355', 'P136', 'Q130232', 'what genre on netflix is psychopathia sexualis']
# use of cache!
# use of cache!
# 3860 : ['Q6252865', 'P413', 'Q336286', 'What position does footballer john pickering play?']
# use of cache!
# use of cache!
# 3861 : ['Q6189207', 'P27', 'Q928', "What is jett pangan's nationality?"]
# use of cache!
# use of cache!
# 3862 : ['Q1426203', 'R19', 'Q6548142', 'what African-American cook was born in the mississippi delta']
# use of cache!
# 3863 : ['Q3040927', 'P57', 'Q55438', 'who directed knives of the avenger']
# use of cache!
# use of cache!
# 3864 : ['Q2457109', 'R175', 'Q2905682', 'what album is by silentiumband']
# use of cache!
# 3865 : ['Q918313', 'P19', 'Q495', 'What part of italy was giovanni cheli born in?']
# use of cache!
# use of cache!
# 3866 : ['Q745000', 'P136', 'Q206159', 'What genre of music is off the album smiley smile']
# use of cache!
# use of cache!
# 3867 : ['Q5525107', 'P21', 'Q6581097', 'what gender does gary gach belong to']
# use of cache!
# use of cache!
# 3868 : ['Q4872204', 'P276', 'Q1016292', 'where did the battle of ros-mhic-thriúin take place']
# use of cache!
# 3869 : ['Q4645990', 'P57', 'Q5386224', 'who directed 9500 liberty']
# use of cache!
# 3870 : ['Q7315674', 'P136', 'Q10926', 'what genre is resolution']
# use of cache!
# use of cache!
# 3871 : ['Q12084660', 'P364', 'Q1860', 'what language is the princess and the goblin in']
# use of cache!
# use of cache!
# 3872 : ['Q4423324', 'P19', 'Q18013', 'In which city was ruth slenczynska born?']
# use of cache!
# use of cache!
# 3873 : ['Q679657', 'P1040', 'Q542167', 'who edited the film bobby?']
# use of cache!
# use of cache!
# 3874 : ['Q274744', 'P50', 'Q36322', 'who is the author of sense and sensibility']
# use of cache!
# 3875 : ['Q1788050', 'P17', 'Q155', 'what is urucuia a second level division of']
# use of cache!
# use of cache!
# 3876 : ['Q3759415', 'P27', 'Q30', 'What was the nationality of gene banks']
# use of cache!
# use of cache!
# 3877 : ['Q1496664', 'R19', 'Q528826', 'who is someone born in mitchelstown']
# use of cache!
# 3878 : ['Q3894917', 'P136', 'Q859369', 'What genre is popi ']
# use of cache!
# use of cache!
# 3879 : ['Q3484515', 'P364', 'Q1860', 'what language is spoken in the big fisherman']
# use of cache!
# use of cache!
# 3880 : ['Q43421', 'R19', 'Q5336226', 'who is a man that was born in richmond']
# use of cache!
# use of cache!
# 3881 : ['Q7925943', 'P27', 'Q30', 'what country is victor gotbaum from']
# use of cache!
# use of cache!
# 3882 : ['Q4655520', 'P495', 'Q884', 'Which country is the film a bloody aria from']
# use of cache!
# use of cache!
# 3883 : ['Q5496384', 'P413', 'Q1142885', 'what position does baseball player fred tauby play at?']
# use of cache!
# use of cache!
# 3884 : ['Q8007591', 'P607', 'Q362', 'what war did william darling participate in?']
# use of cache!
# use of cache!
# 3885 : ['Q5542360', 'P413', 'Q1149560', 'what position does george mcnamara play']
# use of cache!
# 3886 : ['Q7429431', 'R112', 'Q2216770', 'who founded sazō idemitsu']
# use of cache!
# 3887 : ['Q5293185', 'P106', 'Q19204627', 'what is the profession of don muhlbach']
# use of cache!
# use of cache!
# 3888 : ['Q6581072', 'R21', 'Q2278783', 'Who is a female character?']
# use of cache!
# use of cache!
# 3889 : ['Q382270', 'P21', 'Q6581097', 'What gender is panajot pano']
# use of cache!
# use of cache!
# 3890 : ['Q777476', 'P20', 'Q163749', 'where did joey maxim spend his last days']
# use of cache!
# 3891 : ['Q299727', 'P27', 'Q45', "what is rolando (portuguese footballer)'s nationality?"]
# use of cache!
# use of cache!
# 3892 : ['Q4974628', 'P131', 'Q54065', 'which county is brookhaven located in?']
# use of cache!
# 3893 : ['Q191755', 'R58', 'Q3352751', 'what film did jim jarmusch write']
# use of cache!
# 3894 : ['Q5310366', 'P27', 'Q30', 'What was the nationality of duane niatum?']
# use of cache!
# use of cache!
# 3895 : ['Q1142207', 'P136', 'Q11366', 'what type of music does the mayfield four play']
# use of cache!
# use of cache!
# 3896 : ['Q7691167', 'P495', 'Q30', 'where is the film teach me! from']
# use of cache!
# use of cache!
# 3897 : ['Q1315100', 'P196', 'Q2179', 'What asteroid group is 8087 kazutaka a member of?']
# use of cache!
# use of cache!
# 3898 : ['Q302762', 'P264', 'Q4883239', 'what label is barry manilow with ']
# use of cache!
# 3899 : ['Q785224', 'P364', 'Q1860', 'Which language is the tv show the lost room in']
# use of cache!
# use of cache!
# 3900 : ['Q16731552', 'P19', 'Q49111', 'what is the birthplace of ian lithgow']
# use of cache!
# Labels Identified: 3900 Cache Size: 5132
# 3901 : ['Q2082933', 'P21', 'Q6581097', 'Mexican soccer player juan carlos medina is what gender?']
# use of cache!
# use of cache!
# 3902 : ['Q18086784', 'P364', 'Q1860', 'in which language is the broadminded movie spoken ']
# use of cache!
# use of cache!
# 3903 : ['Q1940229', 'P136', 'Q170435', 'what type of music is distant earth']
# use of cache!
# 3904 : ['Q983158', 'P19', 'Q406', 'which turkey city was marcel zanini born in']
# use of cache!
# use of cache!
# 3905 : ['Q369747', 'R136', 'Q5454252', "What's an example of a war film"]
# use of cache!
# 3906 : ['Q5081135', 'P27', 'Q30', 'Where is charles mount originally from?']
# use of cache!
# use of cache!
# 3907 : ['Q7301680', 'P19', 'Q43668', "Where did rebecca broussard's mother give birth to her?"]
# use of cache!
# use of cache!
# 3908 : ['Q651357', 'P421', 'Q3134980', 'What is the time zone for evergreen?']
# use of cache!
# use of cache!
# 3909 : ['Q36834', 'R106', 'Q12586834', 'whats the name of a korean composer']
# use of cache!
# use of cache!
# 3910 : ['Q212589', 'P20', 'Q1218', 'Which city did yehuda ashlag die in']
# use of cache!
# 3911 : ['Q4940314', 'P27', 'Q30', "what is nanci bowen's county of nationality?"]
# use of cache!
# use of cache!
# 3912 : ['Q7156926', 'P21', 'Q6581097', 'What gender is payton jordan']
# use of cache!
# use of cache!
# 3913 : ['Q3320923', 'P509', 'Q9687', 'what was the cause of death of berry oakley']
# use of cache!
# use of cache!
# 3914 : ['Q5579170', 'P123', 'Q122741', 'Who published golden axe: beast rider']
# use of cache!
# use of cache!
# 3915 : ['Q55607', 'P178', 'Q122741', 'who is the developer of bonanza bros.?']
# use of cache!
# use of cache!
# 3916 : ['Q1753454', 'P123', 'Q2264873', 'who published the thing']
# use of cache!
# use of cache!
# 3917 : ['Q561586', 'P20', 'Q2887', 'where did pedro opaso die?']
# use of cache!
# use of cache!
# 3918 : ['Q8341', 'R136', 'Q434968', 'which artists perform jazz music?']
# use of cache!
# use of cache!
# 3919 : ['Q1640657', 'P364', 'Q1860', 'is hymn of the nations in the english language or french']
# use of cache!
# use of cache!
# 3920 : ['Q146407', 'P196', 'Q2179', 'What type of asteroid group is 1962 dunant located in']
# use of cache!
# use of cache!
# 3921 : ['Q1192546', 'P196', 'Q2179', 'what asteroid group is 9508 titurel a part of ']
# use of cache!
# use of cache!
# 3922 : ['Q37084', 'P19', 'Q16869', "what was john vi kantakouzenos's birthplace"]
# use of cache!
# use of cache!
# 3923 : ['Q2556456', 'P136', 'Q1054574', 'What film genre is show boat?']
# use of cache!
# use of cache!
# 3924 : ['Q2498241', 'P171', 'Q753221', 'What is the higher classification of mimus?']
# use of cache!
# 3925 : ['Q16067215', 'P27', 'Q30', 'which country is john f. williams from']
# use of cache!
# use of cache!
# 3926 : ['Q664400', 'P61', 'Q457312', 'what Japanese scientist discovered 7797 morita']
# use of cache!
# 3927 : ['Q5162041', 'P27', 'Q408', 'What country is connor pain from?']
# use of cache!
# use of cache!
# 3928 : ['Q41753', 'R19', 'Q659782', 'Who is a man born in klagenfurt?']
# use of cache!
# use of cache!
# 3929 : ['Q2009192', 'P57', 'Q51114', 'who is the director of the movie the sun shines bright']
# use of cache!
# 3930 : ['Q1131279', 'P58', 'Q192217', 'which actor wrote and starred in the hot chick']
# use of cache!
# 3931 : ['Q1770685', 'P19', 'Q9022', 'What release included the recording fantasy']
# use of cache!
# 3932 : ['Q6746062', 'P364', 'Q1860', "what language was man's fate originally filmed in"]
# use of cache!
# use of cache!
# 3933 : ['Q2172661', 'P27', 'Q30', 'What country is rudolf flesch from?']
# use of cache!
# use of cache!
# 3934 : ['Q3413925', 'P364', 'Q150', 'in what language is the movie let there be light spoken']
# use of cache!
# use of cache!
# 3935 : ['Q1080602', 'P86', 'Q168155', 'Who did the music on the film decalogue iii']
# use of cache!
# 3936 : ['Q1349850', 'R58', 'Q1458649', 'which movie was written by jerry juhl']
# use of cache!
# 3937 : ['Q6252091', 'P607', 'Q361', 'which war did john patrick hamilton attend to']
# use of cache!
# use of cache!
# 3938 : ['Q1760399', 'P264', 'Q1139341', 'What record label is sugar on?']
# use of cache!
# 3939 : ['Q670186', 'P641', 'Q2736', 'what sport does deportivo toluca play']
# use of cache!
# 3940 : ['Q45859', 'R40', 'Q470403', 'who is mother of isabella i of castile']
# use of cache!
# 3941 : ['Q229513', 'P20', 'Q913346', 'where did sarah vaughan die']
# use of cache!
# 3942 : ['Q131524', 'R279', 'Q3427922', 'what is the tittle of an entrepreneur who opens and runs restaurants professionally']
# 3943 : ['Q5207062', 'P162', 'Q1391329', 'who was the producer for d: underworld badhshah']
# use of cache!
# 3944 : ['Q639669', 'R106', 'Q5927919', 'Who is a professional musician?']
# use of cache!
# 3945 : ['Q164997', 'R112', 'Q338920', 'What organization did Leonard Blavatnik found?']
# use of cache!
# 3946 : ['Q216820', 'R19', 'Q959750', 'What american character actor was born in youngstown?']
# use of cache!
# use of cache!
# 3947 : ['Q92899', 'P21', 'Q6581097', 'What was the gender of richard grimsdale']
# use of cache!
# use of cache!
# 3948 : ['Q7042310', 'P21', 'Q6581097', "what is niño gelig's gender?"]
# use of cache!
# use of cache!
# 3949 : ['Q551389', 'P106', 'Q2526255', "What is josef rovenský's profession?"]
# use of cache!
# use of cache!
# 3950 : ['Q7288204', 'P20', 'Q18575', 'where did ralph w. aigler die']
# use of cache!
# use of cache!
# 3951 : ['Q10525801', 'P27', 'Q668', 'Which country is mackroy peixote from']
# use of cache!
# use of cache!
# 3952 : ['Q2322285', 'P413', 'Q308879', 'What basketball position does martin müürsepp play']
# use of cache!
# use of cache!
# 3953 : ['Q462471', 'R413', 'Q719631', 'what is the name of a  power forward basketball player']
# use of cache!
# use of cache!
# 3954 : ['Q16932445', 'P136', 'Q170238', 'what type of tv show is legit?']
# use of cache!
# 3955 : ['Q93204', 'R136', 'Q16028667', 'what is a name of a documentary film']
# use of cache!
# use of cache!
# 3956 : ['Q621493', 'P364', 'Q1860', 'which language is spoken in the film observe and report?']
# use of cache!
# use of cache!
# 3957 : ['Q5540273', 'P21', 'Q6581097', 'whats the gender of  george harrison']
# use of cache!
# use of cache!
# 3958 : ['Q1329343', 'P21', 'Q6581097', 'what is the gender of eligius fromentin']
# use of cache!
# use of cache!
# 3959 : ['Q1172875', 'P136', 'Q130232', 'The film four friends is considered to be a part of which film genre?']
# use of cache!
# use of cache!
# 3960 : ['Q467945', 'P19', 'Q1345', 'where was roxy reynolds given birth']
# use of cache!
# use of cache!
# 3961 : ['Q151216', 'P31', 'Q3863', 'what kind of object is 3287 olmstead?']
# use of cache!
# use of cache!
# 3962 : ['Q499649', 'P1303', 'Q202027', 'Which instrument is played by nat adderley']
# use of cache!
# 3963 : ['Q280658', 'R413', 'Q547766', 'which soccer player plays forward?']
# use of cache!
# use of cache!
# 3964 : ['Q1050571', 'R413', 'Q484293', 'What is the name of a Japanese catcher?']
# use of cache!
# use of cache!
# 3965 : ['Q240575', 'P40', 'Q7244790', 'who is the daughter of queen noor of jordan ']
# use of cache!
# 3966 : ['Q1075769', 'P509', 'Q175111', 'how did seisaku nakamura die']
# use of cache!
# 3967 : ['Q5324689', 'P112', 'Q16137703', 'Who is a founder of exl']
# use of cache!
# 3968 : ['Q184462', 'R40', 'Q299551', "who was the king of Lydia and croesus's father"]
# use of cache!
# 3969 : ['Q927956', 'P175', 'Q133405', 'which artist made a the greatest hits album']
# use of cache!
# 3970 : ['Q1850956', 'P413', 'Q201330', 'which soccer position does adam blacklaw play']
# use of cache!
# use of cache!
# 3971 : ['Q848929', 'P138', 'Q505037', 'Who was socinianism named after']
# use of cache!
# 3972 : ['Q6166687', 'P19', 'Q49231', "what was jay harris's place of birth"]
# use of cache!
# use of cache!
# 3973 : ['Q809003', 'R175', 'Q1179354', 'What is an album from barry adamson?']
# use of cache!
# 3974 : ['Q5493705', 'P19', 'Q157341', 'where was fraser watts born ']
# use of cache!
# 3975 : ['Q10871364', 'R106', 'Q5293717', 'Name a professional baseball player']
# use of cache!
# use of cache!
# 3976 : ['Q10871364', 'R106', 'Q4909059', 'Name a baseball player']
# use of cache!
# use of cache!
# 3977 : ['Q446518', 'P172', 'Q49085', 'What is the ethnicity of heather hunter?']
# use of cache!
# use of cache!
# 3978 : ['Q188534', 'R136', 'Q677891', 'Name a grindcore band']
# use of cache!
# 3979 : ['Q45700', 'R123', 'Q1986054', 'what game was published by konami, the cvg publisher']
# use of cache!
# use of cache!
# 3980 : ['Q658694', 'P21', 'Q6581072', 'is sibylle canonica a male of a female ']
# use of cache!
# use of cache!
# 3981 : ['Q2793276', 'R272', 'Q319061', 'What is a 2005 participant media American drama film ']
# use of cache!
# 3982 : ['Q292274', 'P19', 'Q124230', 'Where was princess theodora of greece and denmark born?']
# use of cache!
# 3983 : ['Q3565954', 'P136', 'Q8341', 'What kind of music is the album waltz for debby?']
# use of cache!
# use of cache!
# 3984 : ['Q175600', 'P58', 'Q294583', "who wrote don't come knocking "]
# use of cache!
# 3985 : ['Q286028', 'P27', 'Q142', 'what country is louis Émile javal citizen of ']
# use of cache!
# use of cache!
# 3986 : ['Q1027823', 'R19', 'Q7815075', "what's  the name of a cricket umpire born in paddington"]
# use of cache!
# 3987 : ['Q569704', 'P21', 'Q6581097', 'What gender is ansgar brinkmann?']
# use of cache!
# use of cache!
# 3988 : ['Q6780114', 'P21', 'Q6581072', "What is mary losseff's gender"]
# use of cache!
# use of cache!
# 3989 : ['Q33999', 'R106', 'Q66548', 'Name an actor']
# use of cache!
# use of cache!
# 3990 : ['Q15231777', 'P1408', 'Q572052', 'which city produced kucd']
# 3991 : ['Q55430', 'R57', 'Q1190863', 'What film did zhang yimou direct?']
# use of cache!
# use of cache!
# 3992 : ['Q1496376', 'P138', 'Q6722', 'Who was gaussian process named after?']
# use of cache!
# 3993 : ['Q3370374', 'P21', 'Q6581097', "what is dmitrijs jurkevičs's gender?"]
# use of cache!
# use of cache!
# 3994 : ['Q1166236', 'P136', 'Q37073', 'what music does zsuzsi mary perform ']
# use of cache!
# use of cache!
# 3995 : ['Q362', 'R607', 'Q7287447', 'which military personnel was involved in world war ii']
# use of cache!
# use of cache!
# 3996 : ['Q236958', 'R50', 'Q1134909', "What's a book written by katherine anne porter"]
# use of cache!
# 3997 : ['Q596358', 'P495', 'Q30', 'which country released shaft in africa']
# use of cache!
# use of cache!
# 3998 : ['Q3591220', 'P106', 'Q28389', 'What does eric laugérias do for a profession?']
# use of cache!
# use of cache!
# 3999 : ['Q18292163', 'P136', 'Q130232', 'What type of movie is the magnetists fifth winter?']
# use of cache!
# use of cache!
# 4000 : ['Q4734882', 'P27', 'Q224', 'What is the nationality of fedor Škubonja?']
# use of cache!
# use of cache!
# Labels Identified: 4000 Cache Size: 5270
# 4001 : ['Q7406336', 'P136', 'Q1935609', 'what kind of film is salute to the marines?']
# use of cache!
# 4002 : ['Q1501379', 'R178', 'Q6129971', 'Which game did parker brothers develop?']
# use of cache!
# 4003 : ['Q3281790', 'P495', 'Q45', 'Which country filmed my voice']
# use of cache!
# use of cache!
# 4004 : ['Q919145', 'P20', 'Q2462645', 'where did verney lovett cameron die']
# use of cache!
# 4005 : ['Q1051256', 'P112', 'Q5334704', 'Who was a founder of the cato institute']
# use of cache!
# 4006 : ['Q87546', 'P21', 'Q6581097', 'Which gender is carl balhaus?']
# use of cache!
# use of cache!
# 4007 : ['Q10926', 'R136', 'Q7960374', 'whats an album name found in the emo genre']
# use of cache!
# use of cache!
# 4008 : ['Q1255403', 'P21', 'Q6581097', 'Is sami garam male or female?']
# use of cache!
# use of cache!
# 4009 : ['Q5325067', 'P413', 'Q622747', "what is eagle day's position "]
# use of cache!
# use of cache!
# 4010 : ['Q566864', 'P19', 'Q13666', 'where was the woman annibale maria di francia born']
# use of cache!
# use of cache!
# 4011 : ['Q54064', 'R131', 'Q3452193', 'what is in nassau county?']
# use of cache!
# use of cache!
# 4012 : ['Q566994', 'P413', 'Q193592', 'which position does albert brülls play']
# use of cache!
# use of cache!
# 4013 : ['Q7830557', 'P175', 'Q7830558', 'Who is the artist from the album titled toya']
# use of cache!
# 4014 : ['Q3571584', 'P364', 'Q1860', 'what language is spoken in yankee doodle bugs']
# use of cache!
# use of cache!
# 4015 : ['Q6522728', 'P19', 'Q8686', 'where was kuan-chung ku born']
# use of cache!
# 4016 : ['Q1194810', 'P58', 'Q5237900', 'what is a film written by daddy day camp']
# use of cache!
# 4017 : ['Q104718', 'P21', 'Q6581097', 'Is friedrich gustav jaeger a man or a woman']
# use of cache!
# use of cache!
# 4018 : ['Q963142', 'P264', 'Q557632', 'under which label does ernest tubb work']
# use of cache!
# use of cache!
# 4019 : ['Q151599', 'P58', 'Q19504', 'who wrote metropolis (film)']
# use of cache!
# 4020 : ['Q2550119', 'P495', 'Q30', "What is the country of origin of the film mockingbird don't sing?"]
# use of cache!
# use of cache!
# 4021 : ['Q7560207', 'P136', 'Q842256', 'what category of film is something for the boys']
# use of cache!
# use of cache!
# 4022 : ['Q7539895', 'P50', 'Q727079', 'Who was the author of sleeping in flame']
# use of cache!
# 4023 : ['Q261700', 'P86', 'Q95008', 'who wrote the music for ghosts of mars']
# use of cache!
# use of cache!
# 4024 : ['Q3460480', 'P131', 'Q108618', 'where is highland mills located']
# use of cache!
# use of cache!
# 4025 : ['Q835675', 'R175', 'Q693816', 'whats an album created by the artist  freedom call']
# use of cache!
# 4026 : ['Q4913467', 'P19', 'Q1018565', 'where was the place of birth of billy williams']
# use of cache!
# 4027 : ['Q5111950', 'P106', 'Q6625963', "what is christopher bigsby's profession"]
# use of cache!
# 4028 : ['Q15623685', 'P364', 'Q1860', 'What language is spoken in fargo']
# use of cache!
# use of cache!
# 4029 : ['Q5394329', 'P27', 'Q30', 'Where is ernie alexander from?']
# use of cache!
# use of cache!
# 4030 : ['Q16200717', 'P27', 'Q30', "What is hiram n. breed's nationality?"]
# use of cache!
# use of cache!
# 4031 : ['Q3630', 'R19', 'Q12525500', 'who was born in jakarta']
# use of cache!
# 4032 : ['Q887946', 'P106', 'Q82955', "What is josé antonio remón cantera's profession?"]
# use of cache!
# use of cache!
# 4033 : ['Q288040', 'P136', 'Q37073', 'what kind of music does tonina torrielli perform']
# use of cache!
# use of cache!
# 4034 : ['Q5502982', 'P175', 'Q216288', 'which country artist recorded fresh horses']
# use of cache!
# 4035 : ['Q1187585', 'P175', 'Q1163207', 'which artist released odessey and oracle?']
# use of cache!
# 4036 : ['Q3976065', 'P264', 'Q1063242', 'what label is chrisadamsstringdriventhing under']
# use of cache!
# 4037 : ['Q400266', 'P40', 'Q6039896', 'who is the child of ahinoam']
# use of cache!
# 4038 : ['Q3361666', 'P162', 'Q25100', 'Who produced red lob?']
# use of cache!
# 4039 : ['Q1349722', 'P27', 'Q142', 'what country is jacques lisfranc de st. martin originally from?']
# use of cache!
# use of cache!
# 4040 : ['Q4687974', 'P175', 'Q281034', 'which musician recorded aerial ballet']
# use of cache!
# 4041 : ['Q2249109', 'P175', 'Q922445', 'which artist put out the album wowee zowee: sordid sentinels edition?']
# use of cache!
# 4042 : ['Q924848', 'P31', 'Q3863', 'what category does the celestial object 10188 yasuoyoneda belong to']
# use of cache!
# use of cache!
# 4043 : ['Q49145', 'R19', 'Q3430673', 'What is the name of someone born in new haven?']
# use of cache!
# use of cache!
# 4044 : ['Q336286', 'R413', 'Q1898767', 'what player is a defender?']
# use of cache!
# use of cache!
# 4045 : ['Q1955445', 'R175', 'Q5640018', "what's the name of one of bryn jones's albums"]
# use of cache!
# use of cache!
# 4046 : ['Q615860', 'P364', 'Q9027', 'what language is spoken in beck – skarpt läge']
# use of cache!
# 4047 : ['Q732397', 'R162', 'Q2299961', 'what film is produced by ismail merchant?']
# use of cache!
# 4048 : ['Q4963319', 'P413', 'Q336286', 'What position does footballer brian caswell play?']
# use of cache!
# use of cache!
# 4049 : ['Q6148443', 'P27', 'Q408', 'This is the nationality of actress and entertainer jan adele.']
# use of cache!
# use of cache!
# 4050 : ['Q949784', 'P136', 'Q130232', 'Which genre of film is caro diario']
# use of cache!
# use of cache!
# 4051 : ['Q116995', 'P27', 'Q39', 'what is the nationality of charles dutoit?']
# use of cache!
# use of cache!
# 4052 : ['Q1043614', 'P272', 'Q2820005', 'which company produced taare zameen par']
# use of cache!
# 4053 : ['Q640432', 'P138', 'Q78503', 'after what physicist was the 9253 oberth asteroid named']
# use of cache!
# 4054 : ['Q7109690', 'P19', 'Q1297', 'Where was otto krueger born?']
# use of cache!
# use of cache!
# 4055 : ['Q1526390', 'P27', 'Q766', 'Where is lloyd parks from']
# use of cache!
# use of cache!
# 4056 : ['Q51562', 'R57', 'Q1199446', 'what film was ernst lubitsch the director of']
# use of cache!
# 4057 : ['Q216669', 'R1142', 'Q477273', 'What is the name of a political party that practices monarchism']
# use of cache!
# 4058 : ['Q436829', 'R57', 'Q238681', 'Which film did russell mulcahy direct']
# use of cache!
# 4059 : ['Q16552', 'R19', 'Q6384262', 'Who was born in san diego']
# use of cache!
# use of cache!
# 4060 : ['Q500212', 'P19', 'Q2833', 'where was andreas resch born']
# use of cache!
# use of cache!
# 4061 : ['Q3128143', 'P27', 'Q142', 'What nationality is hassan hirt ']
# use of cache!
# use of cache!
# 4062 : ['Q12125107', 'P364', 'Q1860', 'What language do the characters speak in the intelligence men']
# use of cache!
# use of cache!
# 4063 : ['Q1326154', 'R413', 'Q5229659', 'Who is a notable first baseman']
# use of cache!
# use of cache!
# use of cache!
# 4064 : ['Q6768810', 'P19', 'Q170263', 'Where was Mark McGregor born?']
# use of cache!
# 4065 : ['Q2404462', 'P106', 'Q483501', "what is william rotsler's profession?"]
# use of cache!
# 4066 : ['Q2980608', 'P21', 'Q6581097', "What is sven-olof walldoff's language?"]
# use of cache!
# use of cache!
# 4067 : ['Q3051285', 'P21', 'Q6581072', 'what gender is elizabeth clarke wolstenholme elmy']
# use of cache!
# use of cache!
# 4068 : ['Q7060078', 'P364', 'Q1860', 'which language is primarily used in northwest hounded police']
# use of cache!
# use of cache!
# 4069 : ['Q5209027', 'P19', 'Q2003342', 'where was dai prosser born?']
# use of cache!
# 4070 : ['Q17600963', 'P19', 'Q12892', 'This city in Belgium is where actor bert van tichelen was born.']
# use of cache!
# use of cache!
# 4071 : ['Q93204', 'R136', 'Q983854', "What's a documentary film on netflix"]
# use of cache!
# use of cache!
# 4072 : ['Q17124728', 'P495', 'Q183', 'which country is mein kampf from']
# use of cache!
# use of cache!
# 4073 : ['Q1733', 'R19', 'Q7965920', 'What oberfeldwebel was born in magdeburg?']
# use of cache!
# use of cache!
# 4074 : ['Q3988095', 'P136', 'Q226730', 'What genre is the lost paradise']
# use of cache!
# use of cache!
# 4075 : ['Q690316', 'P31', 'Q3863', 'what is 6806 kaufmann categorized as?']
# use of cache!
# use of cache!
# 4076 : ['Q4180164', 'P175', 'Q5383', 'who is the artist of seven']
# use of cache!
# 4077 : ['Q60', 'R19', 'Q8879489', 'Who was born in new york city?']
# use of cache!
# use of cache!
# 4078 : ['Q128538', 'P140', 'Q5043', 'What is the religion of luke the evangelist?']
# use of cache!
# use of cache!
# 4079 : ['Q2405386', 'P57', 'Q347864', 'Who directed terrible teddy, the grizzly king']
# use of cache!
# 4080 : ['Q152795', 'P196', 'Q2179', 'what is 4151 alanhale a member of?']
# use of cache!
# use of cache!
# 4081 : ['Q2707741', 'P136', 'Q83270', 'What genre  is secret treaties?']
# use of cache!
# use of cache!
# 4082 : ['Q749153', 'P364', 'Q1860', 'What language is the film geris game']
# use of cache!
# use of cache!
# 4083 : ['Q16968380', 'P175', 'Q234891', 'who is the musician that created around the world in 77 minutes']
# use of cache!
# 4084 : ['Q3443417', 'P19', 'Q204561', 'which city in california was darlene vogel born in']
# use of cache!
# 4085 : ['Q2663586', 'R40', 'Q130873', "Who is benny begin's father?"]
# use of cache!
# 4086 : ['Q252472', 'P403', 'Q201679', 'which body of water is the mouth of oti river?']
# use of cache!
# 4087 : ['Q5245060', 'P136', 'Q472055', 'what kind of game is deactivators']
# use of cache!
# use of cache!
# 4088 : ['Q2412723', 'R19', 'Q6301548', 'which religious leader was born in hatillo']
# use of cache!
# 4089 : ['Q667128', 'R58', 'Q1170354', 'what films did king hu write?']
# use of cache!
# 4090 : ['Q216344', 'R119', 'Q558992', 'What United States Air Force Officer is interred at the Arlington National Cemetery?']
# use of cache!
# use of cache!
# 4091 : ['Q183504', 'R136', 'Q593878', 'which artist is considered an indie rock artist']
# use of cache!
# use of cache!
# 4092 : ['Q308879', 'R413', 'Q19615250', 'who plays small forward in basketball']
# use of cache!
# use of cache!
# 4093 : ['Q877128', 'P136', 'Q8341', 'What sort of music does louie austen play']
# use of cache!
# use of cache!
# 4094 : ['Q4643847', 'P136', 'Q93204', 'what genre category is 7 girls ']
# use of cache!
# use of cache!
# 4095 : ['Q2444881', 'P27', 'Q183', 'what country does torsten knippertz get his nationality from?']
# use of cache!
# use of cache!
# 4096 : ['Q2360218', 'P178', 'Q14428', 'Who developed mega man 6']
# use of cache!
# use of cache!
# 4097 : ['Q5545621', 'P119', 'Q216344', 'Where is george w. getty buried']
# use of cache!
# use of cache!
# 4098 : ['Q336286', 'R413', 'Q3981663', 'who plays defender for the kingston fc canadian soccer league?']
# use of cache!
# use of cache!
# 4099 : ['Q6205010', 'P21', 'Q6581072', "What is joan druett's gender"]
# use of cache!
# use of cache!
# 4100 : ['Q7171822', 'P413', 'Q1050571', 'which baseball position is played by pete allen']
# use of cache!
# use of cache!
# Labels Identified: 4100 Cache Size: 5407
# 4101 : ['Q4900673', 'P495', 'Q668', 'what country is bhagwan parshuram filmed in?']
# use of cache!
# use of cache!
# 4102 : ['Q789741', 'P364', 'Q1568', 'what language is auzaar in?']
# use of cache!
# use of cache!
# 4103 : ['Q913194', 'P264', 'Q183412', 'which label is roll deep signed to ']
# use of cache!
# use of cache!
# 4104 : ['Q756137', 'P131', 'Q109150', 'which county is atlanta in']
# use of cache!
# 4105 : ['Q7728490', 'P136', 'Q1641839', 'what genre does the curtains make']
# use of cache!
# use of cache!
# 4106 : ['Q431252', 'P1040', 'Q273379', 'Who edited the film jackie brown (film)']
# use of cache!
# 4107 : ['Q6176462', 'P27', 'Q145', 'What nationality is jehanne wake']
# use of cache!
# use of cache!
# 4108 : ['Q708888', 'P364', 'Q727694', 'What language is comrades: almost a love story in?']
# use of cache!
# 4109 : ['Q3646704', 'P136', 'Q83270', 'What type of music genre is the album "Built to Destroy"?']
# use of cache!
# use of cache!
# 4110 : ['Q378089', 'P31', 'Q3863', 'what is the category of 6488 drebach?']
# use of cache!
# use of cache!
# 4111 : ['Q280658', 'R413', 'Q4191312', 'what is the name of a russian football foward']
# use of cache!
# use of cache!
# 4112 : ['Q27467', 'P364', 'Q5146', 'which language is in the film  isle of flowers']
# use of cache!
# 4113 : ['Q7078797', 'P86', 'Q598185', 'what music is in the film of rice and hen']
# use of cache!
# use of cache!
# 4114 : ['Q299842', 'P19', 'Q3141', 'Where was antonia kidman born']
# use of cache!
# use of cache!
# 4115 : ['Q2446832', 'P421', 'Q847142', 'what time zone is summerville in']
# use of cache!
# use of cache!
# 4116 : ['Q30', 'R17', 'Q110983', 'name a county located in the united states ']
# use of cache!
# use of cache!
# 4117 : ['Q362', 'R607', 'Q62250', 'who is a SS officer in world war ii ']
# use of cache!
# use of cache!
# 4118 : ['Q636637', 'P19', 'Q3711', 'Where was vladimir dedijer born?']
# use of cache!
# 4119 : ['Q1444948', 'P86', 'Q193273', 'who composed the music in a chef in love']
# use of cache!
# 4120 : ['Q12152', 'R509', 'Q5132861', 'Name someone who died of a myocardial infarction']
# use of cache!
# use of cache!
# 4121 : ['Q1248335', 'P495', 'Q30', 'what is the country of origin of deadline']
# use of cache!
# use of cache!
# 4122 : ['Q59566', 'P344', 'Q2149612', 'Who was the cinematographer for the film the upside of anger?']
# use of cache!
# 4123 : ['Q1080008', 'P196', 'Q2179', 'where is 8994 kashkashian found']
# use of cache!
# use of cache!
# 4124 : ['Q714411', 'R175', 'Q7033445', "WHat's an album from chris botti"]
# use of cache!
# 4125 : ['Q7287259', 'P19', 'Q913153', 'what location was ralph botting born in']
# use of cache!
# 4126 : ['Q271263', 'P27', 'Q30', "What is vanessa del rio's country of origin?"]
# use of cache!
# use of cache!
# 4127 : ['Q5213838', 'P21', 'Q6581097', 'whats dan kwong gender']
# use of cache!
# use of cache!
# 4128 : ['Q4928797', 'P264', 'Q778792', 'what label is blue under?']
# use of cache!
# 4129 : ['Q7519181', 'P21', 'Q6581097', "what is simon law's gender?"]
# use of cache!
# use of cache!
# 4130 : ['Q76382', 'P1142', 'Q517372', 'what is the ideology of sinn fein']
# use of cache!
# 4131 : ['Q130232', 'R136', 'Q580917', 'drama is the genre that best describes this film.']
# use of cache!
# use of cache!
# 4132 : ['Q16980961', 'P27', 'Q30', 'what nationality is priscilla slade?']
# use of cache!
# use of cache!
# 4133 : ['Q2831466', 'P106', 'Q520549', 'what does albert peter low do']
# use of cache!
# 4134 : ['Q1722', 'R19', 'Q1029676', 'Who was born in dubrovnik?']
# use of cache!
# 4135 : ['Q6952641', 'P123', 'Q18594', 'Who published nba 06']
# use of cache!
# 4136 : ['Q3625045', 'P21', 'Q6581072', 'is asia cruise male or female']
# use of cache!
# use of cache!
# 4137 : ['Q5317378', 'P20', 'Q16556', 'what city and state did dutch ruether die in']
# use of cache!
# use of cache!
# 4138 : ['Q3283316', 'P404', 'Q208850', 'what gameplay mode does spogs racing offer']
# use of cache!
# use of cache!
# 4139 : ['Q6733393', 'P495', 'Q668', 'what country was maharathi filmed']
# use of cache!
# use of cache!
# 4140 : ['Q59062', 'P19', 'Q1085', "What is vladimír franz's place of birth?"]
# use of cache!
# use of cache!
# 4141 : ['Q303530', 'P20', 'Q1085', 'where did jan zrzavý die']
# use of cache!
# use of cache!
# 4142 : ['Q5132900', 'P27', 'Q30', 'what is the nationality of clifford chatman']
# use of cache!
# use of cache!
# 4143 : ['Q382420', 'P27', 'Q30', 'what country is damon wayans from?']
# use of cache!
# use of cache!
# 4144 : ['Q329424', 'P21', 'Q6581097', 'what is the sex of edgar valter?']
# use of cache!
# use of cache!
# 4145 : ['Q1236386', 'P403', 'Q1265', 'What river is can be found at the mouth of the dolores river?']
# use of cache!
# 4146 : ['Q5668796', 'P413', 'Q1048902', 'What position does harry feldman play']
# use of cache!
# use of cache!
# 4147 : ['Q506400', 'P1431', 'Q966535', 'who executively produced red dawn']
# use of cache!
# 4148 : ['Q361', 'R607', 'Q8013613', 'who is a victoria cross recipient in world war i']
# use of cache!
# use of cache!
# 4149 : ['Q2374149', 'R106', 'Q15994689', 'whats the name of a professional botanist']
# use of cache!
# 4150 : ['Q6228119', 'P21', 'Q6581097', 'what gender is john d. chandris']
# use of cache!
# use of cache!
# 4151 : ['Q1291464', 'P27', 'Q183', 'what spacecrafts has rockwell international manufactured']
# use of cache!
# use of cache!
# 4152 : ['Q343568', 'R136', 'Q580276', 'What is the name of a game in the action-adventure game category']
# use of cache!
# use of cache!
# 4153 : ['Q313828', 'P172', 'Q167420', 'Which ethnicity is ivan meštrović?']
# use of cache!
# 4154 : ['Q1343362', 'R179', 'Q4824266', "What's a season from australian idol"]
# use of cache!
# 4155 : ['Q974553', 'P21', 'Q6581072', "What is angela ruggiero's gender?"]
# use of cache!
# use of cache!
# 4156 : ['Q488543', 'R131', 'Q793493', 'which park is located in orange county, florida']
# use of cache!
# 4157 : ['Q3760870', 'R50', 'Q6188059', "what books have gerald o'collins written?"]
# use of cache!
# 4158 : ['Q6120207', 'P364', 'Q1321', 'What language is santa in?']
# use of cache!
# use of cache!
# 4159 : ['Q1763166', 'P364', 'Q9043', 'What do the actors speak in totally true love']
# use of cache!
# 4160 : ['Q7748767', 'P170', 'Q1432195', 'What network created the tv progam the lost tribes']
# use of cache!
# 4161 : ['Q7595703', 'P86', 'Q7312', 'Who wrote the song stabat mater']
# use of cache!
# 4162 : ['Q848825', 'P272', 'Q141336', 'what is the production company responsible for autumn marathon']
# use of cache!
# use of cache!
# 4163 : ['Q3160536', 'P21', 'Q6581097', 'what is the gender of jagz kooner']
# use of cache!
# use of cache!
# 4164 : ['Q75828', 'P27', 'Q183', 'what is the nationality of heinrich wilhelm olbers']
# use of cache!
# use of cache!
# 4165 : ['Q946523', 'R264', 'Q371238', 'Who is signed with the record lable konlive distribution']
# use of cache!
# 4166 : ['Q447236', 'P172', 'Q7325', "what is stanley fischer's ethnicity?"]
# use of cache!
# use of cache!
# 4167 : ['Q10980509', 'P136', 'Q37073', "what is the best description of clara sofie's music"]
# use of cache!
# use of cache!
# 4168 : ['Q1168925', 'P19', 'Q40435', 'Where was tom schuman born?']
# use of cache!
# use of cache!
# 4169 : ['Q1015818', 'R19', 'Q151403', 'which scottish philosopher was born in  ecclefechan']
# use of cache!
# 4170 : ['Q1376082', 'P106', 'Q188094', "What is michio morishima's profession?"]
# use of cache!
# 4171 : ['Q380261', 'P27', 'Q30', 'what country is little walter from']
# use of cache!
# use of cache!
# 4172 : ['Q1215511', 'P364', 'Q7737', 'what was the language used for the film donkeys hide ']
# use of cache!
# use of cache!
# 4173 : ['Q7791344', 'P20', 'Q23156', 'where did thomas johnes die ']
# use of cache!
# use of cache!
# 4174 : ['Q4816329', 'P364', 'Q1860', 'which language is spoken in atlantic city']
# use of cache!
# use of cache!
# 4175 : ['Q1085', 'R19', 'Q1386296', 'who was born in prague?']
# use of cache!
# use of cache!
# 4176 : ['Q4849336', 'P136', 'Q183504', 'what kind of music is on the album bakesale']
# use of cache!
# use of cache!
# 4177 : ['Q5545288', 'P20', 'Q925424', 'which place did george townsend die ']
# use of cache!
# 4178 : ['Q62', 'R19', 'Q230180', 'Who was born in the city of san francisco?']
# use of cache!
# use of cache!
# 4179 : ['Q422980', 'P21', 'Q6581097', "What is brett lee's gender"]
# use of cache!
# use of cache!
# 4180 : ['Q6581616', 'P19', 'Q873769', "where was urubongs rajsombhoj's birth place"]
# use of cache!
# 4181 : ['Q950141', 'P1303', 'Q5994', 'what instruments can john ogdon play?']
# use of cache!
# use of cache!
# use of cache!
# 4182 : ['Q3218816', 'P404', 'Q208850', 'what type of gameplay mode is the game zombie zombie?']
# use of cache!
# use of cache!
# 4183 : ['Q2127756', 'P50', 'Q49074', 'who wrote the title 2 b r 0 2 b']
# use of cache!
# 4184 : ['Q7793744', 'P20', 'Q319566', 'where did thomas s. tait die']
# use of cache!
# 4185 : ['Q7723196', 'P57', 'Q723738', 'who directed the city that never sleeps']
# use of cache!
# 4186 : ['Q495223', 'P138', 'Q273546', 'Who was hamlin county named for?']
# use of cache!
# 4187 : ['Q3282637', 'R106', 'Q7668719', 'What person has the profession of a film producer?']
# use of cache!
# use of cache!
# 4188 : ['Q41843', 'R19', 'Q5418308', 'who is a person that was born in  beersheba']
# use of cache!
# 4189 : ['Q122557', 'P607', 'Q362', 'what war was curt gallenkamp part of']
# use of cache!
# use of cache!
# 4190 : ['Q7612815', 'P27', 'Q30', 'What is the nationality of steve henderson?']
# use of cache!
# use of cache!
# 4191 : ['Q7297755', 'P27', 'Q30', "What is ray loring's nationality"]
# use of cache!
# use of cache!
# 4192 : ['Q8341', 'R136', 'Q366351', 'Name a jazz artist']
# use of cache!
# use of cache!
# 4193 : ['Q2474321', 'P413', 'Q193592', 'what position is volodymyr sharan known for playing ']
# use of cache!
# use of cache!
# 4194 : ['Q2143368', 'P264', 'Q778673', 'what artist is with the walkabouts?']
# use of cache!
# 4195 : ['Q1287526', 'R276', 'Q3434300', 'What event took place at opis?']
# use of cache!
# 4196 : ['Q15059463', 'P19', 'Q212991', 'Where was morgan taylor reid birthed']
# use of cache!
# 4197 : ['Q1417638', 'P171', 'Q42046', 'what is higher in classification than hyaena (genus)?']
# use of cache!
# 4198 : ['Q846224', 'R136', 'Q150294', 'which game is of the cvg genre fighting game']
# use of cache!
# use of cache!
# 4199 : ['Q446531', 'P27', 'Q15180', 'where is aleksandr ivanchenkov from']
# use of cache!
# use of cache!
# 4200 : ['Q4354506', 'P136', 'Q93204', 'what kind of film is tornado intercept']
# use of cache!
# ...
# use of cache!
# 5472 : ['Q673902', 'P57', 'Q946039', 'who directed the movie jeepers creepers (2001 film)']
# use of cache!
# 5473 : ['Q319122', 'P136', 'Q2143665', 'To what genre does the film Candleshoe belong?']
# use of cache!
# use of cache!
# 5474 : ['Q265252', 'P136', 'Q484344', 'what type of music is buckethead?']
# use of cache!
# use of cache!
# use of cache!
# 5475 : ['Q56179', 'P19', 'Q82960', 'Where was sigrid d. peyerimhoff born']
# use of cache!
# 5476 : ['Q4696247', 'P27', 'Q884', 'What country is ahn seok-ho a citizen of']
# use of cache!
# use of cache!
# 5477 : ['Q3490659', 'P175', 'Q299208', 'which artist made the album sonny rollins and the big brass']
# use of cache!
# 5478 : ['Q7769345', 'P404', 'Q208850', 'which gameplay was used in the time warp of dr. brain']
# use of cache!
# use of cache!
# 5479 : ['Q601336', 'P178', 'Q780528', 'Who was the developer for majin tensei']
# use of cache!
# use of cache!
# 5480 : ['Q11399', 'R136', 'Q5286575', 'which album is of the rock music genre']
# use of cache!
# use of cache!
# 5481 : ['Q208850', 'R404', 'Q893422', 'What game has a single-player']
# use of cache!
# use of cache!
# 5482 : ['Q2704217', 'P86', 'Q367032', 'what music is used in secrets']
# use of cache!
# use of cache!
# 5483 : ['Q650214', 'P19', 'Q1295', 'where was christian nerlinger born']
# use of cache!
# use of cache!
# 5484 : ['Q670305', 'P495', 'Q38', 'where is the film reality from?']
# use of cache!
# use of cache!
# 5485 : ['Q2601200', 'P136', 'Q343568', 'what is the cvg genre of disneys pk: out of the shadows']
# use of cache!
# use of cache!
# 5486 : ['Q7228662', 'P495', 'Q30', 'What country did the show poolside chats originate in?']
# use of cache!
# use of cache!
# 5487 : ['Q1673314', 'P131', 'Q3206', 'what is the administrative parent of shire of irwin?']
# use of cache!
# 5488 : ['Q334147', 'P19', 'Q220', 'which famous city is julius evola from']
# use of cache!
# use of cache!
# 5489 : ['Q4799526', 'P20', 'Q6254080', 'where did arthur lionel pugh norrington die']
# use of cache!
# use of cache!
# 5490 : ['Q2534502', 'P27', 'Q30', 'What is the nationality of thomas hill (painter)?']
# use of cache!
# use of cache!
# 5491 : ['Q37073', 'R136', 'Q7035220', 'what artist is known for  pop music ']
# use of cache!
# use of cache!
# 5492 : ['Q4839295', 'P495', 'Q30', 'What is the country of origin for back in the day?']
# use of cache!
# use of cache!
# 5493 : ['Q595769', 'P131', 'Q370654', 'what county and state is the city muskego in ']
# use of cache!
# 5494 : ['Q1768977', 'R179', 'Q150169', 'What is the title of a game in the fire emblem series']
# use of cache!
# 5495 : ['Q785430', 'P170', 'Q1544996', 'who created young justice']
# use of cache!
# 5496 : ['Q164963', 'P162', 'Q4465', 'who produced the lord of the rings: the two towers?']
# use of cache!
# use of cache!
# 5497 : ['Q571689', 'P21', 'Q6581097', 'what sex is ole hallesby']
# use of cache!
# use of cache!
# 5498 : ['Q918502', 'P264', 'Q183387', 'what music company is bruce hornsby with?']
# use of cache!
# use of cache!
# 5499 : ['Q353369', 'P19', 'Q84', "what was john mitchell kemble's place of birth"]
# use of cache!
# use of cache!
# 5500 : ['Q7614170', 'P19', 'Q776662', 'where was steve tully born ']
# use of cache!
# Labels Identified: 5500 Cache Size: 7306
# 5501 : ['Q4934191', 'P413', 'Q1149560', 'What position in baseball does bob thorpe play?']
# use of cache!
# use of cache!
# 5502 : ['Q1351392', 'P19', 'Q72', 'Where was eric kress born?']
# use of cache!
# 5503 : ['Q952833', 'P131', 'Q127238', 'which county is buckner a part of ']
# use of cache!
# 5504 : ['Q392', 'R676', 'Q1419882', 'what lyrics did bob dylan write']
# use of cache!
# use of cache!
# 5505 : ['Q6229422', 'P20', 'Q6106', 'where did john didion pass away in']
# use of cache!
# use of cache!
# 5506 : ['Q1838622', 'P495', 'Q27', 'what country created the film nothing personal']
# use of cache!
# use of cache!
# 5507 : ['Q1019255', 'P131', 'Q507459', 'What county does vevay belong to']
# use of cache!
# 5508 : ['Q6967143', 'P19', 'Q117', 'what country is nasir lamine from?']
# use of cache!
# use of cache!
# 5509 : ['Q7744614', 'P175', 'Q2026981', 'Who is the artist that created the album the kingdom']
# use of cache!
# 5510 : ['Q470779', 'R58', 'Q1074882', 'What is the name of a film by kinji fukasaku']
# use of cache!
# 5511 : ['Q54317', 'P123', 'Q1501379', 'who published the videogame star wars?']
# use of cache!
# use of cache!
# 5512 : ['Q82955', 'R106', 'Q315953', 'Who was a politician in Madagascar? ']
# use of cache!
# use of cache!
# 5513 : ['Q1210688', 'P21', 'Q6581097', 'What gender is Didz Hammond?']
# use of cache!
# use of cache!
# 5514 : ['Q7934910', 'P123', 'Q339228', 'who is the video game publisher of virtua cop: elite edition?']
# use of cache!
# use of cache!
# 5515 : ['Q484344', 'R136', 'Q462380', 'whats the name of a artist whose musical genre is  progressive metal']
# use of cache!
# use of cache!
# 5516 : ['Q719483', 'P21', 'Q6581097', 'Is the gender of gérard cooreman male or female?']
# use of cache!
# use of cache!
# 5517 : ['Q18383', 'R19', 'Q7327527', 'Name someone famous who was born in providence, rhode island']
# use of cache!
# use of cache!
# 5518 : ['Q519555', 'P27', 'Q145', 'what country gives eros vlahos nationality']
# use of cache!
# use of cache!
# 5519 : ['Q43845', 'R106', 'Q6145033', 'Who was a businessman from the 1900s?']
# use of cache!
# use of cache!
# 5520 : ['Q395494', 'P20', 'Q159288', 'where did john ireland die?']
# use of cache!
# 5521 : ['Q741572', 'P106', 'Q33999', "What is steve james's profession?"]
# use of cache!
# use of cache!
# 5522 : ['Q76727', 'P21', 'Q6581097', 'what is the biological gender of ernst jünger']
# use of cache!
# use of cache!
# 5523 : ['Q1070953', 'P404', 'Q6895044', 'what mode is intelligent qube set up for ']
# use of cache!
# use of cache!
# 5524 : ['Q1229424', 'P86', 'Q313537', 'who was a musician for shes out of control']
# use of cache!
# 5525 : ['Q2634187', 'P58', 'Q435920', 'Who wrote the tv episode a kind of a stopwatch?']
# use of cache!
# use of cache!
# 5526 : ['Q4021857', 'P19', 'Q37951', 'Where was eir aoi born?']
# use of cache!
# 5527 : ['Q6581097', 'R21', 'Q912184', 'Name someone who is a male character']
# use of cache!
# use of cache!
# 5528 : ['Q1444046', 'P136', 'Q157443', 'What genre is bubble boy?']
# use of cache!
# use of cache!
# 5529 : ['Q4385348', 'P404', 'Q208850', 'what type of game is colosseum: road to freedom']
# use of cache!
# use of cache!
# 5530 : ['Q1984772', 'P19', 'Q490', 'which italian city was niccolò castiglioni born']
# use of cache!
# use of cache!
# 5531 : ['Q111946', 'R131', 'Q2032379', 'in which us county is cerro gordo county found ']
# use of cache!
# 5532 : ['Q640416', 'P27', 'Q16', 'where was john george bowes from ']
# use of cache!
# use of cache!
# 5533 : ['Q503318', 'P19', 'Q90', 'Which city in France was jean-baptiste boussingault born']
# use of cache!
# use of cache!
# use of cache!
# 5534 : ['Q214831', 'P140', 'Q42504', 'what belief does david archuleta practice ']
# use of cache!
# use of cache!
# 5535 : ['Q3783328', 'P136', 'Q3071', 'what types of music is hard times and nursery rhymes']
# use of cache!
# use of cache!
# 5536 : ['Q7093535', 'P50', 'Q229480', 'Who authored one of ours?']
# use of cache!
# 5537 : ['Q193592', 'R413', 'Q5040323', 'What is the name of someone who is a midfielder']
# use of cache!
# use of cache!
# 5538 : ['Q7859642', 'P413', 'Q1048902', 'Which position did ty taubenheim play?']
# use of cache!
# use of cache!
# 5539 : ['Q7149687', 'P21', 'Q6581097', 'What is the sex of paul calvert?']
# use of cache!
# use of cache!
# 5540 : ['Q130232', 'R136', 'Q661202', 'name a netflix drama.']
# use of cache!
# use of cache!
# use of cache!
# 5541 : ['Q3222219', 'P364', 'Q150', 'which language is one for the road?']
# use of cache!
# use of cache!
# 5542 : ['Q2409483', 'R175', 'Q6692912', 'what album did the appleseed cast create ']
# use of cache!
# 5543 : ['Q101505', 'R175', 'Q1941366', "What's an album from deep purple"]
# use of cache!
# 5544 : ['Q4807036', 'P19', 'Q1354', 'where was asit sen born']
# use of cache!
# 5545 : ['Q5328516', 'P177', 'Q379648', 'what river runs under the east haddam bridge']
# use of cache!
# use of cache!
# 5546 : ['Q6147108', 'P264', 'Q843402', "What is jamie lee thurston's label?"]
# use of cache!
# use of cache!
# 5547 : ['Q7922251', 'P21', 'Q6581097', "what is vernon tomlin's gender?"]
# use of cache!
# use of cache!
# 5548 : ['Q1428750', 'R179', 'Q8054565', 'What is a name of an episode of the show flight of the conchords']
# use of cache!
# 5549 : ['Q867123', 'R136', 'Q94797', "what's a popular open world game"]
# use of cache!
# 5550 : ['Q5309286', 'P495', 'Q30', "what country is drums o' voodoo filmed in "]
# use of cache!
# use of cache!
# 5551 : ['Q235077', 'R86', 'Q3501095', 'what films did jerry goldsmith contribute music to']
# use of cache!
# 5552 : ['Q7062337', 'P136', 'Q53094', 'what kind of comdey is not the end of the world']
# use of cache!
# 5553 : ['Q2900257', 'P20', 'Q60', 'where did jim boyd pass away']
# use of cache!
# use of cache!
# 5554 : ['Q5606354', 'P27', 'Q30', 'What country is greg toler from']
# use of cache!
# use of cache!
# 5555 : ['Q608304', 'P19', 'Q3054408', 'dwayne roloson was born here.']
# use of cache!
# 5556 : ['Q5080879', 'P21', 'Q6581097', 'What gender is charles meade']
# use of cache!
# use of cache!
# 5557 : ['Q11727900', 'P20', 'Q84', 'which european city did john henry tudhope die in']
# use of cache!
# use of cache!
# 5558 : ['Q49202', 'R19', 'Q358746', 'Who was born in greenwich?']
# use of cache!
# use of cache!
# 5559 : ['Q1760854', 'P364', 'Q1860', 'Which language was gentlemen marry brunettes released in']
# use of cache!
# use of cache!
# 5560 : ['Q779945', 'P19', 'Q21178', 'what was the name of the town morten jørgensen was born in']
# use of cache!
# 5561 : ['Q8046638', 'P136', 'Q11366', 'What genre of music is yael yuzon']
# use of cache!
# use of cache!
# 5562 : ['Q2551479', 'P1303', 'Q6607', 'does carlos alomar play guitar or drums']
# use of cache!
# use of cache!
# 5563 : ['Q1360272', 'P19', 'Q541590', 'Where was john lloyd born']
# use of cache!
# 5564 : ['Q485509', 'R131', 'Q954830', 'What is the name of a city located in pine county?']
# use of cache!
# 5565 : ['Q7672393', 'P495', 'Q928', 'in which asian country is tv patrol northwestern mindanao played']
# use of cache!
# use of cache!
# 5566 : ['Q3567134', 'P86', 'Q185928', 'Who wrote the soundtrack for welcome home?']
# use of cache!
# 5567 : ['Q6526228', 'P19', 'Q1486', 'where was leonel kaplan born?']
# use of cache!
# 5568 : ['Q100', 'R19', 'Q6282594', 'Name a person born in Boston. ']
# use of cache!
# use of cache!
# 5569 : ['Q79135', 'P20', 'Q1741', 'In which city did ludwig von wallmoden-gimborn die?']
# use of cache!
# use of cache!
# 5570 : ['Q252835', 'P21', 'Q6581097', 'What is teh gender of eriks Ādamsons?']
# use of cache!
# use of cache!
# 5571 : ['Q6724194', 'P21', 'Q6581097', 'which gender is mack bolan']
# use of cache!
# use of cache!
# 5572 : ['Q377725', 'P21', 'Q6581097', 'what is the gender of peter berngardovich struve?']
# use of cache!
# use of cache!
# 5573 : ['Q439911', 'R344', 'Q1106851', 'Ellen Kuras collaborated on these 3 short films.']
# use of cache!
# use of cache!
# 5574 : ['Q2440503', 'P27', 'Q30', 'what is the nationality of pauline bush']
# use of cache!
# use of cache!
# 5575 : ['Q6968891', 'P20', 'Q138391', 'where did nathan barnert die?']
# use of cache!
# 5576 : ['Q260125', 'R57', 'Q7945266', 'Which film did john g. avildsen direct?']
# use of cache!
# 5577 : ['Q147778', 'R509', 'Q299168', 'who died from cirrhosis?']
# use of cache!
# 5578 : ['Q6680120', 'P175', 'Q4931799', 'Name the artist of the album lord of the past']
# use of cache!
# use of cache!
# 5579 : ['Q7405055', 'P264', 'Q183412', 'What label is sally anthony associated with?']
# use of cache!
# use of cache!
# 5580 : ['Q7004736', 'P177', 'Q4915', 'what river does the neville island bridge corss']
# use of cache!
# 5581 : ['Q1939373', 'P413', 'Q528145', 'what position does rohan marley play ']
# use of cache!
# use of cache!
# 5582 : ['Q1929298', 'P19', 'Q10744', 'Where was michael schweighöfer born?']
# use of cache!
# 5583 : ['Q1434', 'R40', 'Q1430', 'who was the parent of commodus']
# use of cache!
# 5584 : ['Q7373094', 'P20', 'Q862679', 'Where did roy m. davenport die?']
# use of cache!
# 5585 : ['Q372256', 'R57', 'Q5098623', 'which 2004 comedy film did don mckellar directed?']
# use of cache!
# 5586 : ['Q936866', 'R58', 'Q1749806', 'what film did joe carnahan write ']
# use of cache!
# use of cache!
# 5587 : ['Q33999', 'R106', 'Q5642754', 'Who is a famous actor during the silent film era?']
# use of cache!
# use of cache!
# 5588 : ['Q1460197', 'P21', 'Q6581097', "what is howard komives's gender"]
# use of cache!
# use of cache!
# 5589 : ['Q167051', 'P136', 'Q130232', 'What type of film is "The Dark Side of the Sun"?']
# use of cache!
# use of cache!
# 5590 : ['Q4705668', 'P21', 'Q6581097', 'What is the gender of alain joly?']
# use of cache!
# use of cache!
# 5591 : ['Q113052', 'P344', 'Q585668', 'who was the cinematographer for elizabethtown (film)']
# use of cache!
# 5592 : ['Q431252', 'P162', 'Q514913', 'who produced jackie brown (film)']
# use of cache!
# use of cache!
# 5593 : ['Q7660987', 'P19', 'Q18383', 'what is sylvia poggiolis place of birth']
# use of cache!
# use of cache!
# 5594 : ['Q261724', 'P175', 'Q121507', 'who is the singer of the diary of alicia keys album']
# use of cache!
# 5595 : ['Q1325753', 'R58', 'Q727016', 'Which film did eleanore griffin contribute film story to']
# use of cache!
# 5596 : ['Q2774245', 'P136', 'Q193355', 'does crawler play blues-rock or classical']
# use of cache!
# 5597 : ['Q5221412', 'P27', 'Q96', 'which country does dany saadia belong to ']
# use of cache!
# use of cache!
# 5598 : ['Q2837766', 'P19', 'Q1930', 'Where was allan rock born']
# use of cache!
# 5599 : ['Q16266958', 'P404', 'Q208850', 'What type of gameplay is available in nba jam 99']
# use of cache!
# use of cache!
# 5600 : ['Q755105', 'P105', 'Q7432', 'what is largemouth bass']
# use of cache!
# use of cache!
# Labels Identified: 5600 Cache Size: 7440
# 5601 : ['Q989495', 'P136', 'Q484344', 'what genre is empire considered']
# use of cache!
# use of cache!
# 5602 : ['Q1297', 'R19', 'Q908642', 'Name a person born in chicago.']
# use of cache!
# use of cache!
# 5603 : ['Q226730', 'R136', 'Q12037390', 'what is a silent film from 1927']
# use of cache!
# use of cache!
# 5604 : ['Q19204627', 'R106', 'Q5256586', 'who was an american football player who played for the tennessee oilers?']
# use of cache!
# use of cache!
# 5605 : ['Q457864', 'R57', 'Q1744972', 'What is the name of a film that friz freleng directed?']
# use of cache!
# use of cache!
# 5606 : ['Q102316', 'P27', 'Q183', 'what country is paul gratzik from']
# use of cache!
# use of cache!
# 5607 : ['Q708694', 'P413', 'Q336286', 'which football position is gregg berhalter charged of ']
# use of cache!
# use of cache!
# 5608 : ['Q1326154', 'R413', 'Q6933893', 'what is the name of a first baseman in baseball']
# use of cache!
# use of cache!
# 5609 : ['Q2913373', 'P81', 'Q152029', 'What is the transit line for the stop haymarket?']
# use of cache!
# 5610 : ['Q370264', 'P27', 'Q16', 'what country is christopher robinson a citizen of']
# use of cache!
# use of cache!
# 5611 : ['Q7813436', 'P495', 'Q928', 'What is the country of origin of the show tok! tok! tok! isang milyon pasok!']
# use of cache!
# use of cache!
# 5612 : ['Q16001440', 'P27', 'Q30', 'What country was malouf abraham, sr. born to']
# use of cache!
# use of cache!
# 5613 : ['Q180852', 'P21', 'Q6581072', 'is zhang ziyi female or male']
# use of cache!
# use of cache!
# 5614 : ['Q5121470', 'P136', 'Q8261', 'What genre is the book circle of friends?']
# use of cache!
# use of cache!
# use of cache!
# 5615 : ['Q4938547', 'P20', 'Q1754', 'Where did ellen lundström die']
# use of cache!
# use of cache!
# 5616 : ['Q7142651', 'P495', 'Q145', 'which country filmed passing shadows']
# use of cache!
# use of cache!
# 5617 : ['Q1492', 'R19', 'Q11923043', 'Who is a notable figure that was born in barcelona']
# use of cache!
# 5618 : ['Q2870425', 'R1431', 'Q18162623', 'what films have been produced by jun lana?']
# use of cache!
# 5619 : ['Q445899', 'P19', 'Q1748', 'Where was gunnar johansen born in Denmark?']
# use of cache!
# use of cache!
# 5620 : ['Q582715', 'P31', 'Q3863', 'what celestial object is 2974 holden']
# use of cache!
# use of cache!
# 5621 : ['Q458750', 'P27', 'Q30', 'what nationality is lucille clifton?']
# use of cache!
# use of cache!
# 5622 labels retrieved!

# %%
df['subject_label']=subject_labels
df['predicate_label']=predicate_labels
df['object_label']=object_labels
df.to_csv('wsq-labels.csv')
df.head()
# Out:
#     subject predicate    object  \
# 0  Q7358590       P20  Q1637790
# 1   Q154335      P509    Q12152
# 2  Q2747238      P413  Q5059480
# 3    Q62498       P21  Q6581097
# 4   Q182485      P413  Q1143358
#
#                                             question      subject_label  \
# 0                        Where did roger marquis die      Roger Marquis
# 1          what was the cause of death of yves klein         Yves Klein
# 2              What position does carlos gomez play?       Carlos Gómez
# 3               how does engelbert zaschka identify   Engelbert Zaschka
# 4  what position does pee wee reese play in baseball      Pee Wee Reese
#
#                         predicate_label           object_label
# 0                        place of death                Holyoke
# 1                        cause of death  myocardial infarction
# 2  position played on team / speciality         center fielder
# 3                         sex or gender                   male
# 4  position played on team / speciality              shortstop
