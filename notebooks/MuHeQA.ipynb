# %% [markdown]
# # Entity Recognition

# %%
# %%capture
# !pip install --upgrade pip
# !pip install flair
# !pip install unidecode

# %%
import logging
#logging.basicConfig(filename='myfirstlog.log',level=logging.INFO,filemode='w',format='%(asctime)s | %(name)s | %(levelname)s | %(message)s')
logging.basicConfig(level=logging.INFO,format='%(asctime)s | %(name)s | %(levelname)s | %(message)s')
logging.info('This message will be logged')
logging.debug('This message will not be logged')

# %%
import unidecode
import hashlib

# PoS tagger
from flair.data import Sentence
from flair.models import SequenceTagger

# uncased NER model
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

def hash_text(text):
    hash_object = hashlib.md5(text.encode())
    md5_hash = hash_object.hexdigest()
    return str(md5_hash) 

pos_language_model = "flair/pos-english"
ner_language_model = "dslim/bert-base-NER-uncased"

ner_tagger = SequenceTagger.load(pos_language_model)
ner_tokenizer = AutoTokenizer.from_pretrained(ner_language_model)
ner_model = AutoModelForTokenClassification.from_pretrained(ner_language_model)
ner_nlp = pipeline("ner", model=ner_model, tokenizer=ner_tokenizer)

entities_cache = {}

def unicase(label):
  return unidecode.unidecode(label.strip()).lower()

def get_pos_entities(text,main_categories=['CD','NN','NNS','NNP','NNPS'],additional_categories=['JJ','NNS','CC'],drop_categories=['IN']):
    # make sentence
    sentence = Sentence(text)

    # predict NER tags
    ner_tagger.predict(sentence)

    # iterate over entities 
    entities = []
    current_entity = ""
    partial_entity = ""
    for t in sentence.tokens:
        for label in t.annotation_layers.keys():
            text = t.text
            label = t.get_labels(label)[0].value   
            if (label in main_categories):
                if (len(partial_entity)>0):
                  current_entity = partial_entity + " " + text
                  partial_entity = ""
                elif (current_entity == ""):
                  current_entity += text
                else:
                    current_entity += " " + text
            elif(label in additional_categories):
              if (len(current_entity)>0):
                current_entity += " " + text
              elif (len(partial_entity)>0):
                partial_entity += " " + text
              else:
                partial_entity += text
            elif(label in drop_categories):
               current_entity = ""
               partial_entity = ""
            elif len(current_entity) > 0:
                entities.append(current_entity)
                current_entity = ""
                partial_entity = ""
          
    if (len(current_entity)>0):
        entities.append(current_entity)
    return entities

def get_entities(text,additional=True):
    key = hash_text(text)
    if (key in entities_cache):
        #print("use of entities_cache!")
        return entities_cache[key]
    entities = []
    entity = ""
    index = -1
    offset = -1
    for token in ner_nlp(text):
        if (index == -1):
            index = token['index']
            offset = token['start']
        word = token['word']
        if (word[0] == '#'):
            word = token['word'].replace("#","")
            
        if (token['start']== offset):
            entity += word
        elif (token['index']-index < 2):
            entity += " " + word
        else:
            entities.append(entity)
            entity = word
        index = token['index']
        offset = token['end']
        
    if (len(entity) > 0):    
        entities.append(entity)
    if additional:      
      pos_entities = [unicase(e) for e in get_pos_entities(text)]      
      if (len(entities) == 0):
        return pos_entities
      final_entities = [] 
      for e in entities:
          final_entity = e
          for pe in pos_entities:
            if (e in pe):
              final_entity = pe
          final_entities.append(final_entity)
      if (len(final_entities)>0):
        return list(set(final_entities))
    entities_cache[key] = entities
    return entities
# Out:
# 2022-05-03 11:35:20,037 loading file /Users/cbadenes/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# 2022-05-03 11:35:20,820 SequenceTagger predicts: Dictionary with 53 tags: <unk>, O, UH, ,, VBD, PRP, VB, PRP$, NN, RB, ., DT, JJ, VBP, VBG, IN, CD, NNS, NNP, WRB, VBZ, WDT, CC, TO, MD, VBN, WP, :, RP, EX, JJR, FW, XX, HYPH, POS, RBR, JJS, PDT, NNPS, RBS, AFX, WP$, -LRB-, -RRB-, ``, '', LS, $, SYM, ADD

# %%
text = "How many Turing awards have people from Austria won?"
print("PoS entities:",get_pos_entities(text))
print("Entities:", get_entities(text))
# Out:
# PoS entities: ['many Turing awards', 'Austria']
# Entities: ['austria', 'many turing awards']

# %% [markdown]
# # Entity Linking

# %%
# %%capture
# !pip install sentence-transformers
# !pip3 install sparqlwrapper

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import time
from SPARQLWrapper import SPARQLWrapper, JSON  
import pandas as pd
import urllib.request as url
import json
import requests

sentence_language_model = "sentence-transformers/all-distilroberta-v1"
sentence_model = SentenceTransformer(sentence_language_model)
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/cbadenes/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/cbadenes/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
wiki_cache = {}
dbpedia_cache = {}

# %%
def lemmatize(text):
  result = []
  for token in text.split(" "):
    result.append(lemmatizer.lemmatize(token))
  return " ".join(result)

print("Lemma:",lemmatize("Turing awards"))

def sort_by_similar(text,texts):
  sentences = [text]
  sentences.extend(texts)
  embeddings = sentence_model.encode(sentences)
  sim_list = []
  index=0
  for e in embeddings[1:]:
    ref = embeddings[0]
    score = cosine_similarity([ref], [e])
    score_val = round(score[0][0], 1)
    sim_list.append({'id':index, 'text':texts[index], 'score':score_val})  
    index+=1
  sim_list.sort(key=lambda x: x.get('score'),reverse=True)
  return sim_list

def get_top_candidates(ref_text,candidates,max=-1):
  top_candidates = []
  if (len(candidates) == 0):
        return top_candidates
  sorted_candidates = sort_by_similar(ref_text,[c['text'] for c in candidates])  
  best_score = sorted_candidates[0]['score']
  for index, c in enumerate(sorted_candidates):
    if (index < max) or (c['score'] == best_score):
        candidate = candidates[c['id']]
        candidate['score'] = c['score']
        top_candidates.append(candidate)
  return top_candidates  

def print_candidates(criteria,candidates):
    print("## Sorted Candidates by",criteria,": ",[{'name':c['label'], 'id': c['id'], 'description':c['description'],'score':c['score']} for c in candidates])

def get_resources_by_candidates(context,label,candidates,max=-1):
  if (len(candidates) == 0):
    return []
  # sort candidates by name/label
  candidates_by_name = []  
  top_candidates_by_name = get_top_candidates(label,[ {'id':i, 'text':c['label'] } for i,c in enumerate(candidates)],10)
  for t in top_candidates_by_name:
    candidate = candidates[t['id']]
    candidate['score'] = t['score']
    candidates_by_name.append(candidate)
  #print_candidates("By Name",candidates_by_name)
  
  # sort candidates by properties
  candidates_by_properties = []
  candidate_properties = []
  for i,c in enumerate(candidates_by_name):
     for p in c['properties']:
        candidate_properties.append({'id':i, 'text':p['value'] })
  top_candidates_by_prop = get_top_candidates(context.replace(c['label'],""),candidate_properties,10) 
  for t in top_candidates_by_prop:
     candidate = candidates_by_name[t['id']]
     if (candidate not in candidates_by_properties):
        candidate['score'] = (2*candidate['score'] + 4*t['score']) / 6.0
        candidates_by_properties.append(candidate)
  #print_candidates("By Properties",candidates_by_properties)
  
        
  # sort candidates by description
  candidates_by_description = []
  top_candidates_by_desc = get_top_candidates(context.replace(c['label'],""),[ {'id':i, 'text':c['description'] } for i,c in enumerate(candidates_by_properties)],max)    
  for t in top_candidates_by_desc:
     candidate = candidates_by_properties[t['id']]
     if (candidate not in candidates_by_description):
        candidate['score'] = (2*candidate['score'] + 1*t['score']) / 3.0
        candidates_by_description.append(candidate)  
  #print_candidates("By Description",candidates_by_description)
  return candidates_by_description

##########################################################################################
# Wikidata Linker
##########################################################################################
wiki_sparql = SPARQLWrapper("https://query.wikidata.org/sparql",agent='Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36')
wiki_sparql.setReturnFormat(JSON)
wiki_sparql.setTimeout(timeout=60)

def get_wikidata_properties(entity,use_cache=False):
  if (use_cache) and (entity in wiki_cache):
    #print("use of cache!")
    return wiki_cache[entity].copy()
  query = """
      PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
      PREFIX wd: <http://www.wikidata.org/entity/> 
      SELECT distinct ?prop ?propLabel
      WHERE
      {
        { wd:ENTITY ?a ?b }
              union
              { ?s ?a wd:ENTITY } .

        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } 
        # ?prop wikibase:directClaim ?a .
      } 
      LIMIT 250
      """
  query_text = query.replace('ENTITY',entity)
  wiki_sparql.setQuery(query_text)
  result = []
  while (len(result) == 0):
    try:
        ret = wiki_sparql.queryAndConvert()
        for r in ret["results"]["bindings"]:
            if ('propLabel' in r) and ('value' in r['propLabel']):
                    value = r['propLabel']['value']
                    id = r['prop']['value'].split("http://www.wikidata.org/entity/")[1]
                    if ('id' not in value.lower()) and ('link' not in value.lower()) and ('has abstract' not in value.lower()) and ('wiki' not in value.lower()) and ('instance of' not in value.lower()):
                        result.append({'id':id, 'value':value})
    except Exception as e:
        print("Error on wikidata property query:",e,"->",query_text)
    break           
  wiki_cache[entity] = result
  return result

def get_wikidata_candidates(label,use_cache=True,verbose=False):
    if (use_cache) and (label in wiki_cache):
      #print("use of cache for label:",label)
      return wiki_cache[label].copy()
    candidates = []
    if (label==""):
        return candidates
    # type: One of the following values: form, form, item, lexeme, property, sense, sense
    headers = { 'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    query_path = "https://www.wikidata.org/w/api.php?action=wbsearchentities&search=QUERY_TEXT&language=en&limit=10&type=item&format=json"
    request = query_path.replace("QUERY_TEXT",label)
    if (verbose):
        print("Request:",request)
    r = requests.get(request,headers = headers)
    if (len(r.json()['search']) == 0):
      if (verbose):
        print("search by lemma:",lemmatize(label))
      r = requests.get(query_path.replace("QUERY_TEXT",lemmatize(label)))
      size = len(label.split(" "))
      index = 1
      while(('search' in r.json()) and (len(r.json()['search']) == 0) and (index<size)):
        query_label = " ".join(label.split(" ")[index:])
        index += 1  
        if (verbose):
          print("search by Partial Label:",query_label)
        r = requests.get(query_path.replace("QUERY_TEXT",query_label)) 
    if (verbose):
        print("Response:",r.json())
    for answer in r.json()['search']:
        description = ""
        if ('description' in answer['display']):
          description = answer['display']['description']['value']
          if 'disambiguation' in description:
                continue
        candidate = {
            'label': answer['display']['label']['value'],
            'id':answer['id'],
            'description' : description,
            'properties' : get_wikidata_properties(answer['id'],use_cache)
        }
        candidates.append(candidate)
    wiki_cache[label]=candidates
    #print("cache '",label,"' updated with:'",[c['id'] for c in candidates])
    return candidates

def get_wikidata_resource(context,entity,max=-1,use_cache=True):
    candidates = get_wikidata_candidates(entity,use_cache)
    lema_entity = lemmatize(entity)
    if (entity != lema_entity):
        candidate_ids = [c['id'] for c in candidates]
        for ac in get_wikidata_candidates(lema_entity,use_cache):
            if (ac['id'] not in candidate_ids):
                candidates.append(ac)
    resources = get_resources_by_candidates(context, entity, candidates,max)
    return resources

##########################################################################################
# DBpedia Linker
##########################################################################################

dbpedia_sparql = SPARQLWrapper("https://dbpedia.org/sparql/")
dbpedia_sparql.setReturnFormat(JSON)
dbpedia_sparql.setTimeout(timeout=60)

def get_dbpedia_properties(entity,use_cache=True):
    #select distinct ?property ?label {
      key = entity+"_props"
      if (use_cache) and (key in dbpedia_cache):
          #print("use of cache!")
          return dbpedia_cache[key].copy()
      query = """
          PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
          PREFIX dbr: <http://dbpedia.org/resource/> 
          select distinct ?property ?label {
              { <http://dbpedia.org/resource/ENTITY> ?property ?o }
              union
              { ?s ?property <http://dbpedia.org/resource/ENTITY> }

              optional { 
                # ?property rdfs:label ?label .
                filter langMatches(lang(?label), 'en')
              }
              filter(regex(?property, "property", "i" )) 
          }
          LIMIT 250
          """
      query_text = query.replace('ENTITY',entity)
      dbpedia_sparql.setQuery(query_text)
      result = []
      while (len(result) == 0):
        try:
            ret = dbpedia_sparql.queryAndConvert()
            for r in ret["results"]["bindings"]:
                if ('label' in r) and ('value' in r['label']):
                    value = r['label']['value']
                    id = r['property']['value']
                    if ('id' not in value.lower()) and ('link' not in value.lower()) and ('has abstract' not in value.lower()) and ('wiki' not in value.lower()) and ('instance of' not in value.lower()):
                        result.append({'id':id, 'value':value})
        except Exception as e:
            print("Error on SPARQL query:",e)
        break           
      dbpedia_cache[key] = result
      #print(len(result),"properties found")
      return result

def get_dbpedia_candidates(label,use_cache=True,verbose=False):
    if (use_cache) and (label in dbpedia_cache):
      #print("use of cache!")
      return dbpedia_cache[label].copy()
    candidates = []
    if (label==""):
        return candidates
    # type: One of the following values: form, form, item, lexeme, property, sense, sense
    #query_path = "https://www.wikidata.org/w/api.php?action=wbsearchentities&search=QUERY_TEXT&language=en&limit=10&type=item&format=json"
    query_path = "https://lookup.dbpedia.org/api/search?format=JSON&query=QUERY_TEXT&maxResults=10"
    url = query_path.replace("QUERY_TEXT",label)
    #print("->",url)
    r = requests.get(url)
    if (len(r.json()['docs']) == 0):
        if (verbose):
            print("Use of lemmatize literal:",lemmatize(label))
        r = requests.get(query_path.replace("QUERY_TEXT",lemmatize(label)))
        size = len(label.split(" "))
        index = 1  
        while(('search' in r.json()) and (len(r.json()['search']) == 0) and (index<size)):
            query_label = " ".join(label.split(" ")[index:])
            index += 1  
            if (verbose):
              print("search by Partial Label:",query_label)
            r = requests.get(query_path.replace("QUERY_TEXT",query_label)) 
    for answer in r.json()['docs']:
        description,label,id = "","",""
        properties = []
        if ('comment' in answer) and (len(answer['comment']) > 0):
          description = answer['comment'][0].replace("<B>","").replace("</B>","")
        if ('resource' in answer) and (len(answer['resource']) > 0):
          id = answer['resource'][0].split("http://dbpedia.org/resource/")[1]
          properties = get_dbpedia_properties(id,use_cache)
        if ('label' in answer) and (len(answer['label']) > 0):
          label = answer['label'][0].replace("<B>","").replace("</B>","")
        else:
          label = id        
        candidate = {
            'label': label,
            'id':id,
            'description' : description,
            'properties' : properties
        }
        candidates.append(candidate)
    dbpedia_cache[label]=candidates
    return candidates

def get_dbpedia_resource(context,entity,max=-1,use_cache=True):
    candidates = get_dbpedia_candidates(entity,use_cache)
    lema_entity = lemmatize(entity)
    if (entity != lema_entity):
        candidate_ids = [c['id'] for c in candidates]
        for ac in get_dbpedia_candidates(lema_entity,use_cache):
            if (ac['id'] not in candidate_ids):
                candidates.append(ac)
    resources = get_resources_by_candidates(context, entity, candidates,max)
    return resources
# Out:
# Lemma: Turing award

# %%
for r in get_wikidata_resource("What position does carlos gomez play?","Carlos Gomez",2,use_cache=True):
    print(r['id'],r['label'],r['description'])
# Out:
# ## Sorted Candidates by By Name :  [{'name': 'Carlos Gomez', 'id': 'Q89898891', 'description': 'researcher', 'score': 1.0}, {'name': 'Carlos A Gomez', 'id': 'Q91676432', 'description': 'researcher (ORCID 0000-0001-5486-5710)', 'score': 0.9}, {'name': 'Carlos Gómez', 'id': 'Q949506', 'description': 'American actor', 'score': 0.8}, {'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.8}, {'name': 'Carlos Gómez', 'id': 'Q51944192', 'description': 'researcher', 'score': 0.8}, {'name': 'Carlos Gómez', 'id': 'Q2747238', 'description': 'Dominican Republic baseball player', 'score': 0.8}, {'name': 'Carlos Gómez', 'id': 'Q3660067', 'description': 'Argentinian comics artist', 'score': 0.8}, {'name': 'Carlos Gómez', 'id': 'Q5750557', 'description': 'Chilean association football player born 1992', 'score': 0.8}, {'name': 'Carlos M Gómez', 'id': 'Q40124092', 'description': 'researcher', 'score': 0.7}]
# ## Sorted Candidates by By Properties :  [{'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.5333333412806193}, {'name': 'Carlos Gómez', 'id': 'Q2747238', 'description': 'Dominican Republic baseball player', 'score': 0.5333333412806193}, {'name': 'Carlos Gómez', 'id': 'Q5750557', 'description': 'Chilean association football player born 1992', 'score': 0.5333333412806193}, {'name': 'Carlos Gomez', 'id': 'Q89898891', 'description': 'researcher', 'score': 0.46666666865348816}, {'name': 'Carlos A Gomez', 'id': 'Q91676432', 'description': 'researcher (ORCID 0000-0001-5486-5710)', 'score': 0.43333332737286884}, {'name': 'Carlos Gómez', 'id': 'Q949506', 'description': 'American actor', 'score': 0.4000000059604645}]
# ## Sorted Candidates by By Description :  [{'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.5222222275204128}, {'name': 'Carlos Gómez', 'id': 'Q2747238', 'description': 'Dominican Republic baseball player', 'score': 0.488888896173901}]
# Q203210 Carlos Gómez Mexican footballer (1952-2017)
# Q2747238 Carlos Gómez Dominican Republic baseball player

# %%
for r in get_dbpedia_candidates("roger marquis",use_cache=False,verbose=False):
    print("[",r['id'],"]",r['label'],":",r['properties'])
# Out:
# [ Roger_Marquis,_2nd_Earl_of_Woolton ] Roger Marquis, 2nd Earl of Woolton : [{'id': 'http://dbpedia.org/property/after', 'value': 'after'}, {'id': 'http://dbpedia.org/property/before', 'value': 'before'}, {'id': 'http://dbpedia.org/property/coronet', 'value': 'coronet'}, {'id': 'http://dbpedia.org/property/creationDate', 'value': 'creation date'}, {'id': 'http://dbpedia.org/property/crest', 'value': 'crest'}, {'id': 'http://dbpedia.org/property/escutcheon', 'value': 'escutcheon'}, {'id': 'http://dbpedia.org/property/motto', 'value': 'motto'}, {'id': 'http://dbpedia.org/property/supporters', 'value': 'supporters'}, {'id': 'http://dbpedia.org/property/title', 'value': 'title'}, {'id': 'http://dbpedia.org/property/years', 'value': 'years'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}, {'id': 'http://dbpedia.org/property/parents', 'value': 'parents'}, {'id': 'http://dbpedia.org/ontology/parent', 'value': 'parent'}]
# [ Ça_Ira_(opera) ] Ça Ira (opera) : [{'id': 'http://dbpedia.org/property/name', 'value': 'name'}, {'id': 'http://dbpedia.org/property/accessDate', 'value': 'access-date'}, {'id': 'http://dbpedia.org/property/artist', 'value': 'artist'}, {'id': 'http://dbpedia.org/property/award', 'value': 'award'}, {'id': 'http://dbpedia.org/property/certmonth', 'value': 'certmonth'}, {'id': 'http://dbpedia.org/property/certyear', 'value': 'certyear'}, {'id': 'http://dbpedia.org/property/cover', 'value': 'cover'}, {'id': 'http://dbpedia.org/property/genre', 'value': 'genre'}, {'id': 'http://dbpedia.org/property/label', 'value': 'label'}, {'id': 'http://dbpedia.org/property/length', 'value': 'length'}, {'id': 'http://dbpedia.org/property/nextTitle', 'value': 'next title'}, {'id': 'http://dbpedia.org/property/nextYear', 'value': 'next year'}, {'id': 'http://dbpedia.org/property/prevTitle', 'value': 'prev title'}, {'id': 'http://dbpedia.org/property/prevYear', 'value': 'prev year'}, {'id': 'http://dbpedia.org/property/recorded', 'value': 'recorded'}, {'id': 'http://dbpedia.org/property/region', 'value': 'region'}, {'id': 'http://dbpedia.org/property/released', 'value': 'released'}, {'id': 'http://dbpedia.org/property/relmonth', 'value': 'relmonth'}, {'id': 'http://dbpedia.org/property/relyear', 'value': 'relyear'}, {'id': 'http://dbpedia.org/property/rev', 'value': 'rev'}, {'id': 'http://dbpedia.org/property/title', 'value': 'title'}, {'id': 'http://dbpedia.org/property/type', 'value': 'type'}, {'id': 'http://dbpedia.org/property/producer', 'value': 'producer'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}]
# [ Roger_Machado_Marques ] Roger Machado Marques : []
# [ Roger_Marquis ] Roger Marquis : [{'id': 'http://dbpedia.org/property/name', 'value': 'name'}, {'id': 'http://dbpedia.org/ontology/birthPlace', 'value': 'birth place'}, {'id': 'http://dbpedia.org/ontology/deathPlace', 'value': 'death place'}, {'id': 'http://dbpedia.org/property/deathPlace', 'value': 'death place'}, {'id': 'http://dbpedia.org/ontology/deathDate', 'value': 'death date'}, {'id': 'http://dbpedia.org/property/birthPlace', 'value': 'birth place'}, {'id': 'http://dbpedia.org/ontology/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/bats', 'value': 'bats'}, {'id': 'http://dbpedia.org/property/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/deathDate', 'value': 'death date'}, {'id': 'http://dbpedia.org/property/debutdate', 'value': 'debutdate'}, {'id': 'http://dbpedia.org/property/debutleague', 'value': 'debutleague'}, {'id': 'http://dbpedia.org/property/debutteam', 'value': 'debutteam'}, {'id': 'http://dbpedia.org/property/debutyear', 'value': 'debutyear'}, {'id': 'http://dbpedia.org/property/finaldate', 'value': 'finaldate'}, {'id': 'http://dbpedia.org/property/finalleague', 'value': 'finalleague'}, {'id': 'http://dbpedia.org/property/finalteam', 'value': 'finalteam'}, {'id': 'http://dbpedia.org/property/finalyear', 'value': 'finalyear'}, {'id': 'http://dbpedia.org/property/position', 'value': 'position'}, {'id': 'http://dbpedia.org/property/stat1label', 'value': 'stat1label'}, {'id': 'http://dbpedia.org/property/stat1value', 'value': 'stat1value'}, {'id': 'http://dbpedia.org/property/stat2label', 'value': 'stat2label'}, {'id': 'http://dbpedia.org/property/stat2value', 'value': 'stat2value'}, {'id': 'http://dbpedia.org/property/stat3label', 'value': 'stat3label'}, {'id': 'http://dbpedia.org/property/stat3value', 'value': 'stat3value'}, {'id': 'http://dbpedia.org/property/statleague', 'value': 'statleague'}, {'id': 'http://dbpedia.org/property/teams', 'value': 'teams'}, {'id': 'http://dbpedia.org/property/throws', 'value': 'throws'}, {'id': 'http://dbpedia.org/ontology/position', 'value': 'position'}, {'id': 'http://dbpedia.org/ontology/debutTeam', 'value': 'debut team'}]
# [ Gaston-Robert,_Marquis_de_Banneville ] Gaston-Robert, Marquis de Banneville : [{'id': 'http://dbpedia.org/property/after', 'value': 'after'}, {'id': 'http://dbpedia.org/property/before', 'value': 'before'}, {'id': 'http://dbpedia.org/property/title', 'value': 'title'}, {'id': 'http://dbpedia.org/property/years', 'value': 'years'}]
# [ Marques_Houston ] Marques Houston : [{'id': 'http://dbpedia.org/property/name', 'value': 'name'}, {'id': 'http://dbpedia.org/ontology/birthPlace', 'value': 'birth place'}, {'id': 'http://dbpedia.org/property/birthPlace', 'value': 'birth place'}, {'id': 'http://dbpedia.org/ontology/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/alias', 'value': 'alias'}, {'id': 'http://dbpedia.org/property/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/birthName', 'value': 'birth name'}, {'id': 'http://dbpedia.org/property/occupation', 'value': 'occupation'}, {'id': 'http://dbpedia.org/property/relatives', 'value': 'relatives'}, {'id': 'http://dbpedia.org/property/spouse', 'value': 'spouse'}, {'id': 'http://dbpedia.org/property/yearsActive', 'value': 'years active'}, {'id': 'http://dbpedia.org/property/caption', 'value': 'caption'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}, {'id': 'http://dbpedia.org/ontology/occupation', 'value': 'occupation'}, {'id': 'http://dbpedia.org/ontology/activeYearsStartYear', 'value': 'active years start year'}, {'id': 'http://dbpedia.org/ontology/birthName', 'value': 'birth name'}, {'id': 'http://dbpedia.org/ontology/birthYear', 'value': 'birth year'}, {'id': 'http://dbpedia.org/property/chronology', 'value': 'chronology'}, {'id': 'http://dbpedia.org/property/artist', 'value': 'artist'}, {'id': 'http://dbpedia.org/property/associatedActs', 'value': 'associated acts'}, {'id': 'http://dbpedia.org/property/currentMembers', 'value': 'current members'}, {'id': 'http://dbpedia.org/property/extra', 'value': 'extra'}, {'id': 'http://dbpedia.org/property/starring', 'value': 'starring'}, {'id': 'http://dbpedia.org/property/themeMusicComposer', 'value': 'theme music composer'}, {'id': 'http://dbpedia.org/property/producer', 'value': 'producer'}, {'id': 'http://dbpedia.org/property/screenplay', 'value': 'screenplay'}, {'id': 'http://dbpedia.org/property/writer', 'value': 'writer'}, {'id': 'http://dbpedia.org/ontology/artist', 'value': 'performer'}, {'id': 'http://dbpedia.org/ontology/associatedBand', 'value': 'associated band'}, {'id': 'http://dbpedia.org/ontology/associatedMusicalArtist', 'value': 'associated musical artist'}, {'id': 'http://dbpedia.org/ontology/bandMember', 'value': 'band member'}, {'id': 'http://dbpedia.org/ontology/composer', 'value': 'composer'}, {'id': 'http://dbpedia.org/ontology/producer', 'value': 'producer'}, {'id': 'http://dbpedia.org/ontology/starring', 'value': 'starring'}, {'id': 'http://dbpedia.org/ontology/writer', 'value': 'writer'}]
# [ Vice_and_Virtue ] Vice and Virtue : [{'id': 'http://dbpedia.org/property/name', 'value': 'name'}, {'id': 'http://dbpedia.org/property/gross', 'value': 'gross'}, {'id': 'http://dbpedia.org/property/language', 'value': 'language'}, {'id': 'http://dbpedia.org/property/released', 'value': 'released'}, {'id': 'http://dbpedia.org/property/runtime', 'value': 'runtime'}, {'id': 'http://dbpedia.org/property/starring', 'value': 'starring'}, {'id': 'http://dbpedia.org/property/caption', 'value': 'caption'}, {'id': 'http://dbpedia.org/property/cinematography', 'value': 'cinematography'}, {'id': 'http://dbpedia.org/property/director', 'value': 'director'}, {'id': 'http://dbpedia.org/property/distributor', 'value': 'distributor'}, {'id': 'http://dbpedia.org/property/music', 'value': 'music'}, {'id': 'http://dbpedia.org/property/producer', 'value': 'producer'}, {'id': 'http://dbpedia.org/property/writer', 'value': 'writer'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}, {'id': 'http://dbpedia.org/ontology/Work/runtime', 'value': 'runtime (m)'}, {'id': 'http://dbpedia.org/ontology/cinematography', 'value': 'cinematography'}, {'id': 'http://dbpedia.org/ontology/director', 'value': 'film director'}, {'id': 'http://dbpedia.org/ontology/distributor', 'value': 'distributor'}, {'id': 'http://dbpedia.org/ontology/musicComposer', 'value': 'music composer'}, {'id': 'http://dbpedia.org/ontology/producer', 'value': 'producer'}, {'id': 'http://dbpedia.org/ontology/starring', 'value': 'starring'}, {'id': 'http://dbpedia.org/ontology/writer', 'value': 'writer'}, {'id': 'http://dbpedia.org/ontology/gross', 'value': 'gross ($)'}, {'id': 'http://dbpedia.org/ontology/runtime', 'value': 'runtime (s)'}]
# [ Simon_Marquis,_3rd_Earl_of_Woolton ] Simon Marquis, 3rd Earl of Woolton : [{'id': 'http://dbpedia.org/property/name', 'value': 'name'}, {'id': 'http://dbpedia.org/ontology/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/birthDate', 'value': 'birth date'}, {'id': 'http://dbpedia.org/property/birthname', 'value': 'birthname'}, {'id': 'http://dbpedia.org/property/children', 'value': 'children'}, {'id': 'http://dbpedia.org/property/coronet', 'value': 'coronet'}, {'id': 'http://dbpedia.org/property/creationDate', 'value': 'creation date'}, {'id': 'http://dbpedia.org/property/crest', 'value': 'crest'}, {'id': 'http://dbpedia.org/property/education', 'value': 'education'}, {'id': 'http://dbpedia.org/property/escutcheon', 'value': 'escutcheon'}, {'id': 'http://dbpedia.org/property/honorificPrefix', 'value': 'honorific prefix'}, {'id': 'http://dbpedia.org/property/motto', 'value': 'motto'}, {'id': 'http://dbpedia.org/property/occupation', 'value': 'occupation'}, {'id': 'http://dbpedia.org/property/parents', 'value': 'parents'}, {'id': 'http://dbpedia.org/property/spouse', 'value': 'spouse'}, {'id': 'http://dbpedia.org/property/supporters', 'value': 'supporters'}, {'id': 'http://dbpedia.org/property/title', 'value': 'title'}, {'id': 'http://dbpedia.org/property/years', 'value': 'years'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}, {'id': 'http://dbpedia.org/ontology/education', 'value': 'education'}, {'id': 'http://dbpedia.org/ontology/parent', 'value': 'parent'}, {'id': 'http://dbpedia.org/ontology/birthName', 'value': 'birth name'}, {'id': 'http://dbpedia.org/property/after', 'value': 'after'}, {'id': 'http://dbpedia.org/property/presentHolder', 'value': 'present holder'}]
# [ Emma_of_Hauteville ] Emma of Hauteville : [{'id': 'http://dbpedia.org/property/issue', 'value': 'issue'}, {'id': 'http://dbpedia.org/property/mother', 'value': 'mother'}, {'id': 'http://dbpedia.org/ontology/parent', 'value': 'parent'}]
# [ Angelo_Maccagnino ] Angelo Maccagnino : [{'id': 'http://dbpedia.org/property/date', 'value': 'date'}, {'id': 'http://dbpedia.org/property/langcode', 'value': 'langcode'}, {'id': 'http://dbpedia.org/ontology/thumbnail', 'value': 'thumbnail'}]

# %%
for r in get_wikidata_candidates("sam edward",use_cache=True):
    print(r['id'],r['label'],r['description'])

# %%
for p in get_dbpedia_properties("Roger_Marquis",use_cache=False):
    print(p)
# Out:
# {'id': 'http://dbpedia.org/property/name', 'value': 'name'}
# {'id': 'http://dbpedia.org/property/deathPlace', 'value': 'death place'}
# {'id': 'http://dbpedia.org/property/birthPlace', 'value': 'birth place'}
# {'id': 'http://dbpedia.org/property/bats', 'value': 'bats'}
# {'id': 'http://dbpedia.org/property/birthDate', 'value': 'birth date'}
# {'id': 'http://dbpedia.org/property/deathDate', 'value': 'death date'}
# {'id': 'http://dbpedia.org/property/debutdate', 'value': 'debutdate'}
# {'id': 'http://dbpedia.org/property/debutleague', 'value': 'debutleague'}
# {'id': 'http://dbpedia.org/property/debutteam', 'value': 'debutteam'}
# {'id': 'http://dbpedia.org/property/debutyear', 'value': 'debutyear'}
# {'id': 'http://dbpedia.org/property/finaldate', 'value': 'finaldate'}
# {'id': 'http://dbpedia.org/property/finalleague', 'value': 'finalleague'}
# {'id': 'http://dbpedia.org/property/finalteam', 'value': 'finalteam'}
# {'id': 'http://dbpedia.org/property/finalyear', 'value': 'finalyear'}
# {'id': 'http://dbpedia.org/property/position', 'value': 'position'}
# {'id': 'http://dbpedia.org/property/stat1label', 'value': 'stat1label'}
# {'id': 'http://dbpedia.org/property/stat1value', 'value': 'stat1value'}
# {'id': 'http://dbpedia.org/property/stat2label', 'value': 'stat2label'}
# {'id': 'http://dbpedia.org/property/stat2value', 'value': 'stat2value'}
# {'id': 'http://dbpedia.org/property/stat3label', 'value': 'stat3label'}
# {'id': 'http://dbpedia.org/property/stat3value', 'value': 'stat3value'}
# {'id': 'http://dbpedia.org/property/statleague', 'value': 'statleague'}
# {'id': 'http://dbpedia.org/property/teams', 'value': 'teams'}
# {'id': 'http://dbpedia.org/property/throws', 'value': 'throws'}

# %%
#wiki_cache['sam edward']=[]
#wiki_cache['sam edwards']=[]
print(lemmatize('sam edwards'))
for r in wiki_cache['sam edwards']:
    print(r['id'],r['label'],r['description'])

# %% [markdown]
# # Entity Summary

# %%
import hashlib

def verbalize(entity,property,value,verbose=False):
    tokens = ["The",property,"of",entity,"is",value]
    if (verbose):
        print("Tokens:",tokens)
    return " ".join(tokens)

def hash_text(text):
    hash_object = hashlib.md5(text.encode())
    md5_hash = hash_object.hexdigest()
    return str(md5_hash) 

##########################################################################################
# Wikidata Summarizer
##########################################################################################

def get_wikidata_property_value(filter,use_cache=True,verbose=False):
  key = hash_text(filter)
  if (use_cache) and (key in wiki_cache):
    #print("use of cache!")
    return wiki_cache[key].copy()
  query = """
      PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
      PREFIX bd: <http://www.bigdata.com/rdf#>
      PREFIX wd: <http://www.wikidata.org/entity/> 
      PREFIX wdt: <http://www.wikidata.org/prop/direct/>
      PREFIX wikibase: <http://wikiba.se/ontology#>
      SELECT distinct ?obj ?objLabel
      WHERE
      FILTER 
      LIMIT 250
      """
  query_text = query.replace('FILTER',filter)
  wiki_sparql.setQuery(query_text)
  result = []
  while (len(result) == 0):
    try:
        #if (verbose):
        #    print("SPARQL Query:",query_text)
        ret = wiki_sparql.queryAndConvert() 
        #if (verbose):
        #    print("SPARQL Response:",ret)
        for r in ret["results"]["bindings"]:
            id = r['obj']['value']
            value = id
            if ('objLabel' in r) and ('value' in r['objLabel']):
                    value = r['objLabel']['value']                
            if (' id ' not in value.lower()) and (' link ' not in value.lower()) and ('has abstract' not in value.lower()) and ('wiki' not in value.lower()) and ('instance of' not in value.lower()):
                    result.append({'id':id, 'value':value})
    except Exception as e:
        print("Error on wikidata property value query:",e,"->",query_text)
    break           
  wiki_cache[key] = result
  return result

def get_forward_wikidata_property_value(entity,property,use_cache=True,verbose=False): 
  #query_filter = """
  #            {
  #              wd:ENTITY p:PROPERTY ?data .
  #              ?data ps:PROPERTY ?obj .
  #              ?data pq:585 ?time .
  #              SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
  #            }
  #            ORDER BY DESC ( ?time )
  #            """
  query_filter = """
              {
                wd:ENTITY wdt:PROPERTY ?obj .
                SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
              }                            
              """
  return get_wikidata_property_value(query_filter.replace("ENTITY",entity).replace("PROPERTY",property),use_cache,verbose)

def get_backward_wikidata_property_value(entity,property,use_cache=True,verbose=False):
  query_filter = """
              {
                # ?obj wdt:PROPERTY wd:ENTITY .
                SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
              }                            
              """
  return get_wikidata_property_value(query_filter.replace("ENTITY",entity).replace("PROPERTY",property),use_cache,verbose)

def get_wikidata_summary(candidate,context,max=5,use_cache=True,verbose=False):
    candidate_id = candidate['id']
    properties = candidate['properties']
    top_properties = get_top_candidates(context.lower().replace(candidate['label'].lower(),""),[ {'id':i, 'text':p['value'] } for i,p in enumerate(properties)],max)
    if (verbose):
        print("Top Properties:", top_properties)    
    sentences = []
    for p in top_properties:
        property = properties[p['id']]
        if (verbose):
            print(property)
        for v in get_forward_wikidata_property_value(candidate_id,property['id'],verbose):
            if (verbose):
                print("Forward Value:",v)
            sentences.append(verbalize(candidate['label'],property['value'],v['value'],verbose)+".")
        for v in get_backward_wikidata_property_value(candidate_id,property['id'],verbose):
            if (verbose):
                print("Backward Value:",v)
            sentences.append(verbalize(candidate['label'],property['value'],v['value'],verbose)+".")
    return " ".join(sentences)
    
##########################################################################################
# DBpedia Summarizer
##########################################################################################

def get_dbpedia_property_value(filter,use_cache=True,verbose=False):
  key = hash_text(filter)
  if (use_cache) and (key in dbpedia_cache):
    #print("use of cache!")
    return dbpedia_cache[key].copy()
  query = """
      PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
      PREFIX dbr: <http://dbpedia.org/resource/> 
      select distinct ?object ?label {
          { FILTER }

          optional { 
            # ?object rdfs:label ?label .
            filter langMatches(lang(?label), 'en')
          }
      }
      LIMIT 250
      """
  query_text = query.replace('FILTER',filter) 
  dbpedia_sparql.setQuery(query_text)
  result = []
  while (len(result) == 0):
    try:
        if (verbose):
            print("SPARQL Query:",query_text)
        ret = dbpedia_sparql.queryAndConvert()
        if (verbose):
            print("SPARQL Response:",ret)
        for r in ret["results"]["bindings"]:
            id = r['object']['value']
            value = id
            if ('label' in r) and ('value' in r['label']):
                value = r['label']['value']            
            if (' id ' not in value.lower()) and (' link ' not in value.lower()) and ('has abstract' not in value.lower()) and ('wiki' not in value.lower()) and ('instance of' not in value.lower()):
                result.append({'id':id, 'value':value})
    except Exception as e:
        print("Error on SPARQL query:",e)
    break           
  dbpedia_cache[key] = result
  #print(len(result),"properties found")
  return result


def get_forward_dbpedia_property_value(entity,property,use_cache=True,verbose=False):
  query_filter ="<http://dbpedia.org/resource/ENTITY> <PROPERTY> ?object" 
  return get_dbpedia_property_value(query_filter.replace("ENTITY",entity).replace("PROPERTY",property),use_cache,verbose) 

def get_backward_dbpedia_property_value(entity,property,use_cache=True,verbose=False):
  query_filter ="?object <PROPERTY> <http://dbpedia.org/resource/ENTITY>"
  return get_dbpedia_property_value(query_filter.replace("ENTITY",entity).replace("PROPERTY",property),use_cache,verbose) 

def get_dbpedia_summary(candidate,context,max=5,use_cache=True,verbose=False):
    candidate_id = candidate['id']
    properties = candidate['properties']
    top_properties = get_top_candidates(context.lower().replace(candidate['label'].lower(),""),[ {'id':i, 'text':p['value'] } for i,p in enumerate(properties)],max)
    if (verbose):
        print("Top Properties:", top_properties)    
    sentences = []
    for p in top_properties:
        property = properties[p['id']]
        if (verbose):
            print(property)
        for v in get_forward_dbpedia_property_value(candidate_id,property['id'],use_cache,verbose):
            if (verbose):
                print("Forward Value:",v)
            sentences.append(verbalize(candidate['label'],property['value'],v['value'],verbose)+".")
        for v in get_backward_dbpedia_property_value(candidate_id,property['id'],use_cache,verbose):
            if (verbose):
                print("Backward Value:",v)
            sentences.append(verbalize(candidate['label'],property['value'],v['value'],verbose)+".")
    return " ".join(sentences)

# %%
sample_question = "What is the medication of schizophrenia?"
sample_entity = "schizophrenia"
top = 2


print("Summaries for question:",sample_question,"and entity:", sample_entity)
for index, candidate in enumerate(get_wikidata_resource(sample_question,sample_entity,top)):
    print(candidate['id'],"->",get_wikidata_summary(candidate,sample_question,use_cache=True,verbose=False))
# Out:
# Summaries for question: What is the medication of schizophrenia? and entity: schizophrenia
# ## Sorted Candidates by By Name :  [{'name': 'schizophrenia', 'id': 'Q41112', 'description': 'psychotic disorder characterized by emotional responsiveness and disintegration of thought process', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q55868331', 'description': 'scholarly article about schizophrenia', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q28267772', 'description': 'scientific article (publication date: 19 June 2004)', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q72240986', 'description': 'scientific article published on 01 March 1994', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q79226206', 'description': 'scientific article published on 01 October 2003', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q56959104', 'description': 'article', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q71574804', 'description': 'scientific article published on 01 January 1996', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q22242092', 'description': 'scientific article (publication date: 14 July 2007)', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q77397124', 'description': 'scientific article published on 01 April 1999', 'score': 1.0}, {'name': 'Schizophrenia', 'id': 'Q937894', 'description': 'album by Sepultura', 'score': 1.0}]
# ## Sorted Candidates by By Properties :  [{'name': 'schizophrenia', 'id': 'Q41112', 'description': 'psychotic disorder characterized by emotional responsiveness and disintegration of thought process', 'score': 0.6666666666666666}]
# ## Sorted Candidates by By Description :  [{'name': 'schizophrenia', 'id': 'Q41112', 'description': 'psychotic disorder characterized by emotional responsiveness and disintegration of thought process', 'score': 0.5444444484180874}]
# Q41112 -> The drug or therapy used for treatment of schizophrenia is pimozide. The drug or therapy used for treatment of schizophrenia is armodafinil. The drug or therapy used for treatment of schizophrenia is iloperidone. The drug or therapy used for treatment of schizophrenia is ziprasidone. The drug or therapy used for treatment of schizophrenia is zotepine. The drug or therapy used for treatment of schizophrenia is bexarotene. The drug or therapy used for treatment of schizophrenia is perphenazine. The drug or therapy used for treatment of schizophrenia is (Z)-thiothixene. The drug or therapy used for treatment of schizophrenia is brexpiprazole. The drug or therapy used for treatment of schizophrenia is acetophenazine. The drug or therapy used for treatment of schizophrenia is paliperidone. The drug or therapy used for treatment of schizophrenia is trifluoperazine. The drug or therapy used for treatment of schizophrenia is mesoridazine. The drug or therapy used for treatment of schizophrenia is (±)-molindone. The drug or therapy used for treatment of schizophrenia is carphenazine. The drug or therapy used for treatment of schizophrenia is olanzapine. The drug or therapy used for treatment of schizophrenia is haloperidol. The drug or therapy used for treatment of schizophrenia is chlorpromazine. The drug or therapy used for treatment of schizophrenia is clonazepam. The drug or therapy used for treatment of schizophrenia is aripiprazole. The drug or therapy used for treatment of schizophrenia is transclopenthixol. The drug or therapy used for treatment of schizophrenia is clozapine. The drug or therapy used for treatment of schizophrenia is reserpine. The drug or therapy used for treatment of schizophrenia is levosulpiride. The drug or therapy used for treatment of schizophrenia is (E)-chlorprothixene. The drug or therapy used for treatment of schizophrenia is pipotiazine. The drug or therapy used for treatment of schizophrenia is flupentixol. The drug or therapy used for treatment of schizophrenia is cariprazine. The drug or therapy used for treatment of schizophrenia is (R,R)-asenapine. The drug or therapy used for treatment of schizophrenia is carbamazepin. The drug or therapy used for treatment of schizophrenia is risperidone. The drug or therapy used for treatment of schizophrenia is thioridazine. The drug or therapy used for treatment of schizophrenia is (RS)-amisulpride. The drug or therapy used for treatment of schizophrenia is fluphenazine. The drug or therapy used for treatment of schizophrenia is loxapine. The possible treatment of schizophrenia is psychotherapy. The medical condition treated of schizophrenia is iloperidone. The medical condition treated of schizophrenia is Cyproheptadine. The medical condition treated of schizophrenia is ziprasidone. The medical condition treated of schizophrenia is zotepine. The medical condition treated of schizophrenia is perphenazine. The medical condition treated of schizophrenia is (Z)-thiothixene. The medical condition treated of schizophrenia is acetophenazine. The medical condition treated of schizophrenia is (±)-deprenyl. The medical condition treated of schizophrenia is trifluoperazine. The medical condition treated of schizophrenia is mesoridazine. The medical condition treated of schizophrenia is (±)-molindone. The medical condition treated of schizophrenia is carphenazine. The medical condition treated of schizophrenia is deserpidine. The medical condition treated of schizophrenia is olanzapine. The medical condition treated of schizophrenia is haloperidol. The medical condition treated of schizophrenia is chlorpromazine. The medical condition treated of schizophrenia is clonazepam. The medical condition treated of schizophrenia is aripiprazole. The medical condition treated of schizophrenia is transclopenthixol. The medical condition treated of schizophrenia is piperacetazine. The medical condition treated of schizophrenia is clozapine. The medical condition treate ...

# %%
# sample code
    
sample_question = "What drug is used to treat schizophrenia?"
sample_entity = "schizophrenia"
top = 2


print("Summaries for question:",sample_question,"and entity:", sample_entity)
for index, candidate in enumerate(get_dbpedia_resource(sample_question,sample_entity,top)):
    print(candidate['id'],"->",get_dbpedia_summary(candidate,sample_question,use_cache=True,verbose=False))
# Out:
# Summaries for question: What drug is used to treat schizophrenia? and entity: schizophrenia
# ## Sorted Candidates by By Name :  [{'name': 'Schizophrenia', 'id': 'Schizophrenia', 'description': 'Schizophrenia is a mental illness characterized by relapsing episodes of psychosis. Major symptoms', 'score': 1.0}, {'name': 'Paranoid schizophrenia', 'id': 'Paranoid_schizophrenia', 'description': 'Paranoid schizophrenia was long diagnosed as the most common type of schizophrenia, but this sub', 'score': 0.8}, {'name': 'Schizophrenia (disambiguation)', 'id': 'Schizophrenia_(disambiguation)', 'description': '', 'score': 0.8}, {'name': 'Childhood schizophrenia', 'id': 'Childhood_schizophrenia', 'description': 'Childhood schizophrenia (also known as childhood-onset schizophrenia, and very early-onset', 'score': 0.7}, {'name': 'Disorganized schizophrenia', 'id': 'Disorganized_schizophrenia', 'description': 'Disorganized schizophrenia, or hebephrenia, is a subtype of schizophrenia, although', 'score': 0.7}, {'name': 'Sluggish schizophrenia', 'id': 'Sluggish_schizophrenia', 'description': 'Sluggish schizophrenia or slow progressive schizophrenia (Russian: вялотеку́щая шизофрени́я', 'score': 0.7}, {'name': 'Simple-type schizophrenia', 'id': 'Simple-type_schizophrenia', 'description': 'Simple-type schizophrenia is a sub-type of schizophrenia included in the International', 'score': 0.7}, {'name': 'Causes of schizophrenia', 'id': 'Causes_of_schizophrenia', 'description': 'The causes of schizophrenia have been the subject of much debate, with various factors proposed', 'score': 0.6}, {'name': 'Schizophrenia and tobacco smoking', 'id': 'Schizophrenia_and_tobacco_smoking', 'description': 'Studies across 20 countries show a strong association between schizophrenia and tobacco smoking', 'score': 0.6}, {'name': 'On the Origin of the "Influencing Machine" in Schizophrenia', 'id': 'On_the_Origin_of_the_%22Influencing_Machine%22_in_Schizophrenia', 'description': '"On the Origin of the \'Influencing Machine\' in Schizophrenia" is an article written', 'score': 0.5}]
# ## Sorted Candidates by By Properties :  [{'name': 'Schizophrenia', 'id': 'Schizophrenia', 'description': 'Schizophrenia is a mental illness characterized by relapsing episodes of psychosis. Major symptoms', 'score': 0.6666666666666666}, {'name': 'Childhood schizophrenia', 'id': 'Childhood_schizophrenia', 'description': 'Childhood schizophrenia (also known as childhood-onset schizophrenia, and very early-onset', 'score': 0.5666666626930237}]
# ## Sorted Candidates by By Description :  [{'name': 'Schizophrenia', 'id': 'Schizophrenia', 'description': 'Schizophrenia is a mental illness characterized by relapsing episodes of psychosis. Major symptoms', 'score': 0.611111111111111}, {'name': 'Childhood schizophrenia', 'id': 'Childhood_schizophrenia', 'description': 'Childhood schizophrenia (also known as childhood-onset schizophrenia, and very early-onset', 'score': 0.5444444417953491}]
# Schizophrenia -> The medication of Schizophrenia is Antipsychotic. The diagnosis of Schizophrenia is Based on observed behavior, reported experiences, and reports of others familiar with the person. The diseases of Schizophrenia is Geriatric psychiatry. The DiseasesDB of Schizophrenia is 11890. The eMedicineSubj of Schizophrenia is med.
# Childhood_schizophrenia -> The medication of Childhood schizophrenia is Antipsychotics. The name of Childhood schizophrenia is Childhood schizophrenia. The differential of Childhood schizophrenia is Major depressive disorder or bipolar disorder with psychotic or catatonic features, brief psychotic disorder, delusional disorder, obsessive–compulsive disorder and body dysmorphic disorder, autism spectrum disorder or communication disorders, other mental disorders associated with a psychotic episode. The frequency of Childhood schizophrenia is of all forms of psychosis of the schizophrenia spectrum; 1.66:1000 among children. The onset of Childhood schizophrenia is 4.102488E8.

# %%
print(get_forward_wikidata_property_value("Q439893","P413",use_cache=True,verbose=True))

# %%
print("DBpedia summary for question:",sample_question,"and entity:", sample_entity)
for index, candidate in enumerate(get_dbpedia_resource(sample_question,sample_entity,top)):
    print(candidate['id'],"->",get_dbpedia_summary(candidate,sample_question))

# %% [markdown]
# # Answer Extraction

# %%
from transformers import pipeline

#qa_language_model = "deepset/roberta-base-squad2-covid" #roberta-covid
qa_language_model = "deepset/roberta-base-squad2" #roberta

question_answerer = pipeline("question-answering", model=qa_language_model, tokenizer=qa_language_model)

# %%
import spacy
sent_nlp = spacy.load('en_core_web_sm')


def chunks(lst,n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def get_answers_in_context(question,text,verbose=False):
    doc = sent_nlp(text)
    answers = []
    for s in doc.sents:
      context = s.text
      #context = s  
      try:
        if (len(s) == 0):
            continue
        #print("num tokens:", len(text.split(" ")), "num_characters:", len(text))
        result = question_answerer(question=question, context=context, min_answer_len=1, max_answer_len=100)
        #print(f"Partial Answer: '{result['answer']}', score: {round(result['score'], 4)}, start: {result['start']}, end: {result['end']}")
        score = round(result['score'], 1)
        if (score == 0.0):
            continue
        if (verbose):
            print("[",score,"]",context)        
        answer = {}
        answer['value']=result['answer'].replace(","," ")
        answer['score']=score
        answer['summary']=context
        answer['start']=result['start']
        answer['end']=result['end']
        answers.append(answer)
      except Exception as e:
        print("Error extracting answer:",e)
    return answers

# %%
sample_question = "what is the place of birth of sam edwards?"
sample_summary = "The place of birth of Sam Edwards is Swansea. The date of birth of Sam Edwards is 1928-02-01T00:00:00Z. The family name of Sam Edwards is Edwards. The given name of Sam Edwards is Samuel."
for a in get_answers_in_context(sample_question,sample_summary):
    print(a)

# %%
sample_question = "what is the place of birth of sam edwards?"
sample_summary = "The place of birth of Sam Edwards is Macon. The date of birth of Sam Edwards is 1915-05-26T00:00:00Z. The place of death of Sam Edwards is Durango. The family name of Sam Edwards is Edwards. The given name of Sam Edwards is Sam."
print("Answer:",get_answer_in_context(sample_question,sample_summary))

# %% [markdown]
# # Response Creation

# %%
from statistics import mean

def get_answers(question,max=-1,wiki=True,dbpedia=True,verbose=False):
    if (verbose):
        print("Question:",question)
    # identify entities
    entities = get_entities(question)
    if (verbose):
        print("Entities:",entities)
    summaries = []
    for e in entities:
        if (wiki):
            for r in get_wikidata_resource(question,e):
                if (verbose):
                    print("- Wiki Resources:",{'id':r['id'],'label':r['label'],'description':r['description']})
                summaries.append(get_wikidata_summary(r,question))
        if (dbpedia):            
            for r in get_dbpedia_resource(question,e):
                if (verbose):
                    print("- DBpedia Resources:",{'id':r['id'],'label':r['label'],'description':r['description']})
                summaries.append(get_dbpedia_summary(r,question))
    answers_by_value = {}
    if (verbose):
        print(len(summaries),"summaries created")
    for s in summaries:
        for a in get_answers_in_context(question,s):
            if (a['score']>0.0):
                if (a['value'] not in answers_by_value):
                    answers_by_value[a['value']]=[]
                answers_by_value[a['value']].append(a)
                
    # merge duplicates and update scores
    answers = []
    for k in answers_by_value:
        partial_answers = answers_by_value[k]
        partial_answers.sort(key=lambda x: x.get('score'),reverse=True)
        best_answer = partial_answers[0]
        best_answer['relevance'] = len(partial_answers)
        best_answer['score']=mean([a['score'] for a in partial_answers])
        answers.append(best_answer)
    
    # sort by score
    answers.sort(key=lambda x: (x.get('score'),x.get('relevance')),reverse=True)
    if (max>0):
        return answers[:max]
    elif len(answers)>0:
        best_score = answers[0]['score']
        return [a for a in answers if a['score']==best_score]
    else:
        return answers

# %%
for i,a in enumerate(get_answers("what is the place of birth of sam edwards?",max=-1,wiki=True,dbpedia=True,verbose=True)):
    print(i,":",a)
# Out:
# Question: what is the place of birth of sam edwards?
# Entities: ['sam edwards']
# - Wiki Resources: {'id': 'Q472382', 'label': 'Sam Edwards', 'description': 'Welsh physicist (1928-2015)'}
# - Wiki Resources: {'id': 'Q3470479', 'label': 'Sam Edwards', 'description': '1915-2004 American actor'}
# - DBpedia Resources: {'id': 'Sam_Edwards', 'label': 'Sam Edwards', 'description': 'Sam Edwards (May 26, 1915 – July 28, 2004) was an American actor. His most famous role'}
# - DBpedia Resources: {'id': 'Sam_Edwards_(physicist)', 'label': 'Sam Edwards (physicist)', 'description': 'Sir Samuel Frederick Edwards FLSW FRS (1 February 1928 – 7 May 2015), "universally known as \'Sam'}
# 4 summaries created
# 0 : {'value': 'Swansea', 'score': 1.0, 'summary': 'The place of birth of Sam Edwards is Swansea.', 'start': 37, 'end': 44, 'relevance': 2}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Metrics

# %%
import unidecode

def normalize(label):
  return unidecode.unidecode(label.strip()).lower()

def precision(tp,fp):
  if (fp+tp == 0):
    return 0.0
  return tp / (fp + tp)

def recall(tp,fn):
  if (fn+tp == 0):
    return 0.0
  return tp / (fn + tp)

def f1(tp,fp,fn):
  p = precision(tp,fp)
  r = recall(tp,fn)
  if (p+r == 0):
    return 0.0
  return 2 * ((p*r)/(p+r))

def average(values):
  return sum(values) / len(values) 

# lists of entity lists
def evaluate_labels(true_list,pred_list):
  tp, tn, fp, fn = 0, 0, 0, 0
  precision_list, recall_list, f1_list = [], [], []
  empty_values = 0
  for index in range(len(true_list)):
    # normalize entities
    valid_entities = [normalize(e) for e in true_list[index] if e != '']
    predicted_entities = [normalize(e) for e in pred_list[index]]
    ptp, ptn, pfp, pfn = 0, 0, 0, 0
    if (len(valid_entities)==0):
      empty_values += 1
    for entity in valid_entities:
      if (entity not in predicted_entities):
        pfn += 1
    for entity in predicted_entities:
      if (entity in valid_entities):
        ptp += 1
      else:
        pfp += 1    
    precision_list.append(precision(ptp,pfp))
    recall_list.append(recall(ptp,pfn))
    f1_list.append(f1(ptp,pfp,pfn))
    tp += ptp
    tn += ptn
    fp += pfp
    fn += pfn  
  return  {
      'total': index,
      'empty': empty_values,
      'tp': tp,
      'tn': tn, 
      'fp': fp,
      'fn':fn,
      'micro-precision': precision(tp,fp),
      'micro-recall': recall(tp,fn),
      'micro-f1': f1(tp,fp,fn),
      'macro-precision': average(precision_list),
      'macro-recall': average(recall_list),
      'macro-f1': average(f1_list)
  }

# %% [markdown]
# ## Tests

# %%
from IPython.display import clear_output
import json
import pandas as pd
import collections

def json_file(name):
  return name+"-answers.json"

def csv_file(name):
  return name+"-answers.csv"

def evaluate_data(name,dataframe,max=-1):
  l1, l2, l3, l4, l5, l6, l7, l8, l9, l10, l11, l12 = [], [], [], [], [], [], [], [], [], [], [], []
  total = 0
  for index, row in dataframe.iterrows():
      if (max>0) and (total>max):
          l1.append("")
          l2.append("")
          l3.append("")
          l4.append("")
          l5.append("")
          l6.append("")
          l7.append("")
          l8.append("")
          l9.append("")
          l10.append("")
          l11.append("")
          l12.append("")
      else:
          question = row['question']
          print(index,":",question)
          answers = get_answers(question,-1,wiki=True,dbpedia=True)
          l1.append([a['value'] for a in answers])  
          answers = get_answers(question,3,wiki=True,dbpedia=True)  
          l2.append([a['value'] for a in answers[:1]])
          l3.append([a['value'] for a in answers[:2]])
          l4.append([a['value'] for a in answers[:3]])
          answers = get_answers(question,-1,wiki=True,dbpedia=False)
          l5.append([a['value'] for a in answers])           
          answers = get_answers(question,3,wiki=True,dbpedia=False)
          l6.append([a['value'] for a in answers[:1]])
          l7.append([a['value'] for a in answers[:2]])
          l8.append([a['value'] for a in answers[:3]])
          answers = get_answers(question,-1,wiki=False,dbpedia=True)
          l9.append([a['value'] for a in answers])           
          answers = get_answers(question,3,wiki=False,dbpedia=True)
          l10.append([a['value'] for a in answers[:1]])
          l11.append([a['value'] for a in answers[:2]])
          l12.append([a['value'] for a in answers[:3]])    
      total += 1
  dataframe['MuHeQA_Rank']=l1
  dataframe['MuHeQA_Top1']=l2
  dataframe['MuHeQA_Top2']=l3
  dataframe['MuHeQA_Top3']=l4
  dataframe['Wiki_Rank']=l5                     
  dataframe['Wiki_Top1']=l6
  dataframe['Wiki_Top2']=l7
  dataframe['Wiki_Top3']=l8
  dataframe['DBpedia_Rank']=l9                     
  dataframe['DBpedia_Top1']=l10
  dataframe['DBpedia_Top2']=l11
  dataframe['DBpedia_Top3']=l12
  clear_output(wait=True)  
  print(total,"questions analyzed!")
  dataframe.to_json(json_file(name), orient='split')
  dataframe.to_csv(csv_file(name))
  return dataframe

def make_report(name,additional=[],filter=None,max=-1):
  
  df = pd.read_json(json_file(name), orient='split')
  types = [] 
  if ('types' in df):
        types = df['type'].tolist()
  responses = df['responses'].tolist()  
  limit = len(responses)
  if (max>0):
    limit = max
  y_true =[]
  for i,r in enumerate(responses[:limit]):
    partial_response = []
    if (filter) and (types[i] != filter):
        continue
    for response in r:
        resp_value = ""
        if (response):
            resp_value = normalize(response)
        partial_response.append(resp_value)
    y_true.append(partial_response)
  results = []
  for col in df.columns:
    if (col == 'question') or (col == 'responses') or (col == 'type'):
      continue
    predictions = df[col].tolist()
    y_pred = []
    for i,p in enumerate(predictions[:limit]):
        if (filter) and (types[i] != filter):
            continue
        partial_prediction = []
        for prediction in p:
            partial_prediction.append(normalize(prediction))
        y_pred.append(partial_prediction)        
    result = evaluate_labels(y_true,y_pred)
    result['model']=col
    results.append(result)

  for row in additional:
    results.append(row)

  df_results = pd.DataFrame(results)
  return df_results

def visualize_results(name,max=10):
    df = pd.read_json(json_file(name), orient='split')
    return df.head(max)

def show_errors(name,column,max=-1):
    df = pd.read_json(json_file(name), orient='split')
    types = df['type'].tolist()
    questions = df['question'].tolist()
    responses = df['responses'].tolist()  
    limit = len(responses)
    if (max>0):
        limit = max
    y_true =[]
    for r in responses[:limit]:
        partial_response = []
        for response in r:
            partial_response.append(normalize(response))
        y_true.append(partial_response)
    predictions = df[column].tolist()
    y_pred = []
    for p in predictions[:limit]:
        partial_prediction = []
        for prediction in p:
            partial_prediction.append(normalize(prediction))
        y_pred.append(partial_prediction)
    for i,r in enumerate(y_true):
        p = y_pred[i]
        if collections.Counter(r) == collections.Counter(p):
            continue
        else:
            print("Question:",questions[i],"[",types[i],"]","Expected:",r,"Predicted:",p)

# %% [markdown]
# # Results

# %% [markdown]
# ## SimpleQuestions Dataset

# %%
# Read wikipedia compatible SimpleQuestions Dataset
import pandas as pd
df = pd.read_csv('data/wsq-labels.csv', index_col=0)
# inverse predicates contain no entity. In all other cases, the entity corresponds to the subject.
#my_df = df[df.predicate.str.contains('P',case=False)]
#my_df.head()
types = []
responses = []
for index, row in df.iterrows():
  response = row['object_label'] 
  q_type = "F"
  if row['predicate'][0] == 'R':
    q_type = "B"
  responses.append([response])
  types.append(q_type)
df['type'] = types
df['responses'] = responses
sq_df = df.drop(['subject','predicate','object','subject_label','predicate_label','object_label'], axis=1)
sq_df.head(10)
# Out:
#                                             question type  \
# 0                        Where did roger marquis die    F
# 1          what was the cause of death of yves klein    F
# 2              What position does carlos gomez play?    F
# 3               how does engelbert zaschka identify     F
# 4  what position does pee wee reese play in baseball    F
# 5  Which Swiss conductor's cause of death is myoc...    B
# 6      where was padraic mcguinness's place of death    F
# 7         what is the place of birth of sam edwards?    F
# 8  Which home is an example of italianate archite...    B
# 9                           who published neo contra    F
#
#                       responses
# 0                     [Holyoke]
# 1       [myocardial infarction]
# 2              [center fielder]
# 3                        [male]
# 4                   [shortstop]
# 5     [Karl Anton Rickenbacher]
# 6                      [Sydney]
# 7                     [Swansea]
# 8  [John and Maria Adams House]
# 9                      [Konami]

# %%
# read dbpedia compatible SimpleQuestions
import pandas as pd
df = pd.read_csv('data/dsq-labels.csv', index_col=0)
types = []
responses = []
for index, row in df.iterrows():
  response = row['object_label']   
  responses.append([response])
df['responses'] = responses
dsq_df = df.drop(['subject','predicate','object','subject_label','property_label','object_label'], axis=1)
dsq_df.head(10)
# Out:
#                                             question                 responses
# 0                        Where did roger marquis die  [Holyoke, Massachusetts]
# 1              What position does carlos gomez play?          [Center fielder]
# 2                how does engelbert zaschka identify                     [nan]
# 3  what position does pee wee reese play in baseball               [Shortstop]
# 4  Which Swiss conductor's cause of death is myoc...        [Moses J. Epstein]
# 5      where was padraic mcguinness's place of death               [Australia]
# 6         what is the place of birth of sam edwards?                 [Swansea]
# 7  Which home is an example of italianate archite...            [280 Broadway]
# 8                           who published neo contra                  [Konami]
# 9                   what is angie estes's profession                    [Poet]

# %%
# Merge questions into a unique dataframe
counter = 0
valid_rows = []
for index, r in sq_df.iterrows():
    question = r['question']
    if (normalize(question) in dbpedia_questions):
        counter += 1
        valid_rows.append(r)
print("Valid Questions:",counter)
squ_df = pd.DataFrame(columns=sq_df.columns, data=valid_rows)
squ_df.head(10)
# Out:
# Valid Questions: 3667
#                                              question type  \
# 0                         Where did roger marquis die    F
# 2               What position does carlos gomez play?    F
# 3                how does engelbert zaschka identify     F
# 4   what position does pee wee reese play in baseball    F
# 5   Which Swiss conductor's cause of death is myoc...    B
# 6       where was padraic mcguinness's place of death    F
# 7          what is the place of birth of sam edwards?    F
# 8   Which home is an example of italianate archite...    B
# 9                            who published neo contra    F
# 10                  what is angie estes's profession     F
#
#                        responses
# 0                      [Holyoke]
# 2               [center fielder]
# 3                         [male]
# 4                    [shortstop]
# 5      [Karl Anton Rickenbacher]
# 6                       [Sydney]
# 7                      [Swansea]
# 8   [John and Maria Adams House]
# 9                       [Konami]
# 10                        [poet]

# %%
dsq_df.describe()
# Out:
#               question responses
# count             3688      3688
# unique            3656      1741
# top     Name an actor.     [nan]
# freq                12      1076

# %%
#wiki_cache = {}
#dbpedia_cache = {}
#entities_cache = {}
df = evaluate_data('dsq',dsq_df,100)
dsq_df.head(10)
# Out:
# 3688 questions analyzed!
#                                             question  \
# 0                        Where did roger marquis die
# 1              What position does carlos gomez play?
# 2                how does engelbert zaschka identify
# 3  what position does pee wee reese play in baseball
# 4  Which Swiss conductor's cause of death is myoc...
# 5      where was padraic mcguinness's place of death
# 6         what is the place of birth of sam edwards?
# 7  Which home is an example of italianate archite...
# 8                           who published neo contra
# 9                   what is angie estes's profession
#
#                   responses  \
# 0  [Holyoke, Massachusetts]
# 1          [Center fielder]
# 2                     [nan]
# 3               [Shortstop]
# 4        [Moses J. Epstein]
# 5               [Australia]
# 6                 [Swansea]
# 7            [280 Broadway]
# 8                  [Konami]
# 9                    [Poet]
#
#                                          MuHeQA_Rank  \
# 0                  [Holyoke, Holyoke  Massachusetts]
# 1                         [defender, Center fielder]
# 2                                           [German]
# 3                             [shortstop, Shortstop]
# 4  [Thure Widlund, Helge Bäcklund, Ángel José Ram...
# 5                                           [Sydney]
# 6                                   [Swansea, Macon]
# 7  [Brown Township Building, Chatsworth House, 35...
# 8                                           [Konami]
# 9                                     [writer, poet]
#
#                  MuHeQA_Top1                                     MuHeQA_Top2  \
# 0                  [Holyoke]               [Holyoke, Holyoke  Massachusetts]
# 1                 [defender]                      [defender, Center fielder]
# 2                   [German]                                  [German, male]
# 3                [shortstop]                          [shortstop, Shortstop]
# 4            [Thure Widlund]                 [Thure Widlund, Helge Bäcklund]
# 5                   [Sydney]    [Sydney, Sydney  New South Wales  Australia]
# 6                  [Swansea]                                [Swansea, Macon]
# 7  [Francis D. Alling House]  [Francis D. Alling House, George B. Cox House]
# 8                   [Konami]                               [Konami, Jim Lee]
# 9                   [writer]                                  [writer, poet]
#
#                                          MuHeQA_Top3  \
# 0      [Holyoke, Holyoke  Massachusetts, 2004-07-19]
# 1   [defender, Center fielder, association football]
# 2                          [German, male, Engelbert]
# 3        [shortstop, Shortstop, Los Angeles Dodgers]
# 4  [Thure Widlund, Helge Bäcklund, Ángel José Ram...
# 5  [Sydney, Sydney  New South Wales  Australia, 2...
# 6                   [Swansea, Macon, Swansea  Wales]
# 7  [Francis D. Alling House, George B. Cox House,...
# 8                   [Konami, Jim Lee, Sota Fujimori]
# 9  [writer, poet, California Polytechnic State Un...
#
#                                            Wiki_Rank          Wiki_Top1  \
# 0                                          [Holyoke]          [Holyoke]
# 1                                         [defender]         [defender]
# 2                                             [male]             [male]
# 3                                        [shortstop]        [shortstop]
# 4  [Thure Widlund, Helge Bäcklund, Ángel José Ram...    [Thure Widlund]
# 5                                           [Sydney]           [Sydney]
# 6                                   [Swansea, Macon]          [Swansea]
# 7  [Arlington Hotel, East 78th Street Houses, Bro...  [Arlington Hotel]
# 8                                           [Konami]           [Konami]
# 9                                     [writer, poet]           [writer]
#
#                                     Wiki_Top2  \
# 0              [Holyoke, 2004-07-19T00:00:00]
# 1            [defender, association football]
# 2                           [male, Engelbert]
# 3            [shortstop, Los Angeles Dodgers]
# 4             [Thure Widlund, Helge Bäcklund]
# 5                       [Sydney, skin cancer]
# 6                            [Swansea, Macon]
# 7  [Arlington Hotel, East 78th Street Houses]
# 8              [Konami, 2004-10-19T00:00:00Z]
# 9                              [writer, poet]
#
#                                            Wiki_Top3  \
# 0               [Holyoke, 2004-07-19T00:00:00, 1969]
# 1  [defender, association football, Atlético Poto...
# 2            [male, Engelbert, Freiburg im Breisgau]
# 3  [shortstop, Los Angeles Dodgers, Major League ...
# 4  [Thure Widlund, Helge Bäcklund, Ángel José Ram...
# 5                  [Sydney, skin cancer, 2008-01-26]
# 6                             [Swansea, Macon, 1928]
# 7  [Arlington Hotel, East 78th Street Houses, Bro...
# 8                     [Konami, 2004-10-19T00:00:00Z]
# 9  [writer, poet, California Polytechnic State Un...
#
#                                         DBpedia_Rank  \
# 0                           [Holyoke  Massachusetts]
# 1                                   [Center fielder]
# 2                                           [German]
# 3                                        [Shortstop]
# 4                                                 []
# 5               [Sydney  New South Wales  Australia]
# 6                                   [Swansea  Wales]
# 7  [Baston Lodge, Piper-Price House, Townhill Par...
# 8                                           [Konami]
# 9  [The name of Angie Estes is Angie Estes., Univ...
#
#                                 DBpedia_Top1  \
# 0                   [Holyoke  Massachusetts]
# 1                           [Center fielder]
# 2                                   [German]
# 3                                [Shortstop]
# 4                                         []
# 5       [Sydney  New South Wales  Australia]
# 6                           [Swansea  Wales]
# 7                             [Baston Lodge]
# 8                                   [Konami]
# 9  [The name of Angie Estes is Angie Estes.]
#
#                                         DBpedia_Top2  \
# 0               [Holyoke  Massachusetts, 2004-07-19]
# 1                    [Center fielder, New York Mets]
# 2                                [German, Orionette]
# 3                                 [Shortstop, Right]
# 4                                                 []
# 5   [Sydney  New South Wales  Australia, 2008-01-26]
# 6                   [Swansea  Wales, Macon  Georgia]
# 7                  [Baston Lodge, Piper-Price House]
# 8                                  [Konami, Jim Lee]
# 9  [The name of Angie Estes is Angie Estes., Univ...
#
#                                         DBpedia_Top3
# 0               [Holyoke  Massachusetts, 2004-07-19]
# 1               [Center fielder, New York Mets, MLB]
# 2  [German, Orionette, Unterschrift von Engelbert...
# 3                            [Shortstop, Right, MLB]
# 4                                                 []
# 5   [Sydney  New South Wales  Australia, 2008-01-26]
# 6       [Swansea  Wales, Macon  Georgia, 1928-02-01]
# 7  [Baston Lodge, Piper-Price House, Townhill Par...
# 8                   [Konami, Jim Lee, Sota Fujimori]
# 9  [The name of Angie Estes is Angie Estes., Univ...

# %%
make_report('dsq',max=100)
# Out:
#     total  empty  tp  tn   fp  fn  micro-precision  micro-recall  micro-f1  \
# 0      99     23  25   0  882  54         0.027563      0.316456  0.050710
# 1      99     23  17   0   80  60         0.175258      0.220779  0.195402
# 2      99     23  26   0  164  53         0.136842      0.329114  0.193309
# 3      99     23  29   0  250  50         0.103943      0.367089  0.162011
# 4      99     23  18   0  498  59         0.034884      0.233766  0.060708
# 5      99     23  16   0   77  61         0.172043      0.207792  0.188235
# 6      99     23  21   0  157  56         0.117978      0.272727  0.164706
# 7      99     23  24   0  228  53         0.095238      0.311688  0.145897
# 8      99     23  17   0  588  60         0.028099      0.220779  0.049853
# 9      99     23  12   0   74  65         0.139535      0.155844  0.147239
# 10     99     23  18   0  147  59         0.109091      0.233766  0.148760
# 11     99     23  19   0  213  58         0.081897      0.246753  0.122977
#
#     macro-precision  macro-recall  macro-f1         model
# 0          0.157884          0.23  0.173624   MuHeQA_Rank
# 1          0.170000          0.17  0.170000   MuHeQA_Top1
# 2          0.130000          0.24  0.166667   MuHeQA_Top2
# 3          0.101667          0.27  0.146000   MuHeQA_Top3
# 4          0.145387          0.18  0.151774     Wiki_Rank
# 5          0.160000          0.16  0.160000     Wiki_Top1
# 6          0.105000          0.21  0.140000     Wiki_Top2
# 7          0.086667          0.24  0.126667     Wiki_Top3
# 8          0.120050          0.17  0.131290  DBpedia_Rank
# 9          0.120000          0.12  0.120000  DBpedia_Top1
# 10         0.095000          0.18  0.123333  DBpedia_Top2
# 11         0.073333          0.19  0.103333  DBpedia_Top3

# %%
#wiki_cache = {}
#dbpedia_cache = {}
#entities_cache = {}
df = evaluate_data('squ',squ_df,1000)
squ_df.head(10)
# Out:
# 0 : Where did roger marquis die
# 2 : What position does carlos gomez play?
# 3 : how does engelbert zaschka identify
# 4 : what position does pee wee reese play in baseball
# 5 : Which Swiss conductor's cause of death is myocardial infarction?
# 6 : where was padraic mcguinness's place of death
# 7 : what is the place of birth of sam edwards?
# 8 : Which home is an example of italianate architecture?
# 9 : who published neo contra
# 10 : what is angie estes's profession
# 11 : what position does josé francisco torres play?
# 12 : what male actor was born in  warsaw
# 13 : who was also born in jakarta
# 14 : Who was born in prague
# 15 : where was guy pnini born
# 16 : what is an album recorded by scott grimes
# 17 : what was the country of origin of the tv show sidewalks entertainment
# 18 : who was the architect of the structure tour perret
# 19 : What is an album by guy clark?
# 20 : what's the name of an Australian rock and roll
# 21 : what is the category of the celestial object 1241 dysona
# 22 : What is a type of gameplay available to gamers playing custom robo v2
# 24 : where was shigeyasu suzuki's place of birth
# 26 : which indian city was fazil born in
# Error on wikidata property value query: The read operation timed out ->
#       PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#       PREFIX bd: <http://www.bigdata.com/rdf#>
#       PREFIX wd: <http://www.wikidata.org/entity/>
#       PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#       PREFIX wikibase: <http://wikiba.se/ontology#>
#       SELECT distinct ?obj ?objLabel
#       WHERE
#
#               {
#                 wd:Q3534902 wdt:P735 ?obj .
#                 SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#               }
#
#       LIMIT 250
#
# 27 : where was paolo de la haza born?
# 31 : Which film was directed by ian iqbal rashid
# 33 : who recorded rca records
# 35 : What is a gampelay mode found in the game allegiance
# 37 : Which films has leonid gaidai written
# 39 : What is shinji mori's gender?
# 40 : what style of msuic did john pizzarelli play
# 42 : what is trond egil soltvedt's birth place
# 43 : what series is super mario bros. 2 a part of
# 44 : what disease did anthony perkins die of
# 45 : what is the mouth of the schuylkill river
# 46 : Which genre of book is bin laden: the man who declared war on america?
# 47 : Name a model that died due to a car accident
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/3428838183.py in <module>
#       2 #dbpedia_cache = {}
#       3 #entities_cache = {}
# ----> 4 df = evaluate_data('squ',squ_df,1000)
#       5 squ_df.head(10)
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/324408840.py in evaluate_data(name, dataframe, max)
#      38           answers = get_answers(question,-1,wiki=True,dbpedia=False)
#      39           l5.append([a['value'] for a in answers])
# ---> 40           answers = get_answers(question,3,wiki=True,dbpedia=False)
#      41           l6.append([a['value'] for a in answers[:1]])
#      42           l7.append([a['value'] for a in answers[:2]])
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/4143958644.py in get_answers(question, max, wiki, dbpedia, verbose)
#      24         print(len(summaries),"summaries created")
#      25     for s in summaries:
# ---> 26         for a in get_answers_in_context(question,s):
#      27             if (a['score']>0.0):
#      28                 if (a['value'] not in answers_by_value):
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/2274620604.py in get_answers_in_context(question, text, verbose)
#      17             continue
#      18         #print("num tokens:", len(text.split(" ")), "num_characters:", len(text))
# ---> 19         result = question_answerer(question=question, context=context, min_answer_len=1, max_answer_len=100)
#      20         #print(f"Partial Answer: '{result['answer']}', score: {round(result['score'], 4)}, start: {result['start']}, end: {result['end']}")
#      21         score = round(result['score'], 1)
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     247         examples = self._args_parser(*args, **kwargs)
#     248         if len(examples) == 1:
# --> 249             return super().__call__(examples[0], **kwargs)
#     250         return super().__call__(examples, **kwargs)
#     251
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1004             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1005         else:
# -> 1006             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1007
#    1008     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1026         all_outputs = []
#    1027         for model_inputs in self.preprocess(inputs, **preprocess_params):
# -> 1028             model_outputs = self.forward(model_inputs, **forward_params)
#    1029             all_outputs.append(model_outputs)
#    1030         outputs = self.postprocess(all_outputs, **postprocess_params)
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#     921                 with inference_context():
#     922                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 923                     model_outputs = self._forward(model_inputs, **forward_params)
#     924                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     925             else:
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/pipelines/question_answering.py in _forward(self, inputs)
#     367         example = inputs["example"]
#     368         model_inputs = {k: inputs[k] for k in self.tokenizer.model_input_names}
# --> 369         start, end = self.model(**model_inputs)[:2]
#     370         return {"start": start, "end": end, "example": example, **inputs}
#     371
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1514         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1515
# -> 1516         outputs = self.roberta(
#    1517             input_ids,
#    1518             attention_mask=attention_mask,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     848             past_key_values_length=past_key_values_length,
#     849         )
# --> 850         encoder_outputs = self.encoder(
#     851             embedding_output,
#     852             attention_mask=extended_attention_mask,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     524                 )
#     525             else:
# --> 526                 layer_outputs = layer_module(
#     527                     hidden_states,
#     528                     attention_mask,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     410         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     411         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 412         self_attention_outputs = self.attention(
#     413             hidden_states,
#     414             attention_mask,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     337         output_attentions=False,
#     338     ):
# --> 339         self_outputs = self.self(
#     340             hidden_states,
#     341             attention_mask,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     275         context_layer = torch.matmul(attention_probs, value_layer)
#     276
# --> 277         context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
#     278         new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
#     279         context_layer = context_layer.view(*new_context_layer_shape)
#
# KeyboardInterrupt:

# %%
make_report('squ',max=100)
# Out:
#     total  empty  tp  tn   fp  fn  micro-precision  micro-recall  micro-f1  \
# 0      99      0  44   0  680  59         0.060773      0.427184  0.106409
# 1      99      0  38   0   59  62         0.391753      0.380000  0.385787
# 2      99      0  52   0  138  50         0.273684      0.509804  0.356164
# 3      99      0  54   0  224  49         0.194245      0.524272  0.283465
# 4      99      0  47   0  296  53         0.137026      0.470000  0.212190
# 5      99      0  42   0   51  58         0.451613      0.420000  0.435233
# 6      99      0  50   0  128  50         0.280899      0.500000  0.359712
# 7      99      0  53   0  199  47         0.210317      0.530000  0.301136
# 8      99      0  17   0  562  83         0.029361      0.170000  0.050074
# 9      99      0  13   0   73  87         0.151163      0.130000  0.139785
# 10     99      0  21   0  143  79         0.128049      0.210000  0.159091
# 11     99      0  22   0  208  78         0.095652      0.220000  0.133333
#
#     macro-precision  macro-recall  macro-f1         model
# 0          0.327833          0.41  0.352000   MuHeQA_Rank
# 1          0.380000          0.38  0.380000   MuHeQA_Top1
# 2          0.270000          0.50  0.346667   MuHeQA_Top2
# 3          0.201667          0.51  0.282333   MuHeQA_Top3
# 4          0.407566          0.47  0.422121     Wiki_Rank
# 5          0.420000          0.42  0.420000     Wiki_Top1
# 6          0.275000          0.50  0.350000     Wiki_Top2
# 7          0.226667          0.53  0.306667     Wiki_Top3
# 8          0.135000          0.17  0.146667  DBpedia_Rank
# 9          0.130000          0.13  0.130000  DBpedia_Top1
# 10         0.115000          0.21  0.146667  DBpedia_Top2
# 11         0.091667          0.22  0.125000  DBpedia_Top3

# %%
make_report('squ',filter="F",max=100)
# Out:
#     total  empty  tp  tn   fp  fn  micro-precision  micro-recall  micro-f1  \
# 0      70      0  43   0   74  31         0.367521      0.581081  0.450262
# 1      70      0  37   0   31  34         0.544118      0.521127  0.532374
# 2      70      0  50   0   83  23         0.375940      0.684932  0.485437
# 3      70      0  52   0  142  22         0.268041      0.702703  0.388060
# 4      70      0  43   0   43  28         0.500000      0.605634  0.547771
# 5      70      0  40   0   27  31         0.597015      0.563380  0.579710
# 6      70      0  47   0   80  24         0.370079      0.661972  0.474747
# 7      70      0  49   0  128  22         0.276836      0.690141  0.395161
# 8      70      0  15   0   77  56         0.163043      0.211268  0.184049
# 9      70      0  11   0   47  60         0.189655      0.154930  0.170543
# 10     70      0  18   0   92  53         0.163636      0.253521  0.198895
# 11     70      0  19   0  135  52         0.123377      0.267606  0.168889
#
#     macro-precision  macro-recall  macro-f1         model
# 0          0.447653      0.563380  0.481690   MuHeQA_Rank
# 1          0.521127      0.521127  0.521127   MuHeQA_Top1
# 2          0.366197      0.676056  0.469484   MuHeQA_Top2
# 3          0.272300      0.690141  0.381221   MuHeQA_Top3
# 4          0.542723      0.605634  0.561033     Wiki_Rank
# 5          0.563380      0.563380  0.563380     Wiki_Top1
# 6          0.366197      0.661972  0.464789     Wiki_Top2
# 7          0.298122      0.690141  0.401408     Wiki_Top3
# 8          0.161972      0.211268  0.178404  DBpedia_Rank
# 9          0.154930      0.154930  0.154930  DBpedia_Top1
# 10         0.140845      0.253521  0.178404  DBpedia_Top2
# 11         0.110329      0.267606  0.150235  DBpedia_Top3

# %%
make_report('squ',filter="B",max=100)
# Out:
#     total  empty  tp  tn   fp  fn  micro-precision  micro-recall  micro-f1  \
# 0      28      0   1   0  606  28         0.001647      0.034483  0.003145
# 1      28      0   1   0   28  28         0.034483      0.034483  0.034483
# 2      28      0   2   0   55  27         0.035088      0.068966  0.046512
# 3      28      0   2   0   82  27         0.023810      0.068966  0.035398
# 4      28      0   4   0  253  25         0.015564      0.137931  0.027972
# 5      28      0   2   0   24  27         0.076923      0.068966  0.072727
# 6      28      0   3   0   48  26         0.058824      0.103448  0.075000
# 7      28      0   4   0   71  25         0.053333      0.137931  0.076923
# 8      28      0   2   0  485  27         0.004107      0.068966  0.007752
# 9      28      0   2   0   26  27         0.071429      0.068966  0.070175
# 10     28      0   3   0   51  26         0.055556      0.103448  0.072289
# 11     28      0   3   0   73  26         0.039474      0.103448  0.057143
#
#     macro-precision  macro-recall  macro-f1         model
# 0          0.034483      0.034483  0.034483   MuHeQA_Rank
# 1          0.034483      0.034483  0.034483   MuHeQA_Top1
# 2          0.034483      0.068966  0.045977   MuHeQA_Top2
# 3          0.028736      0.068966  0.040230   MuHeQA_Top3
# 4          0.076664      0.137931  0.082027     Wiki_Rank
# 5          0.068966      0.068966  0.068966     Wiki_Top1
# 6          0.051724      0.103448  0.068966     Wiki_Top2
# 7          0.051724      0.137931  0.074713     Wiki_Top3
# 8          0.068966      0.068966  0.068966  DBpedia_Rank
# 9          0.068966      0.068966  0.068966  DBpedia_Top1
# 10         0.051724      0.103448  0.068966  DBpedia_Top2
# 11         0.045977      0.103448  0.063218  DBpedia_Top3

# %%
show_errors('sq',"Wiki_Top1",max=20)

# %% [markdown]
# ## Wikidata QA Dataset

# %%
import pandas as pd
df = pd.read_csv('wqa-labels.csv', index_col=0)
responses = []
for index, row in df.iterrows():
  responses.append(row['object_labels'].replace("[","").replace("]","").replace("\'","").split(","))
df['responses'] = responses
wqa_df = df.drop(['subjects','predicates','objects','subject_labels','predicate_labels','object_labels'], axis=1)
wqa_df.head()

# %%
evaluate_data('wqa',wqa_df)
# Out:
# 0 : Who is the president of Poland?
# 1 : How many Turing awards have people from Austria won?
# 2 : Give me all countries that have won a FIFA World Cup
# 3 : What is the population of Chile?
# 4 : Who is the author of One Piece?
# 5 : Which musicians are from Sweden?
# 6 : How many movies has Tarantino directed?
# 7 : Is New York bigger than Beijing?
# 8 : what countries are part of the European Union?
# 9 : What computer scientists were born after 1970?
# 10 : Is Leonardo Dicaprio older than Joaquin Phoenix?
# 11 : In which country is the Museo del Prado located?
# 12 : When did Caesars Palace open?
# 13 : Which political party was Abraham Lincoln a member of?
# 14 : Which paintings feature a banana?
# 15 : Do any national flags use pink?
# 16 : When did Ian Curtis commit suicide?
# 17 : Where can I see paintings by El Greco?
# 18 : In which movies did Al Pacino and Robert de Niro appear together?
# 19 : Who is the youngest head of state in the world?
# 20 : Which mountains are on Mars?
# 21 : What alcoholic drinks are made with orange?
# 22 : Which video games have a fox character?
# 23 : How many astronauts studied at MIT?
# 24 : When was the first exoplanet discovered?
# 25 : Which movies were directed by siblings?
# 26 : What buildings are named after JFK?
# 27 : When was Hey Jude released?
# 28 : Which countries have multiple capitals?
# 29 : Which video games are known to be NP complete?
# 30 : What is the most common cause of death among F1 drivers?
# 31 : Which asthma drugs are carcinogenic?
# 32 : Which countries are named after plants?
# 33 : Which telescopes are based in Chile?
# 34 : What is the chemical symbol for Potassium?
# 35 : What is the Twitter account of Elon Musk?
# 36 : Who is the CEO of eBay?
# 37 : Which alkali metal is in period 4
# 38 : Where can I find platypuses?
# 39 : Which endangered species can be found in Chile?
# 40 : Which country has the most nuclear power plants?
# 41 : Which country has the most official languages?
# 42 : When did ICLR start?
# 43 : Which country that does not border Germany has German as an official language?
# 44 : What is the national anthem of Greece?
# 45 : Which pair of directors have co-directed the most movies together?
# 46 : Which company makes Twix?
# 47 : What is the nearest black hole?
# 48 : Which statues are made of copper?
# 49 : Which conferences focus on machine learning?
# 50 : Which cities are named after an apostle?
# 51 : What chocolate bars are made by Nestle?
# 52 : Who was president before Nixon?
# 53 : How many books are in the Hitchhiker's Guide to the Galaxy series?
# 54 : Which Simpsons characters were not born in Springfield?
# 55 : When was sparkling water invented?
# 56 : What articles discuss knowledge graph embeddings?
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/1935953053.py in get_wikidata_properties(entity, use_cache)
#     108     try:
# --> 109         ret = wiki_sparql.queryAndConvert()
#     110         for r in ret["results"]["bindings"]:
#
# ~/miniforge3/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in queryAndConvert(self)
#    1113         """
# -> 1114         res = self.query()
#    1115         return res.convert()
#
# ~/miniforge3/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#
# ~/miniforge3/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1070             if self.timeout:
# -> 1071                 response = urlopener(request, timeout=self.timeout)
#    1072             else:
#
# ~/miniforge3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#
# ~/miniforge3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#
# ~/miniforge3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#
# ~/miniforge3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#
# ~/miniforge3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#
# ~/miniforge3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 raise URLError(err)
# -> 1350             r = h.getresponse()
#    1351         except:
#
# ~/miniforge3/lib/python3.9/http/client.py in getresponse(self)
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#
# ~/miniforge3/lib/python3.9/http/client.py in begin(self)
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#
# ~/miniforge3/lib/python3.9/http/client.py in _read_status(self)
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#
# ~/miniforge3/lib/python3.9/socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~/miniforge3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/miniforge3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/2063317307.py in <module>
# ----> 1 evaluate_data('wqa',wqa_df)
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/144909782.py in evaluate_data(name, dataframe, max)
#      30           question = row['question']
#      31           print(index,":",question)
# ---> 32           answers = get_answers(question,-1,wiki=True,dbpedia=True)
#      33           l1.append([a['value'] for a in answers])
#      34           answers = get_answers(question,3,wiki=True,dbpedia=True)
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/4143958644.py in get_answers(question, max, wiki, dbpedia, verbose)
#      11     for e in entities:
#      12         if (wiki):
# ---> 13             for r in get_wikidata_resource(question,e):
#      14                 if (verbose):
#      15                     print("- Wiki Resources:",{'id':r['id'],'label':r['label'],'description':r['description']})
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/1935953053.py in get_wikidata_resource(context, entity, max, use_cache)
#     170     if (entity != lema_entity):
#     171         candidate_ids = [c['id'] for c in candidates]
# --> 172         for ac in get_wikidata_candidates(lema_entity,use_cache):
#     173             if (ac['id'] not in candidate_ids):
#     174                 candidates.append(ac)
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/1935953053.py in get_wikidata_candidates(label, use_cache, verbose)
#     158             'id':answer['id'],
#     159             'description' : description,
# --> 160             'properties' : get_wikidata_properties(answer['id'],use_cache)
#     161         }
#     162         candidates.append(candidate)
#
# /var/folders/pl/5b04mlvj1rn614d6tswgqljw0000gn/T/ipykernel_58862/1935953053.py in get_wikidata_properties(entity, use_cache)
#     115                         result.append({'id':id, 'value':value})
#     116     except Exception as e:
# --> 117         print("Error on wikidata property query:",e + "->" + query_text)
#     118     break
#     119   wiki_cache[entity] = result
#
# TypeError: unsupported operand type(s) for +: 'timeout' and 'str'

# %%
make_report('wqa')

# %% [markdown]
# ## Free Tests

# %%
wiki_cache = {}
dbpedia_cache = {}
entities_cache = {}

# %%
sample_question = "what was the country of origin of the tv show sidewalks entertainment"
sample_entity = "tv show sidewalks entertainment"
for index, candidate in enumerate(get_wikidata_candidates(sample_question,sample_entity)):
    print(index,":",candidate['id'], candidate['label'])

# %%
sample_question = "what was the country of origin of the tv show sidewalks entertainment"
sample_entity = "tv show sidewalks entertainment"
for index, candidate in enumerate(get_wikidata_resource(sample_question,sample_entity)):
    print(index,":",candidate['id'], candidate['label'])
    summary = get_wikidata_summary(candidate,sample_question,3)
    print("Summary:",summary)
    answer = get_answer_in_context(sample_question,summary,verbose=True)
    print("Answer:",answer)

# %%
sample_question = "What drug is used to treat schizophrenia?"
sample_entity = "roger marquis"
print("DBpedia Resource for question:", sample_question, "and entity:",sample_entity)
for index, candidate in enumerate(get_dbpedia_resource(sample_question,sample_entity)):
    print(index,":",candidate['id'], candidate['label'])
    print("Summary:",get_dbpedia_summary(candidate,sample_question,3))
# Out:
# DBpedia Resource for question: Where did roger marquis die and entity: roger marquis
# 0 : Roger_Marquis Roger Marquis
# Summary: The death place of Roger Marquis is Holyoke, Massachusetts. The death date of Roger Marquis is 2004-07-19. The name of Roger Marquis is Roger Marquis.

# %%
for i,a in enumerate(get_answers("What position does carlos gomez play?",max=-1,wiki=True,dbpedia=True,verbose=True)):
    print(i,":",a)
# Out:
# Question: What position does carlos gomez play?
# Entities: ['carlos gomez']
# ## Sorted Candidates by By Name :  [{'name': 'Carlos Gomez', 'id': 'Q89898891', 'description': 'researcher', 'score': 0.9}, {'name': 'Carlos A Gomez', 'id': 'Q91676432', 'description': 'researcher (ORCID 0000-0001-5486-5710)', 'score': 0.9}, {'name': 'Carlos Gómez', 'id': 'Q949506', 'description': 'American actor', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Q51944192', 'description': 'researcher', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Q2747238', 'description': 'Dominican Republic baseball player', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Q3660067', 'description': 'Argentinian comics artist', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Q5750557', 'description': 'Chilean association football player born 1992', 'score': 0.7}, {'name': 'Carlos M Gómez', 'id': 'Q40124092', 'description': 'researcher', 'score': 0.7}]
# ## Sorted Candidates by By Properties :  [{'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.5}, {'name': 'Carlos Gómez', 'id': 'Q2747238', 'description': 'Dominican Republic baseball player', 'score': 0.5}, {'name': 'Carlos Gómez', 'id': 'Q5750557', 'description': 'Chilean association football player born 1992', 'score': 0.5}, {'name': 'Carlos Gomez', 'id': 'Q89898891', 'description': 'researcher', 'score': 0.43333332737286884}, {'name': 'Carlos A Gomez', 'id': 'Q91676432', 'description': 'researcher (ORCID 0000-0001-5486-5710)', 'score': 0.43333332737286884}, {'name': 'Carlos Gómez', 'id': 'Q949506', 'description': 'American actor', 'score': 0.36666666467984516}]
# ## Sorted Candidates by By Description :  [{'name': 'Carlos Gómez', 'id': 'Q203210', 'description': 'Mexican footballer (1952-2017)', 'score': 0.5}]
# - Wiki Resources: {'id': 'Q203210', 'label': 'Carlos Gómez', 'description': 'Mexican footballer (1952-2017)'}
# ## Sorted Candidates by By Name :  [{'name': 'Carlos Gomes', 'id': 'Carlos_Gomes', 'description': '', 'score': 0.8}, {'name': 'Carlos Gomes Júnior', 'id': 'Carlos_Gomes_Júnior', 'description': 'Carlos Domingos Gomes Júnior (born December 19, 1949) is a Guinea-Bissauan politician who was Prime', 'score': 0.7}, {'name': 'Juan Carlos Gómez', 'id': 'Juan_Carlos_Gómez', 'description': 'Juan Carlos Gómez (born 26 July 1973) is a Cuban former professional boxer who competed from 1995', 'score': 0.7}, {'name': 'Scott Gomez', 'id': 'Scott_Gomez', 'description': 'Scott Carlos Gomez (born December 23, 1979) is a former American professional ice hockey coach', 'score': 0.7}, {'name': 'Carlos Gómez-Herrera', 'id': 'Carlos_Gómez-Herrera', 'description': 'Carlos Gómez-Herrera (Spanish pronunciation: [ˈkaɾloz ˈɣomeθ eˈreɾa]; born 30 April 1990', 'score': 0.7}, {'name': 'Carlos Gomes (footballer, born 1932)', 'id': 'Carlos_Gomes_(footballer,_born_1932)', 'description': 'Carlos António do Carmo Costa Gomes (18 January 1932, in Barreiro – 18 October 2005, in Lisbon', 'score': 0.7}, {'name': 'Carlos Gómez', 'id': 'Carlos_Gómez', 'description': 'Carlos Argelis Gómez Peña, nicknamed Go-Go, (born December 4, 1985) is a Dominican former', 'score': 0.7}, {'name': 'Carlos Gómez (actor)', 'id': 'Carlos_Gómez_(actor)', 'description': 'Carlos Gómez (born January 1, 1962) is an American actor.', 'score': 0.6}, {'name': 'Roberto Carlos Mario Gómez', 'id': 'Roberto_Carlos_Mario_Gómez', 'description': 'Roberto Mario Carlos Gomez (born February 27, 1957 in Mar del Plata) is an Argentine football', 'score': 0.6}, {'name': 'Carlos Argüello Gómez', 'id': 'Carlos_Argüello_Gómez', 'description': 'Dr. Carlos José Argüello Gómez is a Nicaraguan lawyer and diplomat. He has been the  since 1983.', 'score': 0.6}]
# ## Sorted Candidates by By Properties :  [{'name': 'Scott Gomez', 'id': 'Scott_Gomez', 'description': 'Scott Carlos Gomez (born December 23, 1979) is a former American professional ice hockey coach', 'score': 0.5}, {'name': 'Carlos Gomes (footballer, born 1932)', 'id': 'Carlos_Gomes_(footballer,_born_1932)', 'description': 'Carlos António do Carmo Costa Gomes (18 January 1932, in Barreiro – 18 October 2005, in Lisbon', 'score': 0.4333333373069763}, {'name': 'Carlos Gómez', 'id': 'Carlos_Gómez', 'description': 'Carlos Argelis Gómez Peña, nicknamed Go-Go, (born December 4, 1985) is a Dominican former', 'score': 0.4333333373069763}, {'name': 'Carlos Gomes Júnior', 'id': 'Carlos_Gomes_Júnior', 'description': 'Carlos Domingos Gomes Júnior (born December 19, 1949) is a Guinea-Bissauan politician who was Prime', 'score': 0.36666666467984516}]
# ## Sorted Candidates by By Description :  [{'name': 'Carlos Gómez', 'id': 'Carlos_Gómez', 'description': 'Carlos Argelis Gómez Peña, nicknamed Go-Go, (born December 4, 1985) is a Dominican former', 'score': 0.4555555582046509}]
# - DBpedia Resources: {'id': 'Carlos_Gómez', 'label': 'Carlos Gómez', 'description': 'Carlos Argelis Gómez Peña, nicknamed Go-Go, (born December 4, 1985) is a Dominican former'}
# 2 summaries created
# 0 : {'value': 'defender', 'score': 1.0, 'summary': 'The position played on team / speciality of Carlos Gómez is defender.', 'start': 60, 'end': 68, 'relevance': 1}
# 1 : {'value': 'Center fielder', 'score': 1.0, 'summary': 'The position of Carlos Gómez is Center fielder.', 'start': 32, 'end': 46, 'relevance': 1}

# %%
sample_question = "What drug is used to treat schizophrenia?"
for e in get_entities(sample_question):
    print("Entity:",e)
    print("Wikidata Resources:")
    for r in get_wikidata_resource(sample_question,e):
        print(r)
    print("DBpedia Resources:")
    for r in get_wikidata_resource(sample_question,e):
        print(r)
# Out:
# Entity: schizophrenia
# Wikidata Resources:
# {'label': 'schizophrenia', 'id': 'Q41112', 'description': 'psychotic disorder characterized by emotional responsiveness and disintegration of thought process', 'properties': [{'id': 'P101', 'value': 'field of work'}, {'id': 'P138', 'value': 'named after'}, {'id': 'P373', 'value': 'Commons category'}, {'id': 'P494', 'value': 'ICD-10'}, {'id': 'P557', 'value': 'DiseasesDB'}, {'id': 'P493', 'value': 'ICD-9'}, {'id': 'P672', 'value': 'MeSH tree code'}, {'id': 'P279', 'value': 'subclass of'}, {'id': 'P301', 'value': "category's main topic"}, {'id': 'P180', 'value': 'depicts'}, {'id': 'P780', 'value': 'symptoms and signs'}, {'id': 'P828', 'value': 'has cause'}, {'id': 'P924', 'value': 'possible treatment'}, {'id': 'P910', 'value': "topic's main category"}, {'id': 'P921', 'value': 'main subject'}, {'id': 'P989', 'value': 'spoken text audio'}, {'id': 'P1050', 'value': 'medical condition'}, {'id': 'P971', 'value': 'category combines topics'}, {'id': 'P1114', 'value': 'quantity'}, {'id': 'P1269', 'value': 'facet of'}, {'id': 'P1424', 'value': "topic's main template"}, {'id': 'P1423', 'value': 'template has topic'}, {'id': 'P1692', 'value': 'ICD-9-CM'}, {'id': 'P1889', 'value': 'different from'}, {'id': 'P1912', 'value': 'gene deletion association with'}, {'id': 'P1911', 'value': 'increased expression in'}, {'id': 'P1910', 'value': 'decreased expression in'}, {'id': 'P1995', 'value': 'health specialty'}, {'id': 'P1916', 'value': 'gene substitution association with'}, {'id': 'P1917', 'value': 'posttranslational modification association with'}, {'id': 'P1918', 'value': 'altered regulation leads to'}, {'id': 'P2176', 'value': 'drug or therapy used for treatment'}, {'id': 'P2175', 'value': 'medical condition treated'}, {'id': 'P2293', 'value': 'genetic association'}, {'id': 'P2888', 'value': 'exact match'}, {'id': 'P2892', 'value': 'UMLS CUI'}, {'id': 'P3235', 'value': 'PhilPapers topic'}, {'id': 'P3984', 'value': 'subreddit'}, {'id': 'P4044', 'value': 'therapeutic area'}, {'id': 'P4229', 'value': 'ICD-10-CM'}, {'id': 'P5166', 'value': 'established from medical condition'}, {'id': 'P5132', 'value': 'suggests the existence of'}, {'id': 'P5137', 'value': 'item for this sense'}, {'id': 'P6385', 'value': 'Krugosvet article'}, {'id': 'P7807', 'value': 'ICD-11 (foundation)'}], 'score': 0.5888889034589132}
# DBpedia Resources:
# {'label': 'schizophrenia', 'id': 'Q41112', 'description': 'psychotic disorder characterized by emotional responsiveness and disintegration of thought process', 'properties': [{'id': 'P101', 'value': 'field of work'}, {'id': 'P138', 'value': 'named after'}, {'id': 'P373', 'value': 'Commons category'}, {'id': 'P494', 'value': 'ICD-10'}, {'id': 'P557', 'value': 'DiseasesDB'}, {'id': 'P493', 'value': 'ICD-9'}, {'id': 'P672', 'value': 'MeSH tree code'}, {'id': 'P279', 'value': 'subclass of'}, {'id': 'P301', 'value': "category's main topic"}, {'id': 'P180', 'value': 'depicts'}, {'id': 'P780', 'value': 'symptoms and signs'}, {'id': 'P828', 'value': 'has cause'}, {'id': 'P924', 'value': 'possible treatment'}, {'id': 'P910', 'value': "topic's main category"}, {'id': 'P921', 'value': 'main subject'}, {'id': 'P989', 'value': 'spoken text audio'}, {'id': 'P1050', 'value': 'medical condition'}, {'id': 'P971', 'value': 'category combines topics'}, {'id': 'P1114', 'value': 'quantity'}, {'id': 'P1269', 'value': 'facet of'}, {'id': 'P1424', 'value': "topic's main template"}, {'id': 'P1423', 'value': 'template has topic'}, {'id': 'P1692', 'value': 'ICD-9-CM'}, {'id': 'P1889', 'value': 'different from'}, {'id': 'P1912', 'value': 'gene deletion association with'}, {'id': 'P1911', 'value': 'increased expression in'}, {'id': 'P1910', 'value': 'decreased expression in'}, {'id': 'P1995', 'value': 'health specialty'}, {'id': 'P1916', 'value': 'gene substitution association with'}, {'id': 'P1917', 'value': 'posttranslational modification association with'}, {'id': 'P1918', 'value': 'altered regulation leads to'}, {'id': 'P2176', 'value': 'drug or therapy used for treatment'}, {'id': 'P2175', 'value': 'medical condition treated'}, {'id': 'P2293', 'value': 'genetic association'}, {'id': 'P2888', 'value': 'exact match'}, {'id': 'P2892', 'value': 'UMLS CUI'}, {'id': 'P3235', 'value': 'PhilPapers topic'}, {'id': 'P3984', 'value': 'subreddit'}, {'id': 'P4044', 'value': 'therapeutic area'}, {'id': 'P4229', 'value': 'ICD-10-CM'}, {'id': 'P5166', 'value': 'established from medical condition'}, {'id': 'P5132', 'value': 'suggests the existence of'}, {'id': 'P5137', 'value': 'item for this sense'}, {'id': 'P6385', 'value': 'Krugosvet article'}, {'id': 'P7807', 'value': 'ICD-11 (foundation)'}], 'score': 0.5888889034589132}
